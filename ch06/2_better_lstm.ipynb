# %% [markdown]
# Click this button to run in Colab.
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ssuai/deep_learning_from_scratch_2/blob/master/ch06/2_better_lstm.ipynb)

# %%
# some helper functions for Colab
def is_colab():
    try:
        import google.colab
        return True
    except ImportError:
        return False
if is_colab():
    # !git clone --filter=blob:none --sparse https://github.com/ssuai/deep_learning_from_scratch_2.git
    # %cd deep_learning_from_scratch_2
    # !git sparse-checkout set dataset common ch06
else:
    import sys
    import os
#     sys.path.append('..')
    sys.path.append(os.pardir)  # 부모 디렉터리의 파일을 가져올 수 있도록 설정
# Out:
# Cloning into 'deep_learning_from_scratch_2'...
# remote: Enumerating objects: 440, done.
# remote: Counting objects: 100% (225/225), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 440 (delta 191), reused 187 (delta 170), pack-reused 215 (from 2)
# Receiving objects: 100% (440/440), 76.63 KiB | 5.11 MiB/s, done.
# Resolving deltas: 100% (244/244), done.
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 5 (delta 0), reused 0 (delta 0), pack-reused 4 (from 2)
# Receiving objects: 100% (5/5), 22.11 MiB | 34.14 MiB/s, done.
# Updating files: 100% (5/5), done.
# /content/deep_learning_from_scratch_2
# remote: Enumerating objects: 28, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 28 (delta 3), reused 3 (delta 1), pack-reused 8 (from 2)
# Receiving objects: 100% (28/28), 4.80 MiB | 18.60 MiB/s, done.
# Resolving deltas: 100% (3/3), done.

# %%
# %load better_rnnlm.py
# import sys
# sys.path.append('..')
from common.time_layers import *
from common.np import *  # import numpy as np
from common.base_model import BaseModel


class BetterRnnlm(BaseModel):
    '''
     LSTM 계층을 2개 사용하고 각 층에 드롭아웃을 적용한 모델이다.
     아래 [1]에서 제안한 모델을 기초로 하였고, [2]와 [3]의 가중치 공유(weight tying)를 적용했다.

     [1] Recurrent Neural Network Regularization (https://arxiv.org/abs/1409.2329)
     [2] Using the Output Embedding to Improve Language Models (https://arxiv.org/abs/1608.05859)
     [3] Tying Word Vectors and Word Classifiers (https://arxiv.org/pdf/1611.01462.pdf)
    '''
    def __init__(self, vocab_size=10000, wordvec_size=650,
                 hidden_size=650, dropout_ratio=0.5):
        V, D, H = vocab_size, wordvec_size, hidden_size
        rn = np.random.randn

        embed_W = (rn(V, D) / 100).astype('f')
        lstm_Wx1 = (rn(D, 4 * H) / np.sqrt(D)).astype('f')
        lstm_Wh1 = (rn(H, 4 * H) / np.sqrt(H)).astype('f')
        lstm_b1 = np.zeros(4 * H).astype('f')
        lstm_Wx2 = (rn(H, 4 * H) / np.sqrt(H)).astype('f')
        lstm_Wh2 = (rn(H, 4 * H) / np.sqrt(H)).astype('f')
        lstm_b2 = np.zeros(4 * H).astype('f')
        affine_b = np.zeros(V).astype('f')

        self.layers = [
            TimeEmbedding(embed_W),
            TimeDropout(dropout_ratio),
            TimeLSTM(lstm_Wx1, lstm_Wh1, lstm_b1, stateful=True),
            TimeDropout(dropout_ratio),
            TimeLSTM(lstm_Wx2, lstm_Wh2, lstm_b2, stateful=True),
            TimeDropout(dropout_ratio),
            TimeAffine(embed_W.T, affine_b)  # weight tying!!
        ]
        self.loss_layer = TimeSoftmaxWithLoss()
        self.lstm_layers = [self.layers[2], self.layers[4]]
        self.drop_layers = [self.layers[1], self.layers[3], self.layers[5]]

        self.params, self.grads = [], []
        for layer in self.layers:
            self.params += layer.params
            self.grads += layer.grads

    def predict(self, xs, train_flg=False):
        for layer in self.drop_layers:
            layer.train_flg = train_flg

        for layer in self.layers:
            xs = layer.forward(xs)
        return xs

    def forward(self, xs, ts, train_flg=True):
        score = self.predict(xs, train_flg)
        loss = self.loss_layer.forward(score, ts)
        return loss

    def backward(self, dout=1):
        dout = self.loss_layer.backward(dout)
        for layer in reversed(self.layers):
            dout = layer.backward(dout)
        return dout

    def reset_state(self):
        for layer in self.lstm_layers:
            layer.reset_state()

# %%
# %load train_better_rnnlm.py
import sys
sys.path.append('..')
from common import config
# GPU에서 실행하려면 아래 주석을 해제하세요(CuPy 필요).
# ==============================================
# config.GPU = True
# ==============================================
from common.optimizer import SGD
from common.trainer import RnnlmTrainer
from common.util import eval_perplexity, to_gpu
from dataset import ptb
# from better_rnnlm import BetterRnnlm # defined above


# 하이퍼파라미터 설정
batch_size = 20
wordvec_size = 650
hidden_size = 650
time_size = 35
lr = 20.0
max_epoch = 40
max_grad = 0.25
dropout = 0.5

# 학습 데이터 읽기
corpus, word_to_id, id_to_word = ptb.load_data('train')
corpus_val, _, _ = ptb.load_data('val')
corpus_test, _, _ = ptb.load_data('test')

if config.GPU:
    corpus = to_gpu(corpus)
    corpus_val = to_gpu(corpus_val)
    corpus_test = to_gpu(corpus_test)

vocab_size = len(word_to_id)
xs = corpus[:-1]
ts = corpus[1:]

model = BetterRnnlm(vocab_size, wordvec_size, hidden_size, dropout)
optimizer = SGD(lr)
trainer = RnnlmTrainer(model, optimizer)

best_ppl = float('inf')
for epoch in range(max_epoch):
    trainer.fit(xs, ts, max_epoch=1, batch_size=batch_size,
                time_size=time_size, max_grad=max_grad)

    model.reset_state()
    ppl = eval_perplexity(model, corpus_val)
    print('검증 퍼플렉서티: ', ppl)

    if best_ppl > ppl:
        best_ppl = ppl
        model.save_params()
    else:
        lr /= 4.0
        optimizer.lr = lr

    model.reset_state()
    print('-' * 50)


# 테스트 데이터로 평가
model.reset_state()
ppl_test = eval_perplexity(model, corpus_test)
print('테스트 퍼플렉서티: ', ppl_test)
# Out:
# Downloading ptb.train.txt ...
# Done
# Downloading ptb.valid.txt ...
# Done
# Downloading ptb.test.txt ...
# Done
# | 에폭 1 |  반복 1 / 1327 | 시간 3[s] | 퍼플렉서티 10000.00
# | 에폭 1 |  반복 21 / 1327 | 시간 71[s] | 퍼플렉서티 4597.35
# | 에폭 1 |  반복 41 / 1327 | 시간 141[s] | 퍼플렉서티 1641.20
# | 에폭 1 |  반복 61 / 1327 | 시간 208[s] | 퍼플렉서티 1245.83
# | 에폭 1 |  반복 81 / 1327 | 시간 275[s] | 퍼플렉서티 1011.80
# | 에폭 1 |  반복 101 / 1327 | 시간 341[s] | 퍼플렉서티 906.83
# | 에폭 1 |  반복 121 / 1327 | 시간 406[s] | 퍼플렉서티 807.91
# | 에폭 1 |  반복 141 / 1327 | 시간 472[s] | 퍼플렉서티 743.39
# | 에폭 1 |  반복 161 / 1327 | 시간 539[s] | 퍼플렉서티 694.70
# | 에폭 1 |  반복 181 / 1327 | 시간 605[s] | 퍼플렉서티 688.11
# | 에폭 1 |  반복 201 / 1327 | 시간 672[s] | 퍼플렉서티 583.75
# | 에폭 1 |  반복 221 / 1327 | 시간 738[s] | 퍼플렉서티 575.71
# | 에폭 1 |  반복 241 / 1327 | 시간 805[s] | 퍼플렉서티 528.76
# | 에폭 1 |  반복 261 / 1327 | 시간 871[s] | 퍼플렉서티 524.88
# | 에폭 1 |  반복 281 / 1327 | 시간 938[s] | 퍼플렉서티 516.15
# | 에폭 1 |  반복 301 / 1327 | 시간 1005[s] | 퍼플렉서티 451.56
# | 에폭 1 |  반복 321 / 1327 | 시간 1072[s] | 퍼플렉서티 397.03
# | 에폭 1 |  반복 341 / 1327 | 시간 1139[s] | 퍼플렉서티 451.11
# | 에폭 1 |  반복 361 / 1327 | 시간 1205[s] | 퍼플렉서티 466.06
# | 에폭 1 |  반복 381 / 1327 | 시간 1272[s] | 퍼플렉서티 385.53
# | 에폭 1 |  반복 401 / 1327 | 시간 1338[s] | 퍼플렉서티 405.22
# | 에폭 1 |  반복 421 / 1327 | 시간 1404[s] | 퍼플렉서티 391.89
# | 에폭 1 |  반복 441 / 1327 | 시간 1468[s] | 퍼플렉서티 381.91
# | 에폭 1 |  반복 461 / 1327 | 시간 1532[s] | 퍼플렉서티 371.41
# | 에폭 1 |  반복 481 / 1327 | 시간 1597[s] | 퍼플렉서티 346.23
# | 에폭 1 |  반복 501 / 1327 | 시간 1663[s] | 퍼플렉서티 358.11
# | 에폭 1 |  반복 521 / 1327 | 시간 1727[s] | 퍼플렉서티 334.50
# | 에폭 1 |  반복 541 / 1327 | 시간 1790[s] | 퍼플렉서티 359.63
# | 에폭 1 |  반복 561 / 1327 | 시간 1854[s] | 퍼플렉서티 321.73
# | 에폭 1 |  반복 581 / 1327 | 시간 1918[s] | 퍼플렉서티 290.50
# | 에폭 1 |  반복 601 / 1327 | 시간 1981[s] | 퍼플렉서티 375.57
# | 에폭 1 |  반복 621 / 1327 | 시간 2046[s] | 퍼플렉서티 345.90
# | 에폭 1 |  반복 641 / 1327 | 시간 2109[s] | 퍼플렉서티 316.86
# | 에폭 1 |  반복 661 / 1327 | 시간 2174[s] | 퍼플렉서티 301.22
# | 에폭 1 |  반복 681 / 1327 | 시간 2238[s] | 퍼플렉서티 256.40
# | 에폭 1 |  반복 701 / 1327 | 시간 2301[s] | 퍼플렉서티 278.19
# | 에폭 1 |  반복 721 / 1327 | 시간 2365[s] | 퍼플렉서티 287.60
# | 에폭 1 |  반복 741 / 1327 | 시간 2430[s] | 퍼플렉서티 247.82
# | 에폭 1 |  반복 761 / 1327 | 시간 2492[s] | 퍼플렉서티 258.94
# | 에폭 1 |  반복 781 / 1327 | 시간 2556[s] | 퍼플렉서티 242.42
# | 에폭 1 |  반복 801 / 1327 | 시간 2620[s] | 퍼플렉서티 268.04
# | 에폭 1 |  반복 821 / 1327 | 시간 2684[s] | 퍼플렉서티 249.71
# | 에폭 1 |  반복 841 / 1327 | 시간 2748[s] | 퍼플렉서티 250.67
# | 에폭 1 |  반복 861 / 1327 | 시간 2814[s] | 퍼플렉서티 249.64
# | 에폭 1 |  반복 881 / 1327 | 시간 2878[s] | 퍼플렉서티 230.90
# | 에폭 1 |  반복 901 / 1327 | 시간 2943[s] | 퍼플렉서티 278.44
# | 에폭 1 |  반복 921 / 1327 | 시간 3008[s] | 퍼플렉서티 252.95
# | 에폭 1 |  반복 941 / 1327 | 시간 3073[s] | 퍼플렉서티 255.10
# | 에폭 1 |  반복 961 / 1327 | 시간 3138[s] | 퍼플렉서티 272.36
# | 에폭 1 |  반복 981 / 1327 | 시간 3203[s] | 퍼플렉서티 256.43
# | 에폭 1 |  반복 1001 / 1327 | 시간 3267[s] | 퍼플렉서티 215.53
# | 에폭 1 |  반복 1021 / 1327 | 시간 3332[s] | 퍼플렉서티 250.25
# | 에폭 1 |  반복 1041 / 1327 | 시간 3395[s] | 퍼플렉서티 231.13
# | 에폭 1 |  반복 1061 / 1327 | 시간 3459[s] | 퍼플렉서티 216.73
# | 에폭 1 |  반복 1081 / 1327 | 시간 3525[s] | 퍼플렉서티 186.77
# | 에폭 1 |  반복 1101 / 1327 | 시간 3589[s] | 퍼플렉서티 213.85
# | 에폭 1 |  반복 1121 / 1327 | 시간 3655[s] | 퍼플렉서티 251.73
# | 에폭 1 |  반복 1141 / 1327 | 시간 3719[s] | 퍼플렉서티 231.71
# | 에폭 1 |  반복 1161 / 1327 | 시간 3785[s] | 퍼플렉서티 219.32
# | 에폭 1 |  반복 1181 / 1327 | 시간 3851[s] | 퍼플렉서티 209.07
# | 에폭 1 |  반복 1201 / 1327 | 시간 3916[s] | 퍼플렉서티 181.00
# | 에폭 1 |  반복 1221 / 1327 | 시간 3981[s] | 퍼플렉서티 177.69
# | 에폭 1 |  반복 1241 / 1327 | 시간 4044[s] | 퍼플렉서티 206.63
# | 에폭 1 |  반복 1261 / 1327 | 시간 4108[s] | 퍼플렉서티 189.68
# | 에폭 1 |  반복 1281 / 1327 | 시간 4173[s] | 퍼플렉서티 198.07
# | 에폭 1 |  반복 1301 / 1327 | 시간 4238[s] | 퍼플렉서티 246.16
# | 에폭 1 |  반복 1321 / 1327 | 시간 4302[s] | 퍼플렉서티 231.78
# 퍼플렉서티 평가 중 ...
# 209 / 210
# 검증 퍼플렉서티:  200.54551228418126
# --------------------------------------------------
# | 에폭 2 |  반복 1 / 1327 | 시간 2[s] | 퍼플렉서티 288.46
# | 에폭 2 |  반복 21 / 1327 | 시간 67[s] | 퍼플렉서티 228.42
# | 에폭 2 |  반복 41 / 1327 | 시간 133[s] | 퍼플렉서티 213.61
# | 에폭 2 |  반복 61 / 1327 | 시간 197[s] | 퍼플렉서티 196.24
# | 에폭 2 |  반복 81 / 1327 | 시간 262[s] | 퍼플렉서티 177.70
# | 에폭 2 |  반복 101 / 1327 | 시간 326[s] | 퍼플렉서티 166.28
# | 에폭 2 |  반복 121 / 1327 | 시간 389[s] | 퍼플렉서티 181.43
# | 에폭 2 |  반복 141 / 1327 | 시간 452[s] | 퍼플렉서티 200.19
# | 에폭 2 |  반복 161 / 1327 | 시간 515[s] | 퍼플렉서티 214.19
# | 에폭 2 |  반복 181 / 1327 | 시간 578[s] | 퍼플렉서티 225.63
# | 에폭 2 |  반복 201 / 1327 | 시간 643[s] | 퍼플렉서티 207.80
# | 에폭 2 |  반복 221 / 1327 | 시간 708[s] | 퍼플렉서티 205.24
# | 에폭 2 |  반복 241 / 1327 | 시간 773[s] | 퍼플렉서티 196.26
# | 에폭 2 |  반복 261 / 1327 | 시간 837[s] | 퍼플렉서티 211.04
# | 에폭 2 |  반복 281 / 1327 | 시간 901[s] | 퍼플렉서티 205.94
# | 에폭 2 |  반복 301 / 1327 | 시간 964[s] | 퍼플렉서티 187.63
# | 에폭 2 |  반복 321 / 1327 | 시간 1028[s] | 퍼플렉서티 153.31
# | 에폭 2 |  반복 341 / 1327 | 시간 1092[s] | 퍼플렉서티 199.38
# | 에폭 2 |  반복 361 / 1327 | 시간 1156[s] | 퍼플렉서티 217.61
# | 에폭 2 |  반복 381 / 1327 | 시간 1221[s] | 퍼플렉서티 171.93
# | 에폭 2 |  반복 401 / 1327 | 시간 1285[s] | 퍼플렉서티 192.42
# | 에폭 2 |  반복 421 / 1327 | 시간 1349[s] | 퍼플렉서티 176.55
# | 에폭 2 |  반복 441 / 1327 | 시간 1412[s] | 퍼플렉서티 178.76
# | 에폭 2 |  반복 461 / 1327 | 시간 1477[s] | 퍼플렉서티 182.45
# | 에폭 2 |  반복 481 / 1327 | 시간 1540[s] | 퍼플렉서티 175.59
# | 에폭 2 |  반복 501 / 1327 | 시간 1604[s] | 퍼플렉서티 189.23
# | 에폭 2 |  반복 521 / 1327 | 시간 1669[s] | 퍼플렉서티 191.96
# | 에폭 2 |  반복 541 / 1327 | 시간 1733[s] | 퍼플렉서티 199.86
# | 에폭 2 |  반복 561 / 1327 | 시간 1798[s] | 퍼플렉서티 171.58
# | 에폭 2 |  반복 581 / 1327 | 시간 1865[s] | 퍼플렉서티 157.99
# | 에폭 2 |  반복 601 / 1327 | 시간 1926[s] | 퍼플렉서티 212.84
# | 에폭 2 |  반복 621 / 1327 | 시간 1990[s] | 퍼플렉서티 201.88
# | 에폭 2 |  반복 641 / 1327 | 시간 2054[s] | 퍼플렉서티 182.87
# | 에폭 2 |  반복 661 / 1327 | 시간 2118[s] | 퍼플렉서티 173.19
# | 에폭 2 |  반복 681 / 1327 | 시간 2183[s] | 퍼플렉서티 144.33
# | 에폭 2 |  반복 701 / 1327 | 시간 2247[s] | 퍼플렉서티 169.64
# | 에폭 2 |  반복 721 / 1327 | 시간 2312[s] | 퍼플렉서티 174.21
# | 에폭 2 |  반복 741 / 1327 | 시간 2375[s] | 퍼플렉서티 149.11
# | 에폭 2 |  반복 761 / 1327 | 시간 2439[s] | 퍼플렉서티 152.86
# | 에폭 2 |  반복 781 / 1327 | 시간 2504[s] | 퍼플렉서티 147.62
# | 에폭 2 |  반복 801 / 1327 | 시간 2567[s] | 퍼플렉서티 170.12
# | 에폭 2 |  반복 821 / 1327 | 시간 2632[s] | 퍼플렉서티 161.29
# | 에폭 2 |  반복 841 / 1327 | 시간 2697[s] | 퍼플렉서티 164.25
# | 에폭 2 |  반복 861 / 1327 | 시간 2760[s] | 퍼플렉서티 159.38
# | 에폭 2 |  반복 881 / 1327 | 시간 2824[s] | 퍼플렉서티 148.15
# | 에폭 2 |  반복 901 / 1327 | 시간 2887[s] | 퍼플렉서티 188.48
# | 에폭 2 |  반복 921 / 1327 | 시간 2951[s] | 퍼플렉서티 165.14
# | 에폭 2 |  반복 941 / 1327 | 시간 3015[s] | 퍼플렉서티 169.28
# | 에폭 2 |  반복 961 / 1327 | 시간 3079[s] | 퍼플렉서티 185.02
# | 에폭 2 |  반복 981 / 1327 | 시간 3143[s] | 퍼플렉서티 174.12
# | 에폭 2 |  반복 1001 / 1327 | 시간 3207[s] | 퍼플렉서티 148.19
# | 에폭 2 |  반복 1021 / 1327 | 시간 3269[s] | 퍼플렉서티 176.69
# | 에폭 2 |  반복 1041 / 1327 | 시간 3333[s] | 퍼플렉서티 157.39
# | 에폭 2 |  반복 1061 / 1327 | 시간 3397[s] | 퍼플렉서티 147.93
# | 에폭 2 |  반복 1081 / 1327 | 시간 3462[s] | 퍼플렉서티 122.84
# | 에폭 2 |  반복 1101 / 1327 | 시간 3526[s] | 퍼플렉서티 137.61
# | 에폭 2 |  반복 1121 / 1327 | 시간 3590[s] | 퍼플렉서티 171.56
# | 에폭 2 |  반복 1141 / 1327 | 시간 3654[s] | 퍼플렉서티 160.10
# | 에폭 2 |  반복 1161 / 1327 | 시간 3717[s] | 퍼플렉서티 147.37
# | 에폭 2 |  반복 1181 / 1327 | 시간 3782[s] | 퍼플렉서티 148.89
# | 에폭 2 |  반복 1201 / 1327 | 시간 3846[s] | 퍼플렉서티 126.41
# | 에폭 2 |  반복 1221 / 1327 | 시간 3911[s] | 퍼플렉서티 123.73
# | 에폭 2 |  반복 1241 / 1327 | 시간 3975[s] | 퍼플렉서티 146.18
# | 에폭 2 |  반복 1261 / 1327 | 시간 4038[s] | 퍼플렉서티 138.11
# | 에폭 2 |  반복 1281 / 1327 | 시간 4105[s] | 퍼플렉서티 139.44
# | 에폭 2 |  반복 1301 / 1327 | 시간 4169[s] | 퍼플렉서티 177.15
# | 에폭 2 |  반복 1321 / 1327 | 시간 4231[s] | 퍼플렉서티 172.42
# 퍼플렉서티 평가 중 ...
# 209 / 210
# 검증 퍼플렉서티:  146.82613203280926
# --------------------------------------------------
# | 에폭 3 |  반복 1 / 1327 | 시간 2[s] | 퍼플렉서티 225.78
# | 에폭 3 |  반복 21 / 1327 | 시간 69[s] | 퍼플렉서티 161.86
# | 에폭 3 |  반복 41 / 1327 | 시간 133[s] | 퍼플렉서티 152.47
# | 에폭 3 |  반복 61 / 1327 | 시간 199[s] | 퍼플렉서티 141.83
# | 에폭 3 |  반복 81 / 1327 | 시간 265[s] | 퍼플렉서티 127.64
# | 에폭 3 |  반복 101 / 1327 | 시간 330[s] | 퍼플렉서티 119.55
# | 에폭 3 |  반복 121 / 1327 | 시간 393[s] | 퍼플렉서티 133.33
# | 에폭 3 |  반복 141 / 1327 | 시간 461[s] | 퍼플렉서티 146.51
# | 에폭 3 |  반복 161 / 1327 | 시간 523[s] | 퍼플렉서티 161.89
# | 에폭 3 |  반복 181 / 1327 | 시간 587[s] | 퍼플렉서티 170.86
# | 에폭 3 |  반복 201 / 1327 | 시간 651[s] | 퍼플렉서티 158.72
# | 에폭 3 |  반복 221 / 1327 | 시간 715[s] | 퍼플렉서티 155.43
# | 에폭 3 |  반복 241 / 1327 | 시간 779[s] | 퍼플렉서티 149.78
# | 에폭 3 |  반복 261 / 1327 | 시간 845[s] | 퍼플렉서티 163.90
# | 에폭 3 |  반복 281 / 1327 | 시간 911[s] | 퍼플렉서티 157.71
# | 에폭 3 |  반복 301 / 1327 | 시간 975[s] | 퍼플렉서티 140.41
# | 에폭 3 |  반복 321 / 1327 | 시간 1038[s] | 퍼플렉서티 111.60
# | 에폭 3 |  반복 341 / 1327 | 시간 1104[s] | 퍼플렉서티 152.86
# | 에폭 3 |  반복 361 / 1327 | 시간 1169[s] | 퍼플렉서티 166.66
# | 에폭 3 |  반복 381 / 1327 | 시간 1236[s] | 퍼플렉서티 129.87
# | 에폭 3 |  반복 401 / 1327 | 시간 1300[s] | 퍼플렉서티 149.18
# | 에폭 3 |  반복 421 / 1327 | 시간 1366[s] | 퍼플렉서티 131.08
# | 에폭 3 |  반복 441 / 1327 | 시간 1432[s] | 퍼플렉서티 139.80
# | 에폭 3 |  반복 461 / 1327 | 시간 1498[s] | 퍼플렉서티 138.55
# | 에폭 3 |  반복 481 / 1327 | 시간 1565[s] | 퍼플렉서티 134.73
# | 에폭 3 |  반복 501 / 1327 | 시간 1631[s] | 퍼플렉서티 148.56
# | 에폭 3 |  반복 521 / 1327 | 시간 1696[s] | 퍼플렉서티 153.74
# | 에폭 3 |  반복 541 / 1327 | 시간 1763[s] | 퍼플렉서티 157.88
# | 에폭 3 |  반복 561 / 1327 | 시간 1829[s] | 퍼플렉서티 131.07
# | 에폭 3 |  반복 581 / 1327 | 시간 1895[s] | 퍼플렉서티 122.31
# | 에폭 3 |  반복 601 / 1327 | 시간 1962[s] | 퍼플렉서티 170.83
# | 에폭 3 |  반복 621 / 1327 | 시간 2028[s] | 퍼플렉서티 158.54
# | 에폭 3 |  반복 641 / 1327 | 시간 2092[s] | 퍼플렉서티 145.21
# | 에폭 3 |  반복 661 / 1327 | 시간 2157[s] | 퍼플렉서티 136.51
# | 에폭 3 |  반복 681 / 1327 | 시간 2223[s] | 퍼플렉서티 117.22
# | 에폭 3 |  반복 701 / 1327 | 시간 2287[s] | 퍼플렉서티 134.99
# | 에폭 3 |  반복 721 / 1327 | 시간 2355[s] | 퍼플렉서티 140.94
# | 에폭 3 |  반복 741 / 1327 | 시간 2421[s] | 퍼플렉서티 119.30
# | 에폭 3 |  반복 761 / 1327 | 시간 2488[s] | 퍼플렉서티 113.10
# | 에폭 3 |  반복 781 / 1327 | 시간 2553[s] | 퍼플렉서티 118.93
# | 에폭 3 |  반복 801 / 1327 | 시간 2618[s] | 퍼플렉서티 136.09
# | 에폭 3 |  반복 821 / 1327 | 시간 2684[s] | 퍼플렉서티 134.32
# | 에폭 3 |  반복 841 / 1327 | 시간 2746[s] | 퍼플렉서티 133.50
# | 에폭 3 |  반복 861 / 1327 | 시간 2811[s] | 퍼플렉서티 127.50
# | 에폭 3 |  반복 881 / 1327 | 시간 2877[s] | 퍼플렉서티 119.91
# | 에폭 3 |  반복 901 / 1327 | 시간 2941[s] | 퍼플렉서티 151.59
# | 에폭 3 |  반복 921 / 1327 | 시간 3006[s] | 퍼플렉서티 133.14
# | 에폭 3 |  반복 941 / 1327 | 시간 3072[s] | 퍼플렉서티 139.69
# | 에폭 3 |  반복 961 / 1327 | 시간 3136[s] | 퍼플렉서티 152.01
# | 에폭 3 |  반복 981 / 1327 | 시간 3201[s] | 퍼플렉서티 142.57
# | 에폭 3 |  반복 1001 / 1327 | 시간 3266[s] | 퍼플렉서티 123.26
# | 에폭 3 |  반복 1021 / 1327 | 시간 3330[s] | 퍼플렉서티 146.05
# | 에폭 3 |  반복 1041 / 1327 | 시간 3396[s] | 퍼플렉서티 128.98
# | 에폭 3 |  반복 1061 / 1327 | 시간 3462[s] | 퍼플렉서티 120.93
# | 에폭 3 |  반복 1081 / 1327 | 시간 3528[s] | 퍼플렉서티 100.18
# | 에폭 3 |  반복 1101 / 1327 | 시간 3594[s] | 퍼플렉서티 108.09
# | 에폭 3 |  반복 1121 / 1327 | 시간 3659[s] | 퍼플렉서티 140.12
# | 에폭 3 |  반복 1141 / 1327 | 시간 3721[s] | 퍼플렉서티 134.26
# | 에폭 3 |  반복 1161 / 1327 | 시간 3787[s] | 퍼플렉서티 117.70
# | 에폭 3 |  반복 1181 / 1327 | 시간 3852[s] | 퍼플렉서티 122.15
# | 에폭 3 |  반복 1201 / 1327 | 시간 3916[s] | 퍼플렉서티 104.53
# | 에폭 3 |  반복 1221 / 1327 | 시간 3981[s] | 퍼플렉서티 103.75
# | 에폭 3 |  반복 1241 / 1327 | 시간 4046[s] | 퍼플렉서티 121.50
# | 에폭 3 |  반복 1261 / 1327 | 시간 4113[s] | 퍼플렉서티 116.92
# | 에폭 3 |  반복 1281 / 1327 | 시간 4178[s] | 퍼플렉서티 116.20
# | 에폭 3 |  반복 1301 / 1327 | 시간 4242[s] | 퍼플렉서티 148.41
# | 에폭 3 |  반복 1321 / 1327 | 시간 4307[s] | 퍼플렉서티 145.01
# 퍼플렉서티 평가 중 ...
# 209 / 210
# 검증 퍼플렉서티:  124.74052316176078
# --------------------------------------------------
# | 에폭 4 |  반복 1 / 1327 | 시간 2[s] | 퍼플렉서티 196.73
# | 에폭 4 |  반복 21 / 1327 | 시간 67[s] | 퍼플렉서티 129.76
# | 에폭 4 |  반복 41 / 1327 | 시간 133[s] | 퍼플렉서티 124.43
# | 에폭 4 |  반복 61 / 1327 | 시간 198[s] | 퍼플렉서티 120.49
# | 에폭 4 |  반복 81 / 1327 | 시간 264[s] | 퍼플렉서티 102.93
# | 에폭 4 |  반복 101 / 1327 | 시간 330[s] | 퍼플렉서티 99.83
# | 에폭 4 |  반복 121 / 1327 | 시간 394[s] | 퍼플렉서티 111.58
# | 에폭 4 |  반복 141 / 1327 | 시간 460[s] | 퍼플렉서티 121.43
# | 에폭 4 |  반복 161 / 1327 | 시간 525[s] | 퍼플렉서티 135.24
# | 에폭 4 |  반복 181 / 1327 | 시간 590[s] | 퍼플렉서티 142.73
# | 에폭 4 |  반복 201 / 1327 | 시간 658[s] | 퍼플렉서티 135.76
# | 에폭 4 |  반복 221 / 1327 | 시간 724[s] | 퍼플렉서티 134.20
# | 에폭 4 |  반복 241 / 1327 | 시간 789[s] | 퍼플렉서티 127.65
# | 에폭 4 |  반복 261 / 1327 | 시간 853[s] | 퍼플렉서티 137.28
# | 에폭 4 |  반복 281 / 1327 | 시간 918[s] | 퍼플렉서티 134.24
# | 에폭 4 |  반복 301 / 1327 | 시간 983[s] | 퍼플렉서티 115.52
# | 에폭 4 |  반복 321 / 1327 | 시간 1045[s] | 퍼플렉서티 91.90
# | 에폭 4 |  반복 341 / 1327 | 시간 1110[s] | 퍼플렉서티 128.67
# | 에폭 4 |  반복 361 / 1327 | 시간 1175[s] | 퍼플렉서티 139.98
# | 에폭 4 |  반복 381 / 1327 | 시간 1239[s] | 퍼플렉서티 109.93
# | 에폭 4 |  반복 401 / 1327 | 시간 1304[s] | 퍼플렉서티 127.34
# | 에폭 4 |  반복 421 / 1327 | 시간 1370[s] | 퍼플렉서티 109.73
# | 에폭 4 |  반복 441 / 1327 | 시간 1435[s] | 퍼플렉서티 119.35
# | 에폭 4 |  반복 461 / 1327 | 시간 1499[s] | 퍼플렉서티 118.32
# | 에폭 4 |  반복 481 / 1327 | 시간 1565[s] | 퍼플렉서티 114.27
# | 에폭 4 |  반복 501 / 1327 | 시간 1631[s] | 퍼플렉서티 128.97
# | 에폭 4 |  반복 521 / 1327 | 시간 1695[s] | 퍼플렉서티 130.04
# | 에폭 4 |  반복 541 / 1327 | 시간 1757[s] | 퍼플렉서티 134.41
# | 에폭 4 |  반복 561 / 1327 | 시간 1821[s] | 퍼플렉서티 111.87
# | 에폭 4 |  반복 581 / 1327 | 시간 1884[s] | 퍼플렉서티 104.28
# | 에폭 4 |  반복 601 / 1327 | 시간 1950[s] | 퍼플렉서티 145.96
# | 에폭 4 |  반복 621 / 1327 | 시간 2015[s] | 퍼플렉서티 136.62
# | 에폭 4 |  반복 641 / 1327 | 시간 2079[s] | 퍼플렉서티 125.14
# | 에폭 4 |  반복 661 / 1327 | 시간 2143[s] | 퍼플렉서티 116.06
# | 에폭 4 |  반복 681 / 1327 | 시간 2208[s] | 퍼플렉서티 99.64
# | 에폭 4 |  반복 701 / 1327 | 시간 2271[s] | 퍼플렉서티 116.81
# | 에폭 4 |  반복 721 / 1327 | 시간 2341[s] | 퍼플렉서티 119.76
# | 에폭 4 |  반복 741 / 1327 | 시간 2406[s] | 퍼플렉서티 103.32
# | 에폭 4 |  반복 761 / 1327 | 시간 2468[s] | 퍼플렉서티 94.04
# | 에폭 4 |  반복 781 / 1327 | 시간 2532[s] | 퍼플렉서티 103.97
# | 에폭 4 |  반복 801 / 1327 | 시간 2597[s] | 퍼플렉서티 118.52
# | 에폭 4 |  반복 821 / 1327 | 시간 2663[s] | 퍼플렉서티 117.35
# | 에폭 4 |  반복 841 / 1327 | 시간 2727[s] | 퍼플렉서티 116.62
# | 에폭 4 |  반복 861 / 1327 | 시간 2793[s] | 퍼플렉서티 113.10
# | 에폭 4 |  반복 881 / 1327 | 시간 2857[s] | 퍼플렉서티 104.37
# | 에폭 4 |  반복 901 / 1327 | 시간 2922[s] | 퍼플렉서티 132.31
# | 에폭 4 |  반복 921 / 1327 | 시간 2987[s] | 퍼플렉서티 117.09
# | 에폭 4 |  반복 941 / 1327 | 시간 3052[s] | 퍼플렉서티 122.74
# | 에폭 4 |  반복 961 / 1327 | 시간 3116[s] | 퍼플렉서티 133.38
# | 에폭 4 |  반복 981 / 1327 | 시간 3180[s] | 퍼플렉서티 125.73
# | 에폭 4 |  반복 1001 / 1327 | 시간 3244[s] | 퍼플렉서티 108.71
# | 에폭 4 |  반복 1021 / 1327 | 시간 3312[s] | 퍼플렉서티 128.18
# | 에폭 4 |  반복 1041 / 1327 | 시간 3382[s] | 퍼플렉서티 113.24
# | 에폭 4 |  반복 1061 / 1327 | 시간 3451[s] | 퍼플렉서티 103.94
# | 에폭 4 |  반복 1081 / 1327 | 시간 3520[s] | 퍼플렉서티 86.29
# | 에폭 4 |  반복 1101 / 1327 | 시간 3589[s] | 퍼플렉서티 91.61
# | 에폭 4 |  반복 1121 / 1327 | 시간 3656[s] | 퍼플렉서티 122.81
# | 에폭 4 |  반복 1141 / 1327 | 시간 3723[s] | 퍼플렉서티 116.81
# | 에폭 4 |  반복 1161 / 1327 | 시간 3790[s] | 퍼플렉서티 100.11
# | 에폭 4 |  반복 1181 / 1327 | 시간 3855[s] | 퍼플렉서티 108.19
# | 에폭 4 |  반복 1201 / 1327 | 시간 3921[s] | 퍼플렉서티 91.16
# | 에폭 4 |  반복 1221 / 1327 | 시간 3987[s] | 퍼플렉서티 89.94
# | 에폭 4 |  반복 1241 / 1327 | 시간 4051[s] | 퍼플렉서티 107.17
# | 에폭 4 |  반복 1261 / 1327 | 시간 4116[s] | 퍼플렉서티 101.92
# | 에폭 4 |  반복 1281 / 1327 | 시간 4181[s] | 퍼플렉서티 101.12
# | 에폭 4 |  반복 1301 / 1327 | 시간 4247[s] | 퍼플렉서티 129.55
# | 에폭 4 |  반복 1321 / 1327 | 시간 4313[s] | 퍼플렉서티 125.91
# 퍼플렉서티 평가 중 ...
# 209 / 210
# 검증 퍼플렉서티:  111.64671305818766
# --------------------------------------------------
# | 에폭 5 |  반복 1 / 1327 | 시간 4[s] | 퍼플렉서티 167.30
# | 에폭 5 |  반복 21 / 1327 | 시간 72[s] | 퍼플렉서티 112.54
# | 에폭 5 |  반복 41 / 1327 | 시간 138[s] | 퍼플렉서티 109.06
# | 에폭 5 |  반복 61 / 1327 | 시간 204[s] | 퍼플렉서티 106.16
# | 에폭 5 |  반복 81 / 1327 | 시간 271[s] | 퍼플렉서티 91.01
# | 에폭 5 |  반복 101 / 1327 | 시간 338[s] | 퍼플렉서티 88.89
# | 에폭 5 |  반복 121 / 1327 | 시간 403[s] | 퍼플렉서티 97.16
# | 에폭 5 |  반복 141 / 1327 | 시간 467[s] | 퍼플렉서티 106.17
# | 에폭 5 |  반복 161 / 1327 | 시간 532[s] | 퍼플렉서티 121.88
# | 에폭 5 |  반복 181 / 1327 | 시간 599[s] | 퍼플렉서티 127.64
# | 에폭 5 |  반복 201 / 1327 | 시간 666[s] | 퍼플렉서티 122.94
# | 에폭 5 |  반복 221 / 1327 | 시간 730[s] | 퍼플렉서티 119.74
# | 에폭 5 |  반복 241 / 1327 | 시간 793[s] | 퍼플렉서티 114.28
# | 에폭 5 |  반복 261 / 1327 | 시간 857[s] | 퍼플렉서티 122.52
# | 에폭 5 |  반복 281 / 1327 | 시간 922[s] | 퍼플렉서티 119.56
# | 에폭 5 |  반복 301 / 1327 | 시간 986[s] | 퍼플렉서티 101.45
# | 에폭 5 |  반복 321 / 1327 | 시간 1050[s] | 퍼플렉서티 81.46
# | 에폭 5 |  반복 341 / 1327 | 시간 1113[s] | 퍼플렉서티 115.18
# | 에폭 5 |  반복 361 / 1327 | 시간 1175[s] | 퍼플렉서티 124.11
# | 에폭 5 |  반복 381 / 1327 | 시간 1242[s] | 퍼플렉서티 97.80
# | 에폭 5 |  반복 401 / 1327 | 시간 1307[s] | 퍼플렉서티 113.06
# | 에폭 5 |  반복 421 / 1327 | 시간 1371[s] | 퍼플렉서티 96.84
# | 에폭 5 |  반복 441 / 1327 | 시간 1437[s] | 퍼플렉서티 105.87
# | 에폭 5 |  반복 461 / 1327 | 시간 1502[s] | 퍼플렉서티 103.40
# | 에폭 5 |  반복 481 / 1327 | 시간 1568[s] | 퍼플렉서티 102.74
# | 에폭 5 |  반복 501 / 1327 | 시간 1633[s] | 퍼플렉서티 113.43
# | 에폭 5 |  반복 521 / 1327 | 시간 1698[s] | 퍼플렉서티 118.80
# | 에폭 5 |  반복 541 / 1327 | 시간 1763[s] | 퍼플렉서티 120.80
# | 에폭 5 |  반복 561 / 1327 | 시간 1829[s] | 퍼플렉서티 100.74
# | 에폭 5 |  반복 581 / 1327 | 시간 1894[s] | 퍼플렉서티 92.78
# | 에폭 5 |  반복 601 / 1327 | 시간 1959[s] | 퍼플렉서티 131.16
# | 에폭 5 |  반복 621 / 1327 | 시간 2021[s] | 퍼플렉서티 122.06
# | 에폭 5 |  반복 641 / 1327 | 시간 2089[s] | 퍼플렉서티 112.15
# | 에폭 5 |  반복 661 / 1327 | 시간 2153[s] | 퍼플렉서티 102.67
# | 에폭 5 |  반복 681 / 1327 | 시간 2218[s] | 퍼플렉서티 89.58
# | 에폭 5 |  반복 701 / 1327 | 시간 2284[s] | 퍼플렉서티 104.42
# | 에폭 5 |  반복 721 / 1327 | 시간 2347[s] | 퍼플렉서티 107.04
# | 에폭 5 |  반복 741 / 1327 | 시간 2412[s] | 퍼플렉서티 92.95
# | 에폭 5 |  반복 761 / 1327 | 시간 2476[s] | 퍼플렉서티 86.89
# | 에폭 5 |  반복 781 / 1327 | 시간 2542[s] | 퍼플렉서티 93.00
# | 에폭 5 |  반복 801 / 1327 | 시간 2608[s] | 퍼플렉서티 105.94
# | 에폭 5 |  반복 821 / 1327 | 시간 2676[s] | 퍼플렉서티 105.29
# | 에폭 5 |  반복 841 / 1327 | 시간 2741[s] | 퍼플렉서티 104.31
# | 에폭 5 |  반복 861 / 1327 | 시간 2807[s] | 퍼플렉서티 103.07
# | 에폭 5 |  반복 881 / 1327 | 시간 2873[s] | 퍼플렉서티 95.02
# | 에폭 5 |  반복 901 / 1327 | 시간 2940[s] | 퍼플렉서티 120.88
# | 에폭 5 |  반복 921 / 1327 | 시간 3005[s] | 퍼플렉서티 105.26
# | 에폭 5 |  반복 941 / 1327 | 시간 3071[s] | 퍼플렉서티 110.93
# | 에폭 5 |  반복 961 / 1327 | 시간 3135[s] | 퍼플렉서티 121.06
# | 에폭 5 |  반복 981 / 1327 | 시간 3198[s] | 퍼플렉서티 115.18
# | 에폭 5 |  반복 1001 / 1327 | 시간 3264[s] | 퍼플렉서티 97.70
# | 에폭 5 |  반복 1021 / 1327 | 시간 3329[s] | 퍼플렉서티 116.97
# | 에폭 5 |  반복 1041 / 1327 | 시간 3393[s] | 퍼플렉서티 101.38
# | 에폭 5 |  반복 1061 / 1327 | 시간 3459[s] | 퍼플렉서티 94.17
# | 에폭 5 |  반복 1081 / 1327 | 시간 3525[s] | 퍼플렉서티 79.29
# | 에폭 5 |  반복 1101 / 1327 | 시간 3588[s] | 퍼플렉서티 81.19
# | 에폭 5 |  반복 1121 / 1327 | 시간 3652[s] | 퍼플렉서티 109.58
# | 에폭 5 |  반복 1141 / 1327 | 시간 3714[s] | 퍼플렉서티 106.89
# | 에폭 5 |  반복 1161 / 1327 | 시간 3779[s] | 퍼플렉서티 90.36
# | 에폭 5 |  반복 1181 / 1327 | 시간 3842[s] | 퍼플렉서티 99.39
# | 에폭 5 |  반복 1201 / 1327 | 시간 3905[s] | 퍼플렉서티 82.35
# | 에폭 5 |  반복 1221 / 1327 | 시간 3968[s] | 퍼플렉서티 81.34
# | 에폭 5 |  반복 1241 / 1327 | 시간 4032[s] | 퍼플렉서티 98.86
# | 에폭 5 |  반복 1261 / 1327 | 시간 4095[s] | 퍼플렉서티 93.66
# | 에폭 5 |  반복 1281 / 1327 | 시간 4169[s] | 퍼플렉서티 93.22
# | 에폭 5 |  반복 1301 / 1327 | 시간 4248[s] | 퍼플렉서티 119.32
# | 에폭 5 |  반복 1321 / 1327 | 시간 4330[s] | 퍼플렉서티 116.29
# 퍼플렉서티 평가 중 ...
# 209 / 210
# 검증 퍼플렉서티:  105.35210265688757
# --------------------------------------------------
# | 에폭 6 |  반복 1 / 1327 | 시간 3[s] | 퍼플렉서티 159.36
# | 에폭 6 |  반복 21 / 1327 | 시간 86[s] | 퍼플렉서티 101.37
# | 에폭 6 |  반복 41 / 1327 | 시간 167[s] | 퍼플렉서티 98.98
# | 에폭 6 |  반복 61 / 1327 | 시간 247[s] | 퍼플렉서티 95.46
# | 에폭 6 |  반복 81 / 1327 | 시간 328[s] | 퍼플렉서티 83.59
# | 에폭 6 |  반복 101 / 1327 | 시간 409[s] | 퍼플렉서티 80.60
# | 에폭 6 |  반복 121 / 1327 | 시간 489[s] | 퍼플렉서티 90.27
# | 에폭 6 |  반복 141 / 1327 | 시간 571[s] | 퍼플렉서티 97.19
# | 에폭 6 |  반복 161 / 1327 | 시간 654[s] | 퍼플렉서티 110.95
# | 에폭 6 |  반복 181 / 1327 | 시간 739[s] | 퍼플렉서티 118.17
# | 에폭 6 |  반복 201 / 1327 | 시간 825[s] | 퍼플렉서티 113.95
# | 에폭 6 |  반복 221 / 1327 | 시간 907[s] | 퍼플렉서티 110.02
# | 에폭 6 |  반복 241 / 1327 | 시간 991[s] | 퍼플렉서티 105.52
# | 에폭 6 |  반복 261 / 1327 | 시간 1076[s] | 퍼플렉서티 112.19
# | 에폭 6 |  반복 281 / 1327 | 시간 1159[s] | 퍼플렉서티 110.58
# | 에폭 6 |  반복 301 / 1327 | 시간 1243[s] | 퍼플렉서티 90.38
# | 에폭 6 |  반복 321 / 1327 | 시간 1329[s] | 퍼플렉서티 72.66
# | 에폭 6 |  반복 341 / 1327 | 시간 1402[s] | 퍼플렉서티 103.78
# | 에폭 6 |  반복 361 / 1327 | 시간 1468[s] | 퍼플렉서티 111.78
# | 에폭 6 |  반복 381 / 1327 | 시간 1533[s] | 퍼플렉서티 91.91
# | 에폭 6 |  반복 401 / 1327 | 시간 1599[s] | 퍼플렉서티 104.19
# | 에폭 6 |  반복 421 / 1327 | 시간 1664[s] | 퍼플렉서티 88.08
# | 에폭 6 |  반복 441 / 1327 | 시간 1729[s] | 퍼플렉서티 97.84
# | 에폭 6 |  반복 461 / 1327 | 시간 1793[s] | 퍼플렉서티 96.63
# | 에폭 6 |  반복 481 / 1327 | 시간 1860[s] | 퍼플렉서티 93.31
# | 에폭 6 |  반복 501 / 1327 | 시간 1925[s] | 퍼플렉서티 104.76
# | 에폭 6 |  반복 521 / 1327 | 시간 1991[s] | 퍼플렉서티 108.00
# | 에폭 6 |  반복 541 / 1327 | 시간 2056[s] | 퍼플렉서티 109.68
# | 에폭 6 |  반복 561 / 1327 | 시간 2123[s] | 퍼플렉서티 92.42
# | 에폭 6 |  반복 581 / 1327 | 시간 2188[s] | 퍼플렉서티 85.54
# | 에폭 6 |  반복 601 / 1327 | 시간 2254[s] | 퍼플렉서티 120.11
# | 에폭 6 |  반복 621 / 1327 | 시간 2319[s] | 퍼플렉서티 113.37
# | 에폭 6 |  반복 641 / 1327 | 시간 2384[s] | 퍼플렉서티 102.94
# | 에폭 6 |  반복 661 / 1327 | 시간 2447[s] | 퍼플렉서티 94.25
# | 에폭 6 |  반복 681 / 1327 | 시간 2512[s] | 퍼플렉서티 81.65
# | 에폭 6 |  반복 701 / 1327 | 시간 2576[s] | 퍼플렉서티 96.80
# | 에폭 6 |  반복 721 / 1327 | 시간 2641[s] | 퍼플렉서티 98.38
# | 에폭 6 |  반복 741 / 1327 | 시간 2705[s] | 퍼플렉서티 86.20
# | 에폭 6 |  반복 761 / 1327 | 시간 2767[s] | 퍼플렉서티 77.59
# | 에폭 6 |  반복 781 / 1327 | 시간 2835[s] | 퍼플렉서티 86.67
# | 에폭 6 |  반복 801 / 1327 | 시간 2897[s] | 퍼플렉서티 98.96
# | 에폭 6 |  반복 821 / 1327 | 시간 2963[s] | 퍼플렉서티 96.84
# | 에폭 6 |  반복 841 / 1327 | 시간 3029[s] | 퍼플렉서티 96.57
# | 에폭 6 |  반복 861 / 1327 | 시간 3097[s] | 퍼플렉서티 94.68
# | 에폭 6 |  반복 881 / 1327 | 시간 3162[s] | 퍼플렉서티 87.05
# | 에폭 6 |  반복 901 / 1327 | 시간 3227[s] | 퍼플렉서티 111.11
# | 에폭 6 |  반복 921 / 1327 | 시간 3292[s] | 퍼플렉서티 97.86
# | 에폭 6 |  반복 941 / 1327 | 시간 3359[s] | 퍼플렉서티 103.55
# | 에폭 6 |  반복 961 / 1327 | 시간 3424[s] | 퍼플렉서티 113.33
# | 에폭 6 |  반복 981 / 1327 | 시간 3490[s] | 퍼플렉서티 105.20
# | 에폭 6 |  반복 1001 / 1327 | 시간 3555[s] | 퍼플렉서티 91.62
# | 에폭 6 |  반복 1021 / 1327 | 시간 3621[s] | 퍼플렉서티 108.16
# | 에폭 6 |  반복 1041 / 1327 | 시간 3685[s] | 퍼플렉서티 93.39
# | 에폭 6 |  반복 1061 / 1327 | 시간 3751[s] | 퍼플렉서티 87.72
# | 에폭 6 |  반복 1081 / 1327 | 시간 3819[s] | 퍼플렉서티 73.08
# | 에폭 6 |  반복 1101 / 1327 | 시간 3883[s] | 퍼플렉서티 75.65
# | 에폭 6 |  반복 1121 / 1327 | 시간 3948[s] | 퍼플렉서티 102.44
# | 에폭 6 |  반복 1141 / 1327 | 시간 4013[s] | 퍼플렉서티 98.59
# | 에폭 6 |  반복 1161 / 1327 | 시간 4078[s] | 퍼플렉서티 82.59
# | 에폭 6 |  반복 1181 / 1327 | 시간 4144[s] | 퍼플렉서티 91.35
# | 에폭 6 |  반복 1201 / 1327 | 시간 4206[s] | 퍼플렉서티 75.58
# | 에폭 6 |  반복 1221 / 1327 | 시간 4271[s] | 퍼플렉서티 76.92
# | 에폭 6 |  반복 1241 / 1327 | 시간 4336[s] | 퍼플렉서티 91.12
# | 에폭 6 |  반복 1261 / 1327 | 시간 4401[s] | 퍼플렉서티 85.09
# | 에폭 6 |  반복 1281 / 1327 | 시간 4466[s] | 퍼플렉서티 85.78
# | 에폭 6 |  반복 1301 / 1327 | 시간 4530[s] | 퍼플렉서티 108.54
# | 에폭 6 |  반복 1321 / 1327 | 시간 4596[s] | 퍼플렉서티 107.15
# 퍼플렉서티 평가 중 ...
# 209 / 210
# 검증 퍼플렉서티:  99.57912841402295
# --------------------------------------------------
# | 에폭 7 |  반복 1 / 1327 | 시간 2[s] | 퍼플렉서티 155.15
# | 에폭 7 |  반복 21 / 1327 | 시간 67[s] | 퍼플렉서티 95.14
# | 에폭 7 |  반복 41 / 1327 | 시간 132[s] | 퍼플렉서티 92.40
# | 에폭 7 |  반복 61 / 1327 | 시간 197[s] | 퍼플렉서티 89.86
# | 에폭 7 |  반복 81 / 1327 | 시간 262[s] | 퍼플렉서티 78.77
# | 에폭 7 |  반복 101 / 1327 | 시간 327[s] | 퍼플렉서티 74.91
# | 에폭 7 |  반복 121 / 1327 | 시간 391[s] | 퍼플렉서티 83.12
# | 에폭 7 |  반복 141 / 1327 | 시간 456[s] | 퍼플렉서티 89.09
# | 에폭 7 |  반복 161 / 1327 | 시간 522[s] | 퍼플렉서티 102.91
# | 에폭 7 |  반복 181 / 1327 | 시간 588[s] | 퍼플렉서티 110.22
# | 에폭 7 |  반복 201 / 1327 | 시간 651[s] | 퍼플렉서티 105.52
# | 에폭 7 |  반복 221 / 1327 | 시간 716[s] | 퍼플렉서티 102.89
# | 에폭 7 |  반복 241 / 1327 | 시간 779[s] | 퍼플렉서티 97.64
# | 에폭 7 |  반복 261 / 1327 | 시간 843[s] | 퍼플렉서티 105.10
# | 에폭 7 |  반복 281 / 1327 | 시간 906[s] | 퍼플렉서티 102.79
# | 에폭 7 |  반복 301 / 1327 | 시간 972[s] | 퍼플렉서티 85.90
# | 에폭 7 |  반복 321 / 1327 | 시간 1035[s] | 퍼플렉서티 69.12
# | 에폭 7 |  반복 341 / 1327 | 시간 1100[s] | 퍼플렉서티 98.12
# | 에폭 7 |  반복 361 / 1327 | 시간 1165[s] | 퍼플렉서티 102.46
# | 에폭 7 |  반복 381 / 1327 | 시간 1229[s] | 퍼플렉서티 84.79
# | 에폭 7 |  반복 401 / 1327 | 시간 1291[s] | 퍼플렉서티 96.75
# | 에폭 7 |  반복 421 / 1327 | 시간 1355[s] | 퍼플렉서티 82.64
# | 에폭 7 |  반복 441 / 1327 | 시간 1420[s] | 퍼플렉서티 90.01
# | 에폭 7 |  반복 461 / 1327 | 시간 1484[s] | 퍼플렉서티 88.71
# | 에폭 7 |  반복 481 / 1327 | 시간 1548[s] | 퍼플렉서티 88.48
# | 에폭 7 |  반복 501 / 1327 | 시간 1612[s] | 퍼플렉서티 97.43
# | 에폭 7 |  반복 521 / 1327 | 시간 1679[s] | 퍼플렉서티 101.03
# | 에폭 7 |  반복 541 / 1327 | 시간 1742[s] | 퍼플렉서티 103.33
# | 에폭 7 |  반복 561 / 1327 | 시간 1805[s] | 퍼플렉서티 85.63
# | 에폭 7 |  반복 581 / 1327 | 시간 1870[s] | 퍼플렉서티 79.10
# | 에폭 7 |  반복 601 / 1327 | 시간 1934[s] | 퍼플렉서티 112.54
# | 에폭 7 |  반복 621 / 1327 | 시간 1998[s] | 퍼플렉서티 104.48
# | 에폭 7 |  반복 641 / 1327 | 시간 2062[s] | 퍼플렉서티 95.91
# | 에폭 7 |  반복 661 / 1327 | 시간 2127[s] | 퍼플렉서티 88.05
# | 에폭 7 |  반복 681 / 1327 | 시간 2191[s] | 퍼플렉서티 77.68
# | 에폭 7 |  반복 701 / 1327 | 시간 2252[s] | 퍼플렉서티 91.04
# | 에폭 7 |  반복 721 / 1327 | 시간 2316[s] | 퍼플렉서티 91.47
# | 에폭 7 |  반복 741 / 1327 | 시간 2382[s] | 퍼플렉서티 79.87
# | 에폭 7 |  반복 761 / 1327 | 시간 2447[s] | 퍼플렉서티 73.69
# | 에폭 7 |  반복 781 / 1327 | 시간 2511[s] | 퍼플렉서티 81.06
# | 에폭 7 |  반복 801 / 1327 | 시간 2578[s] | 퍼플렉서티 93.04
# | 에폭 7 |  반복 821 / 1327 | 시간 2642[s] | 퍼플렉서티 90.96
# | 에폭 7 |  반복 841 / 1327 | 시간 2706[s] | 퍼플렉서티 90.05
# | 에폭 7 |  반복 861 / 1327 | 시간 2770[s] | 퍼플렉서티 88.99
# | 에폭 7 |  반복 881 / 1327 | 시간 2835[s] | 퍼플렉서티 81.15
# | 에폭 7 |  반복 901 / 1327 | 시간 2898[s] | 퍼플렉서티 104.53
# | 에폭 7 |  반복 921 / 1327 | 시간 2962[s] | 퍼플렉서티 91.63
# | 에폭 7 |  반복 941 / 1327 | 시간 3026[s] | 퍼플렉서티 97.61
# | 에폭 7 |  반복 961 / 1327 | 시간 3092[s] | 퍼플렉서티 106.24
# | 에폭 7 |  반복 981 / 1327 | 시간 3157[s] | 퍼플렉서티 100.68
# | 에폭 7 |  반복 1001 / 1327 | 시간 3222[s] | 퍼플렉서티 86.54
# | 에폭 7 |  반복 1021 / 1327 | 시간 3287[s] | 퍼플렉서티 101.81
# | 에폭 7 |  반복 1041 / 1327 | 시간 3349[s] | 퍼플렉서티 87.90
# | 에폭 7 |  반복 1061 / 1327 | 시간 3413[s] | 퍼플렉서티 82.94
# | 에폭 7 |  반복 1081 / 1327 | 시간 3476[s] | 퍼플렉서티 69.10
# | 에폭 7 |  반복 1101 / 1327 | 시간 3541[s] | 퍼플렉서티 68.94
# | 에폭 7 |  반복 1121 / 1327 | 시간 3606[s] | 퍼플렉서티 96.14
# | 에폭 7 |  반복 1141 / 1327 | 시간 3672[s] | 퍼플렉서티 92.36
# | 에폭 7 |  반복 1161 / 1327 | 시간 3736[s] | 퍼플렉서티 78.50
# | 에폭 7 |  반복 1181 / 1327 | 시간 3802[s] | 퍼플렉서티 85.78
# | 에폭 7 |  반복 1201 / 1327 | 시간 3864[s] | 퍼플렉서티 70.76
# | 에폭 7 |  반복 1221 / 1327 | 시간 3929[s] | 퍼플렉서티 72.00
# | 에폭 7 |  반복 1241 / 1327 | 시간 3996[s] | 퍼플렉서티 85.32
# | 에폭 7 |  반복 1261 / 1327 | 시간 4060[s] | 퍼플렉서티 80.57
# | 에폭 7 |  반복 1281 / 1327 | 시간 4125[s] | 퍼플렉서티 81.45
# | 에폭 7 |  반복 1301 / 1327 | 시간 4188[s] | 퍼플렉서티 102.22
# | 에폭 7 |  반복 1321 / 1327 | 시간 4255[s] | 퍼플렉서티 100.85
# 퍼플렉서티 평가 중 ...
# 209 / 210
# 검증 퍼플렉서티:  96.50784295658474
# --------------------------------------------------
# | 에폭 8 |  반복 1 / 1327 | 시간 4[s] | 퍼플렉서티 138.40
# | 에폭 8 |  반복 21 / 1327 | 시간 69[s] | 퍼플렉서티 89.95
# | 에폭 8 |  반복 41 / 1327 | 시간 133[s] | 퍼플렉서티 87.36
# | 에폭 8 |  반복 61 / 1327 | 시간 197[s] | 퍼플렉서티 85.26
# | 에폭 8 |  반복 81 / 1327 | 시간 262[s] | 퍼플렉서티 71.86
# | 에폭 8 |  반복 101 / 1327 | 시간 328[s] | 퍼플렉서티 70.99
# | 에폭 8 |  반복 121 / 1327 | 시간 394[s] | 퍼플렉서티 78.01
# | 에폭 8 |  반복 141 / 1327 | 시간 459[s] | 퍼플렉서티 82.87
# | 에폭 8 |  반복 161 / 1327 | 시간 523[s] | 퍼플렉서티 97.27
# | 에폭 8 |  반복 181 / 1327 | 시간 588[s] | 퍼플렉서티 103.12
# | 에폭 8 |  반복 201 / 1327 | 시간 652[s] | 퍼플렉서티 100.37
# | 에폭 8 |  반복 221 / 1327 | 시간 714[s] | 퍼플렉서티 96.68
# | 에폭 8 |  반복 241 / 1327 | 시간 779[s] | 퍼플렉서티 91.19
# | 에폭 8 |  반복 261 / 1327 | 시간 843[s] | 퍼플렉서티 96.94
# | 에폭 8 |  반복 281 / 1327 | 시간 907[s] | 퍼플렉서티 96.84
# | 에폭 8 |  반복 301 / 1327 | 시간 970[s] | 퍼플렉서티 80.27
# | 에폭 8 |  반복 321 / 1327 | 시간 1036[s] | 퍼플렉서티 64.78
# | 에폭 8 |  반복 341 / 1327 | 시간 1099[s] | 퍼플렉서티 92.96
# | 에폭 8 |  반복 361 / 1327 | 시간 1161[s] | 퍼플렉서티 96.62
# | 에폭 8 |  반복 381 / 1327 | 시간 1225[s] | 퍼플렉서티 81.19
# | 에폭 8 |  반복 401 / 1327 | 시간 1289[s] | 퍼플렉서티 90.68
# | 에폭 8 |  반복 421 / 1327 | 시간 1355[s] | 퍼플렉서티 78.77
# | 에폭 8 |  반복 441 / 1327 | 시간 1419[s] | 퍼플렉서티 84.96
# | 에폭 8 |  반복 461 / 1327 | 시간 1482[s] | 퍼플렉서티 84.25
# | 에폭 8 |  반복 481 / 1327 | 시간 1546[s] | 퍼플렉서티 82.61
# | 에폭 8 |  반복 501 / 1327 | 시간 1611[s] | 퍼플렉서티 92.97
# | 에폭 8 |  반복 521 / 1327 | 시간 1673[s] | 퍼플렉서티 96.92
# | 에폭 8 |  반복 541 / 1327 | 시간 1737[s] | 퍼플렉서티 97.55
# | 에폭 8 |  반복 561 / 1327 | 시간 1801[s] | 퍼플렉서티 81.02
# | 에폭 8 |  반복 581 / 1327 | 시간 1867[s] | 퍼플렉서티 74.75
# | 에폭 8 |  반복 601 / 1327 | 시간 1930[s] | 퍼플렉서티 105.82
# | 에폭 8 |  반복 621 / 1327 | 시간 1994[s] | 퍼플렉서티 99.67
# | 에폭 8 |  반복 641 / 1327 | 시간 2055[s] | 퍼플렉서티 89.78
# | 에폭 8 |  반복 661 / 1327 | 시간 2121[s] | 퍼플렉서티 84.96
# | 에폭 8 |  반복 681 / 1327 | 시간 2184[s] | 퍼플렉서티 73.19
# | 에폭 8 |  반복 701 / 1327 | 시간 2248[s] | 퍼플렉서티 85.42
# | 에폭 8 |  반복 721 / 1327 | 시간 2312[s] | 퍼플렉서티 86.86
# | 에폭 8 |  반복 741 / 1327 | 시간 2376[s] | 퍼플렉서티 76.58
# | 에폭 8 |  반복 761 / 1327 | 시간 2438[s] | 퍼플렉서티 69.76
# | 에폭 8 |  반복 781 / 1327 | 시간 2502[s] | 퍼플렉서티 75.85
# | 에폭 8 |  반복 801 / 1327 | 시간 2566[s] | 퍼플렉서티 87.70
# | 에폭 8 |  반복 821 / 1327 | 시간 2632[s] | 퍼플렉서티 86.10
# | 에폭 8 |  반복 841 / 1327 | 시간 2696[s] | 퍼플렉서티 85.54
