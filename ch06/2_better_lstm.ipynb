# %% [markdown]
# Click this button to run in Colab.
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ssuai/deep_learning_from_scratch_2/blob/master/ch06/2_better_lstm.ipynb)

# %%
# some helper functions for Colab
def is_colab():
    try:
        import google.colab
        return True
    except ImportError:
        return False    
if is_colab():
    # !git clone --filter=blob:none --sparse https://github.com/ssuai/deep_learning_from_scratch_2.git
    # %cd deep_learning_from_scratch_2
    # !git sparse-checkout set dataset common ch06
else:        
    import sys
    import os
#     sys.path.append('..')
    sys.path.append(os.pardir)  # 부모 디렉터리의 파일을 가져올 수 있도록 설정

# %%
# %load better_rnnlm.py
# import sys
# sys.path.append('..')
from common.time_layers import *
from common.np import *  # import numpy as np
from common.base_model import BaseModel


class BetterRnnlm(BaseModel):
    '''
     LSTM 계층을 2개 사용하고 각 층에 드롭아웃을 적용한 모델이다.
     아래 [1]에서 제안한 모델을 기초로 하였고, [2]와 [3]의 가중치 공유(weight tying)를 적용했다.

     [1] Recurrent Neural Network Regularization (https://arxiv.org/abs/1409.2329)
     [2] Using the Output Embedding to Improve Language Models (https://arxiv.org/abs/1608.05859)
     [3] Tying Word Vectors and Word Classifiers (https://arxiv.org/pdf/1611.01462.pdf)
    '''
    def __init__(self, vocab_size=10000, wordvec_size=650,
                 hidden_size=650, dropout_ratio=0.5):
        V, D, H = vocab_size, wordvec_size, hidden_size
        rn = np.random.randn

        embed_W = (rn(V, D) / 100).astype('f')
        lstm_Wx1 = (rn(D, 4 * H) / np.sqrt(D)).astype('f')
        lstm_Wh1 = (rn(H, 4 * H) / np.sqrt(H)).astype('f')
        lstm_b1 = np.zeros(4 * H).astype('f')
        lstm_Wx2 = (rn(H, 4 * H) / np.sqrt(H)).astype('f')
        lstm_Wh2 = (rn(H, 4 * H) / np.sqrt(H)).astype('f')
        lstm_b2 = np.zeros(4 * H).astype('f')
        affine_b = np.zeros(V).astype('f')

        self.layers = [
            TimeEmbedding(embed_W),
            TimeDropout(dropout_ratio),
            TimeLSTM(lstm_Wx1, lstm_Wh1, lstm_b1, stateful=True),
            TimeDropout(dropout_ratio),
            TimeLSTM(lstm_Wx2, lstm_Wh2, lstm_b2, stateful=True),
            TimeDropout(dropout_ratio),
            TimeAffine(embed_W.T, affine_b)  # weight tying!!
        ]
        self.loss_layer = TimeSoftmaxWithLoss()
        self.lstm_layers = [self.layers[2], self.layers[4]]
        self.drop_layers = [self.layers[1], self.layers[3], self.layers[5]]

        self.params, self.grads = [], []
        for layer in self.layers:
            self.params += layer.params
            self.grads += layer.grads

    def predict(self, xs, train_flg=False):
        for layer in self.drop_layers:
            layer.train_flg = train_flg

        for layer in self.layers:
            xs = layer.forward(xs)
        return xs

    def forward(self, xs, ts, train_flg=True):
        score = self.predict(xs, train_flg)
        loss = self.loss_layer.forward(score, ts)
        return loss

    def backward(self, dout=1):
        dout = self.loss_layer.backward(dout)
        for layer in reversed(self.layers):
            dout = layer.backward(dout)
        return dout

    def reset_state(self):
        for layer in self.lstm_layers:
            layer.reset_state()

# %%
# %load train_better_rnnlm.py
import sys
sys.path.append('..')
from common import config
# GPU에서 실행하려면 아래 주석을 해제하세요(CuPy 필요).
# ==============================================
config.GPU = True
# ==============================================
from common.optimizer import SGD
from common.trainer import RnnlmTrainer
from common.util import eval_perplexity, to_gpu
from dataset import ptb
# from better_rnnlm import BetterRnnlm # defined above


# 하이퍼파라미터 설정
batch_size = 20
wordvec_size = 650
hidden_size = 650
time_size = 35
lr = 20.0
max_epoch = 40
max_grad = 0.25
dropout = 0.5

# 학습 데이터 읽기
corpus, word_to_id, id_to_word = ptb.load_data('train')
corpus_val, _, _ = ptb.load_data('val')
corpus_test, _, _ = ptb.load_data('test')

if config.GPU:
    corpus = to_gpu(corpus)
    corpus_val = to_gpu(corpus_val)
    corpus_test = to_gpu(corpus_test)

vocab_size = len(word_to_id)
xs = corpus[:-1]
ts = corpus[1:]

model = BetterRnnlm(vocab_size, wordvec_size, hidden_size, dropout)
optimizer = SGD(lr)
trainer = RnnlmTrainer(model, optimizer)

best_ppl = float('inf')
for epoch in range(max_epoch):
    trainer.fit(xs, ts, max_epoch=1, batch_size=batch_size,
                time_size=time_size, max_grad=max_grad)

    model.reset_state()
    ppl = eval_perplexity(model, corpus_val)
    print('검증 퍼플렉서티: ', ppl)

    if best_ppl > ppl:
        best_ppl = ppl
        model.save_params()
    else:
        lr /= 4.0
        optimizer.lr = lr

    model.reset_state()
    print('-' * 50)
# Out:
# | 에폭 1 |  반복 1 / 1327 | 시간 1[s] | 퍼플렉서티 10000.35
# | 에폭 1 |  반복 21 / 1327 | 시간 28[s] | 퍼플렉서티 3767.70
# | 에폭 1 |  반복 41 / 1327 | 시간 54[s] | 퍼플렉서티 1835.76
# | 에폭 1 |  반복 61 / 1327 | 시간 81[s] | 퍼플렉서티 1293.38
# | 에폭 1 |  반복 81 / 1327 | 시간 108[s] | 퍼플렉서티 1023.10
# | 에폭 1 |  반복 101 / 1327 | 시간 134[s] | 퍼플렉서티 889.02
# | 에폭 1 |  반복 121 / 1327 | 시간 161[s] | 퍼플렉서티 835.59
# | 에폭 1 |  반복 141 / 1327 | 시간 187[s] | 퍼플렉서티 754.81
# | 에폭 1 |  반복 161 / 1327 | 시간 214[s] | 퍼플렉서티 698.76
# | 에폭 1 |  반복 181 / 1327 | 시간 241[s] | 퍼플렉서티 710.93
# | 에폭 1 |  반복 201 / 1327 | 시간 267[s] | 퍼플렉서티 590.86
# | 에폭 1 |  반복 221 / 1327 | 시간 294[s] | 퍼플렉서티 583.68
# | 에폭 1 |  반복 241 / 1327 | 시간 320[s] | 퍼플렉서티 515.82
# | 에폭 1 |  반복 261 / 1327 | 시간 347[s] | 퍼플렉서티 544.08
# | 에폭 1 |  반복 281 / 1327 | 시간 374[s] | 퍼플렉서티 529.21
# | 에폭 1 |  반복 301 / 1327 | 시간 401[s] | 퍼플렉서티 456.03
# | 에폭 1 |  반복 321 / 1327 | 시간 428[s] | 퍼플렉서티 404.55
# | 에폭 1 |  반복 341 / 1327 | 시간 455[s] | 퍼플렉서티 454.37
# | 에폭 1 |  반복 361 / 1327 | 시간 482[s] | 퍼플렉서티 476.87
# | 에폭 1 |  반복 381 / 1327 | 시간 508[s] | 퍼플렉서티 389.76
# | 에폭 1 |  반복 401 / 1327 | 시간 535[s] | 퍼플렉서티 408.73
# | 에폭 1 |  반복 421 / 1327 | 시간 561[s] | 퍼플렉서티 404.20
# | 에폭 1 |  반복 441 / 1327 | 시간 588[s] | 퍼플렉서티 383.60
# | 에폭 1 |  반복 461 / 1327 | 시간 614[s] | 퍼플렉서티 374.13
# | 에폭 1 |  반복 481 / 1327 | 시간 641[s] | 퍼플렉서티 350.29
# | 에폭 1 |  반복 501 / 1327 | 시간 668[s] | 퍼플렉서티 355.78
# | 에폭 1 |  반복 521 / 1327 | 시간 695[s] | 퍼플렉서티 344.13
# | 에폭 1 |  반복 541 / 1327 | 시간 722[s] | 퍼플렉서티 365.77
# | 에폭 1 |  반복 561 / 1327 | 시간 749[s] | 퍼플렉서티 325.21
# | 에폭 1 |  반복 581 / 1327 | 시간 775[s] | 퍼플렉서티 296.37
# | 에폭 1 |  반복 601 / 1327 | 시간 802[s] | 퍼플렉서티 379.10
# | 에폭 1 |  반복 621 / 1327 | 시간 829[s] | 퍼플렉서티 351.12
# | 에폭 1 |  반복 641 / 1327 | 시간 856[s] | 퍼플렉서티 318.35
# | 에폭 1 |  반복 661 / 1327 | 시간 883[s] | 퍼플렉서티 306.55
# | 에폭 1 |  반복 681 / 1327 | 시간 910[s] | 퍼플렉서티 259.20
# | 에폭 1 |  반복 701 / 1327 | 시간 937[s] | 퍼플렉서티 283.77
# | 에폭 1 |  반복 721 / 1327 | 시간 964[s] | 퍼플렉서티 287.91
# | 에폭 1 |  반복 741 / 1327 | 시간 991[s] | 퍼플렉서티 248.03
# | 에폭 1 |  반복 761 / 1327 | 시간 1018[s] | 퍼플렉서티 261.47
# | 에폭 1 |  반복 781 / 1327 | 시간 1045[s] | 퍼플렉서티 245.48
# | 에폭 1 |  반복 801 / 1327 | 시간 1072[s] | 퍼플렉서티 274.46
# | 에폭 1 |  반복 821 / 1327 | 시간 1099[s] | 퍼플렉서티 253.89
# | 에폭 1 |  반복 841 / 1327 | 시간 1126[s] | 퍼플렉서티 258.33
# | 에폭 1 |  반복 861 / 1327 | 시간 1152[s] | 퍼플렉서티 249.35
# | 에폭 1 |  반복 881 / 1327 | 시간 1179[s] | 퍼플렉서티 233.85
# | 에폭 1 |  반복 901 / 1327 | 시간 1206[s] | 퍼플렉서티 284.02
# | 에폭 1 |  반복 921 / 1327 | 시간 1233[s] | 퍼플렉서티 255.68
# | 에폭 1 |  반복 941 / 1327 | 시간 1259[s] | 퍼플렉서티 256.13
# | 에폭 1 |  반복 961 / 1327 | 시간 1286[s] | 퍼플렉서티 275.27
# | 에폭 1 |  반복 981 / 1327 | 시간 1312[s] | 퍼플렉서티 260.08
# | 에폭 1 |  반복 1001 / 1327 | 시간 1339[s] | 퍼플렉서티 215.69
# | 에폭 1 |  반복 1021 / 1327 | 시간 1366[s] | 퍼플렉서티 254.59
# | 에폭 1 |  반복 1041 / 1327 | 시간 1392[s] | 퍼플렉서티 232.36
# | 에폭 1 |  반복 1061 / 1327 | 시간 1419[s] | 퍼플렉서티 220.67
# | 에폭 1 |  반복 1081 / 1327 | 시간 1446[s] | 퍼플렉서티 188.35
# | 에폭 1 |  반복 1101 / 1327 | 시간 1473[s] | 퍼플렉서티 216.72
# | 에폭 1 |  반복 1121 / 1327 | 시간 1499[s] | 퍼플렉서티 253.80
# | 에폭 1 |  반복 1141 / 1327 | 시간 1535[s] | 퍼플렉서티 233.27
# | 에폭 1 |  반복 1161 / 1327 | 시간 1562[s] | 퍼플렉서티 220.98
# | 에폭 1 |  반복 1181 / 1327 | 시간 1589[s] | 퍼플렉서티 213.42
# | 에폭 1 |  반복 1201 / 1327 | 시간 1616[s] | 퍼플렉서티 181.60
# | 에폭 1 |  반복 1221 / 1327 | 시간 1643[s] | 퍼플렉서티 179.73
# | 에폭 1 |  반복 1241 / 1327 | 시간 1670[s] | 퍼플렉서티 209.10
# | 에폭 1 |  반복 1261 / 1327 | 시간 1697[s] | 퍼플렉서티 192.34
# | 에폭 1 |  반복 1281 / 1327 | 시간 1724[s] | 퍼플렉서티 198.48
# | 에폭 1 |  반복 1301 / 1327 | 시간 1751[s] | 퍼플렉서티 246.94
# | 에폭 1 |  반복 1321 / 1327 | 시간 1777[s] | 퍼플렉서티 234.61
# 퍼플렉서티 평가 중 ...
# 209 / 210
# 검증 퍼플렉서티:  197.28117080929692
# --------------------------------------------------
# | 에폭 2 |  반복 1 / 1327 | 시간 1[s] | 퍼플렉서티 286.33
# | 에폭 2 |  반복 21 / 1327 | 시간 28[s] | 퍼플렉서티 229.32
# | 에폭 2 |  반복 41 / 1327 | 시간 55[s] | 퍼플렉서티 215.36
# | 에폭 2 |  반복 61 / 1327 | 시간 81[s] | 퍼플렉서티 197.00
# | 에폭 2 |  반복 81 / 1327 | 시간 108[s] | 퍼플렉서티 178.70
# | 에폭 2 |  반복 101 / 1327 | 시간 135[s] | 퍼플렉서티 169.12
# | 에폭 2 |  반복 121 / 1327 | 시간 161[s] | 퍼플렉서티 181.86
# | 에폭 2 |  반복 141 / 1327 | 시간 188[s] | 퍼플렉서티 200.65
# | 에폭 2 |  반복 161 / 1327 | 시간 215[s] | 퍼플렉서티 214.95
# | 에폭 2 |  반복 181 / 1327 | 시간 242[s] | 퍼플렉서티 225.15
# | 에폭 2 |  반복 201 / 1327 | 시간 268[s] | 퍼플렉서티 206.12
# | 에폭 2 |  반복 221 / 1327 | 시간 295[s] | 퍼플렉서티 204.47
# | 에폭 2 |  반복 241 / 1327 | 시간 321[s] | 퍼플렉서티 196.72
# | 에폭 2 |  반복 261 / 1327 | 시간 348[s] | 퍼플렉서티 213.09
# | 에폭 2 |  반복 281 / 1327 | 시간 375[s] | 퍼플렉서티 207.47
# | 에폭 2 |  반복 301 / 1327 | 시간 402[s] | 퍼플렉서티 187.57
# | 에폭 2 |  반복 321 / 1327 | 시간 429[s] | 퍼플렉서티 156.82
# | 에폭 2 |  반복 341 / 1327 | 시간 456[s] | 퍼플렉서티 200.73
# | 에폭 2 |  반복 361 / 1327 | 시간 483[s] | 퍼플렉서티 215.61
# | 에폭 2 |  반복 381 / 1327 | 시간 511[s] | 퍼플렉서티 171.61
# | 에폭 2 |  반복 401 / 1327 | 시간 538[s] | 퍼플렉서티 194.90
# | 에폭 2 |  반복 421 / 1327 | 시간 564[s] | 퍼플렉서티 178.06
# | 에폭 2 |  반복 441 / 1327 | 시간 591[s] | 퍼플렉서티 180.16
# | 에폭 2 |  반복 461 / 1327 | 시간 617[s] | 퍼플렉서티 184.93
# | 에폭 2 |  반복 481 / 1327 | 시간 644[s] | 퍼플렉서티 172.60
# | 에폭 2 |  반복 501 / 1327 | 시간 671[s] | 퍼플렉서티 190.40
# | 에폭 2 |  반복 521 / 1327 | 시간 698[s] | 퍼플렉서티 191.13
# | 에폭 2 |  반복 541 / 1327 | 시간 724[s] | 퍼플렉서티 202.55
# | 에폭 2 |  반복 561 / 1327 | 시간 751[s] | 퍼플렉서티 174.04
# | 에폭 2 |  반복 581 / 1327 | 시간 778[s] | 퍼플렉서티 158.81
# | 에폭 2 |  반복 601 / 1327 | 시간 805[s] | 퍼플렉서티 217.14
# | 에폭 2 |  반복 621 / 1327 | 시간 831[s] | 퍼플렉서티 199.49
# | 에폭 2 |  반복 641 / 1327 | 시간 858[s] | 퍼플렉서티 184.47
# | 에폭 2 |  반복 661 / 1327 | 시간 885[s] | 퍼플렉서티 172.08
# | 에폭 2 |  반복 681 / 1327 | 시간 911[s] | 퍼플렉서티 148.80
# | 에폭 2 |  반복 701 / 1327 | 시간 938[s] | 퍼플렉서티 169.82
# | 에폭 2 |  반복 721 / 1327 | 시간 964[s] | 퍼플렉서티 176.80
# | 에폭 2 |  반복 741 / 1327 | 시간 991[s] | 퍼플렉서티 150.94
# | 에폭 2 |  반복 761 / 1327 | 시간 1018[s] | 퍼플렉서티 151.68
# | 에폭 2 |  반복 781 / 1327 | 시간 1045[s] | 퍼플렉서티 150.28
# | 에폭 2 |  반복 801 / 1327 | 시간 1071[s] | 퍼플렉서티 172.15
# | 에폭 2 |  반복 821 / 1327 | 시간 1099[s] | 퍼플렉서티 163.25
# | 에폭 2 |  반복 841 / 1327 | 시간 1126[s] | 퍼플렉서티 165.79
# | 에폭 2 |  반복 861 / 1327 | 시간 1153[s] | 퍼플렉서티 160.33
# | 에폭 2 |  반복 881 / 1327 | 시간 1180[s] | 퍼플렉서티 149.16
# | 에폭 2 |  반복 901 / 1327 | 시간 1207[s] | 퍼플렉서티 188.91
# | 에폭 2 |  반복 921 / 1327 | 시간 1234[s] | 퍼플렉서티 167.51
# | 에폭 2 |  반복 941 / 1327 | 시간 1261[s] | 퍼플렉서티 170.95
# | 에폭 2 |  반복 961 / 1327 | 시간 1288[s] | 퍼플렉서티 185.87
# | 에폭 2 |  반복 981 / 1327 | 시간 1315[s] | 퍼플렉서티 174.51
# | 에폭 2 |  반복 1001 / 1327 | 시간 1342[s] | 퍼플렉서티 149.32
# | 에폭 2 |  반복 1021 / 1327 | 시간 1369[s] | 퍼플렉서티 175.81
# | 에폭 2 |  반복 1041 / 1327 | 시간 1396[s] | 퍼플렉서티 158.30
# | 에폭 2 |  반복 1061 / 1327 | 시간 1422[s] | 퍼플렉서티 148.09
# | 에폭 2 |  반복 1081 / 1327 | 시간 1449[s] | 퍼플렉서티 123.40
# | 에폭 2 |  반복 1101 / 1327 | 시간 1475[s] | 퍼플렉서티 138.38
# | 에폭 2 |  반복 1121 / 1327 | 시간 1502[s] | 퍼플렉서티 173.38
# | 에폭 2 |  반복 1141 / 1327 | 시간 1528[s] | 퍼플렉서티 162.58
# | 에폭 2 |  반복 1161 / 1327 | 시간 1555[s] | 퍼플렉서티 147.48
# | 에폭 2 |  반복 1181 / 1327 | 시간 1581[s] | 퍼플렉서티 147.67
# | 에폭 2 |  반복 1201 / 1327 | 시간 1608[s] | 퍼플렉서티 127.23
# | 에폭 2 |  반복 1221 / 1327 | 시간 1635[s] | 퍼플렉서티 126.07
# | 에폭 2 |  반복 1241 / 1327 | 시간 1661[s] | 퍼플렉서티 147.54
# | 에폭 2 |  반복 1261 / 1327 | 시간 1688[s] | 퍼플렉서티 137.87
# | 에폭 2 |  반복 1281 / 1327 | 시간 1715[s] | 퍼플렉서티 140.32
# | 에폭 2 |  반복 1301 / 1327 | 시간 1742[s] | 퍼플렉서티 179.45
# | 에폭 2 |  반복 1321 / 1327 | 시간 1769[s] | 퍼플렉서티 171.99
# 퍼플렉서티 평가 중 ...
# 209 / 210
# 검증 퍼플렉서티:  146.82205293553278
# --------------------------------------------------
# | 에폭 3 |  반복 1 / 1327 | 시간 1[s] | 퍼플렉서티 218.78
# | 에폭 3 |  반복 21 / 1327 | 시간 28[s] | 퍼플렉서티 161.22
# | 에폭 3 |  반복 41 / 1327 | 시간 56[s] | 퍼플렉서티 152.72
# | 에폭 3 |  반복 61 / 1327 | 시간 83[s] | 퍼플렉서티 141.97
# | 에폭 3 |  반복 81 / 1327 | 시간 110[s] | 퍼플렉서티 126.98
# | 에폭 3 |  반복 101 / 1327 | 시간 138[s] | 퍼플렉서티 121.79
# | 에폭 3 |  반복 121 / 1327 | 시간 165[s] | 퍼플렉서티 134.41
# | 에폭 3 |  반복 141 / 1327 | 시간 192[s] | 퍼플렉서티 147.71
# | 에폭 3 |  반복 161 / 1327 | 시간 220[s] | 퍼플렉서티 161.29
# | 에폭 3 |  반복 181 / 1327 | 시간 247[s] | 퍼플렉서티 167.81
# | 에폭 3 |  반복 201 / 1327 | 시간 275[s] | 퍼플렉서티 159.18
# | 에폭 3 |  반복 221 / 1327 | 시간 302[s] | 퍼플렉서티 156.94
# | 에폭 3 |  반복 241 / 1327 | 시간 329[s] | 퍼플렉서티 150.07
# | 에폭 3 |  반복 261 / 1327 | 시간 356[s] | 퍼플렉서티 162.65
# | 에폭 3 |  반복 281 / 1327 | 시간 383[s] | 퍼플렉서티 157.23
# | 에폭 3 |  반복 301 / 1327 | 시간 410[s] | 퍼플렉서티 140.36
# | 에폭 3 |  반복 321 / 1327 | 시간 438[s] | 퍼플렉서티 112.47
# | 에폭 3 |  반복 341 / 1327 | 시간 465[s] | 퍼플렉서티 151.65
# | 에폭 3 |  반복 361 / 1327 | 시간 492[s] | 퍼플렉서티 165.31
# | 에폭 3 |  반복 381 / 1327 | 시간 519[s] | 퍼플렉서티 129.62
# | 에폭 3 |  반복 401 / 1327 | 시간 546[s] | 퍼플렉서티 149.71
# | 에폭 3 |  반복 421 / 1327 | 시간 573[s] | 퍼플렉서티 130.36
# | 에폭 3 |  반복 441 / 1327 | 시간 600[s] | 퍼플렉서티 139.27
# | 에폭 3 |  반복 461 / 1327 | 시간 627[s] | 퍼플렉서티 138.96
# | 에폭 3 |  반복 481 / 1327 | 시간 654[s] | 퍼플렉서티 134.28
# | 에폭 3 |  반복 501 / 1327 | 시간 681[s] | 퍼플렉서티 147.50
# | 에폭 3 |  반복 521 / 1327 | 시간 708[s] | 퍼플렉서티 151.73
# | 에폭 3 |  반복 541 / 1327 | 시간 735[s] | 퍼플렉서티 158.52
# | 에폭 3 |  반복 561 / 1327 | 시간 762[s] | 퍼플렉서티 133.94
# | 에폭 3 |  반복 581 / 1327 | 시간 789[s] | 퍼플렉서티 121.77
# | 에폭 3 |  반복 601 / 1327 | 시간 816[s] | 퍼플렉서티 166.57
# | 에폭 3 |  반복 621 / 1327 | 시간 843[s] | 퍼플렉서티 160.19
# | 에폭 3 |  반복 641 / 1327 | 시간 870[s] | 퍼플렉서티 145.56
# | 에폭 3 |  반복 661 / 1327 | 시간 897[s] | 퍼플렉서티 137.46
# | 에폭 3 |  반복 681 / 1327 | 시간 924[s] | 퍼플렉서티 118.04
# | 에폭 3 |  반복 701 / 1327 | 시간 950[s] | 퍼플렉서티 136.16
# | 에폭 3 |  반복 721 / 1327 | 시간 977[s] | 퍼플렉서티 138.22
# | 에폭 3 |  반복 741 / 1327 | 시간 1004[s] | 퍼플렉서티 119.34
# | 에폭 3 |  반복 761 / 1327 | 시간 1031[s] | 퍼플렉서티 113.92
# | 에폭 3 |  반복 781 / 1327 | 시간 1058[s] | 퍼플렉서티 120.63
# | 에폭 3 |  반복 801 / 1327 | 시간 1085[s] | 퍼플렉서티 136.35
# | 에폭 3 |  반복 821 / 1327 | 시간 1111[s] | 퍼플렉서티 132.86
# | 에폭 3 |  반복 841 / 1327 | 시간 1138[s] | 퍼플렉서티 134.38
# | 에폭 3 |  반복 861 / 1327 | 시간 1165[s] | 퍼플렉서티 131.43
# | 에폭 3 |  반복 881 / 1327 | 시간 1192[s] | 퍼플렉서티 119.34
# | 에폭 3 |  반복 901 / 1327 | 시간 1219[s] | 퍼플렉서티 153.89
# | 에폭 3 |  반복 921 / 1327 | 시간 1246[s] | 퍼플렉서티 135.11
# | 에폭 3 |  반복 941 / 1327 | 시간 1273[s] | 퍼플렉서티 140.97
# | 에폭 3 |  반복 961 / 1327 | 시간 1300[s] | 퍼플렉서티 152.65
# | 에폭 3 |  반복 981 / 1327 | 시간 1327[s] | 퍼플렉서티 142.76
# | 에폭 3 |  반복 1001 / 1327 | 시간 1354[s] | 퍼플렉서티 121.89
# | 에폭 3 |  반복 1021 / 1327 | 시간 1381[s] | 퍼플렉서티 146.97
# | 에폭 3 |  반복 1041 / 1327 | 시간 1408[s] | 퍼플렉서티 129.31
# | 에폭 3 |  반복 1061 / 1327 | 시간 1435[s] | 퍼플렉서티 120.54
# | 에폭 3 |  반복 1081 / 1327 | 시간 1462[s] | 퍼플렉서티 100.81
# | 에폭 3 |  반복 1101 / 1327 | 시간 1489[s] | 퍼플렉서티 108.46
# | 에폭 3 |  반복 1121 / 1327 | 시간 1516[s] | 퍼플렉서티 140.81
# | 에폭 3 |  반복 1141 / 1327 | 시간 1543[s] | 퍼플렉서티 134.30
# | 에폭 3 |  반복 1161 / 1327 | 시간 1570[s] | 퍼플렉서티 116.51
# | 에폭 3 |  반복 1181 / 1327 | 시간 1597[s] | 퍼플렉서티 124.12
# | 에폭 3 |  반복 1201 / 1327 | 시간 1624[s] | 퍼플렉서티 103.80
# | 에폭 3 |  반복 1221 / 1327 | 시간 1650[s] | 퍼플렉서티 102.98
# | 에폭 3 |  반복 1241 / 1327 | 시간 1678[s] | 퍼플렉서티 121.95
# | 에폭 3 |  반복 1261 / 1327 | 시간 1705[s] | 퍼플렉서티 116.10
# | 에폭 3 |  반복 1281 / 1327 | 시간 1732[s] | 퍼플렉서티 116.54
# | 에폭 3 |  반복 1301 / 1327 | 시간 1758[s] | 퍼플렉서티 147.78
# | 에폭 3 |  반복 1321 / 1327 | 시간 1785[s] | 퍼플렉서티 144.58
# 퍼플렉서티 평가 중 ...
# 209 / 210
# 검증 퍼플렉서티:  124.91620212778447
# --------------------------------------------------
# | 에폭 4 |  반복 1 / 1327 | 시간 1[s] | 퍼플렉서티 192.26
# | 에폭 4 |  반복 21 / 1327 | 시간 27[s] | 퍼플렉서티 128.66
# | 에폭 4 |  반복 41 / 1327 | 시간 54[s] | 퍼플렉서티 124.32
# | 에폭 4 |  반복 61 / 1327 | 시간 81[s] | 퍼플렉서티 118.83
# | 에폭 4 |  반복 81 / 1327 | 시간 107[s] | 퍼플렉서티 105.11
# | 에폭 4 |  반복 101 / 1327 | 시간 134[s] | 퍼플렉서티 100.46
# | 에폭 4 |  반복 121 / 1327 | 시간 161[s] | 퍼플렉서티 111.03
# | 에폭 4 |  반복 141 / 1327 | 시간 188[s] | 퍼플렉서티 120.34
# | 에폭 4 |  반복 161 / 1327 | 시간 215[s] | 퍼플렉서티 135.31
# | 에폭 4 |  반복 181 / 1327 | 시간 242[s] | 퍼플렉서티 142.69
# | 에폭 4 |  반복 201 / 1327 | 시간 269[s] | 퍼플렉서티 136.68
# | 에폭 4 |  반복 221 / 1327 | 시간 296[s] | 퍼플렉서티 133.49
# | 에폭 4 |  반복 241 / 1327 | 시간 323[s] | 퍼플렉서티 127.74
# | 에폭 4 |  반복 261 / 1327 | 시간 350[s] | 퍼플렉서티 137.76
# | 에폭 4 |  반복 281 / 1327 | 시간 376[s] | 퍼플렉서티 134.76
# | 에폭 4 |  반복 301 / 1327 | 시간 403[s] | 퍼플렉서티 115.44
# | 에폭 4 |  반복 321 / 1327 | 시간 430[s] | 퍼플렉서티 91.49
# | 에폭 4 |  반복 341 / 1327 | 시간 457[s] | 퍼플렉서티 128.40
# | 에폭 4 |  반복 361 / 1327 | 시간 484[s] | 퍼플렉서티 139.56
# | 에폭 4 |  반복 381 / 1327 | 시간 511[s] | 퍼플렉서티 110.91
# | 에폭 4 |  반복 401 / 1327 | 시간 538[s] | 퍼플렉서티 126.32
# | 에폭 4 |  반복 421 / 1327 | 시간 565[s] | 퍼플렉서티 108.95
# | 에폭 4 |  반복 441 / 1327 | 시간 592[s] | 퍼플렉서티 117.40
# | 에폭 4 |  반복 461 / 1327 | 시간 618[s] | 퍼플렉서티 116.63
# | 에폭 4 |  반복 481 / 1327 | 시간 645[s] | 퍼플렉서티 113.60
# | 에폭 4 |  반복 501 / 1327 | 시간 671[s] | 퍼플렉서티 129.30
# | 에폭 4 |  반복 521 / 1327 | 시간 698[s] | 퍼플렉서티 129.59
# | 에폭 4 |  반복 541 / 1327 | 시간 725[s] | 퍼플렉서티 134.77
# | 에폭 4 |  반복 561 / 1327 | 시간 752[s] | 퍼플렉서티 113.08
# | 에폭 4 |  반복 581 / 1327 | 시간 778[s] | 퍼플렉서티 103.34
# | 에폭 4 |  반복 601 / 1327 | 시간 805[s] | 퍼플렉서티 145.80
# | 에폭 4 |  반복 621 / 1327 | 시간 831[s] | 퍼플렉서티 136.67
# | 에폭 4 |  반복 641 / 1327 | 시간 858[s] | 퍼플렉서티 125.59
# | 에폭 4 |  반복 661 / 1327 | 시간 884[s] | 퍼플렉서티 116.34
# | 에폭 4 |  반복 681 / 1327 | 시간 911[s] | 퍼플렉서티 101.28
# | 에폭 4 |  반복 701 / 1327 | 시간 938[s] | 퍼플렉서티 116.86
# | 에폭 4 |  반복 721 / 1327 | 시간 965[s] | 퍼플렉서티 120.00
# | 에폭 4 |  반복 741 / 1327 | 시간 992[s] | 퍼플렉서티 103.34
# | 에폭 4 |  반복 761 / 1327 | 시간 1018[s] | 퍼플렉서티 96.69
# | 에폭 4 |  반복 781 / 1327 | 시간 1045[s] | 퍼플렉서티 103.13
# | 에폭 4 |  반복 801 / 1327 | 시간 1073[s] | 퍼플렉서티 117.07
# | 에폭 4 |  반복 821 / 1327 | 시간 1100[s] | 퍼플렉서티 116.62
# | 에폭 4 |  반복 841 / 1327 | 시간 1127[s] | 퍼플렉서티 115.52
# | 에폭 4 |  반복 861 / 1327 | 시간 1154[s] | 퍼플렉서티 113.56
# | 에폭 4 |  반복 881 / 1327 | 시간 1181[s] | 퍼플렉서티 104.13
# | 에폭 4 |  반복 901 / 1327 | 시간 1207[s] | 퍼플렉서티 131.71
# | 에폭 4 |  반복 921 / 1327 | 시간 1234[s] | 퍼플렉서티 117.54
# | 에폭 4 |  반복 941 / 1327 | 시간 1261[s] | 퍼플렉서티 122.72
# | 에폭 4 |  반복 961 / 1327 | 시간 1288[s] | 퍼플렉서티 131.58
# | 에폭 4 |  반복 981 / 1327 | 시간 1314[s] | 퍼플렉서티 125.95
# | 에폭 4 |  반복 1001 / 1327 | 시간 1341[s] | 퍼플렉서티 106.90
# | 에폭 4 |  반복 1021 / 1327 | 시간 1368[s] | 퍼플렉서티 127.73
# | 에폭 4 |  반복 1041 / 1327 | 시간 1394[s] | 퍼플렉서티 113.48
# | 에폭 4 |  반복 1061 / 1327 | 시간 1421[s] | 퍼플렉서티 105.56
# | 에폭 4 |  반복 1081 / 1327 | 시간 1448[s] | 퍼플렉서티 87.45
# | 에폭 4 |  반복 1101 / 1327 | 시간 1475[s] | 퍼플렉서티 91.37
# | 에폭 4 |  반복 1121 / 1327 | 시간 1502[s] | 퍼플렉서티 121.27
# | 에폭 4 |  반복 1141 / 1327 | 시간 1529[s] | 퍼플렉서티 117.48
# | 에폭 4 |  반복 1161 / 1327 | 시간 1556[s] | 퍼플렉서티 100.99
# | 에폭 4 |  반복 1181 / 1327 | 시간 1583[s] | 퍼플렉서티 108.24
# | 에폭 4 |  반복 1201 / 1327 | 시간 1609[s] | 퍼플렉서티 90.32
# | 에폭 4 |  반복 1221 / 1327 | 시간 1636[s] | 퍼플렉서티 90.05
# | 에폭 4 |  반복 1241 / 1327 | 시간 1663[s] | 퍼플렉서티 106.77
# | 에폭 4 |  반복 1261 / 1327 | 시간 1690[s] | 퍼플렉서티 101.44
# | 에폭 4 |  반복 1281 / 1327 | 시간 1716[s] | 퍼플렉서티 101.90
# | 에폭 4 |  반복 1301 / 1327 | 시간 1743[s] | 퍼플렉서티 130.37
# | 에폭 4 |  반복 1321 / 1327 | 시간 1770[s] | 퍼플렉서티 128.42
# 퍼플렉서티 평가 중 ...
# 209 / 210
# 검증 퍼플렉서티:  112.33098729544339
# --------------------------------------------------
# | 에폭 5 |  반복 1 / 1327 | 시간 1[s] | 퍼플렉서티 173.60
# | 에폭 5 |  반복 21 / 1327 | 시간 28[s] | 퍼플렉서티 113.07
# | 에폭 5 |  반복 41 / 1327 | 시간 54[s] | 퍼플렉서티 107.61
# | 에폭 5 |  반복 61 / 1327 | 시간 81[s] | 퍼플렉서티 104.77
# | 에폭 5 |  반복 81 / 1327 | 시간 108[s] | 퍼플렉서티 91.21
# | 에폭 5 |  반복 101 / 1327 | 시간 135[s] | 퍼플렉서티 87.59
# | 에폭 5 |  반복 121 / 1327 | 시간 163[s] | 퍼플렉서티 96.98
# | 에폭 5 |  반복 141 / 1327 | 시간 190[s] | 퍼플렉서티 106.07
# | 에폭 5 |  반복 161 / 1327 | 시간 217[s] | 퍼플렉서티 121.46
# | 에폭 5 |  반복 181 / 1327 | 시간 244[s] | 퍼플렉서티 127.10
# | 에폭 5 |  반복 201 / 1327 | 시간 271[s] | 퍼플렉서티 123.46
# | 에폭 5 |  반복 221 / 1327 | 시간 298[s] | 퍼플렉서티 119.26
# | 에폭 5 |  반복 241 / 1327 | 시간 324[s] | 퍼플렉서티 113.94
# | 에폭 5 |  반복 261 / 1327 | 시간 352[s] | 퍼플렉서티 121.41
# | 에폭 5 |  반복 281 / 1327 | 시간 379[s] | 퍼플렉서티 118.24
# | 에폭 5 |  반복 301 / 1327 | 시간 406[s] | 퍼플렉서티 101.06
# | 에폭 5 |  반복 321 / 1327 | 시간 432[s] | 퍼플렉서티 80.87
# | 에폭 5 |  반복 341 / 1327 | 시간 459[s] | 퍼플렉서티 114.61
# | 에폭 5 |  반복 361 / 1327 | 시간 486[s] | 퍼플렉서티 122.86
# | 에폭 5 |  반복 381 / 1327 | 시간 513[s] | 퍼플렉서티 99.40
# | 에폭 5 |  반복 401 / 1327 | 시간 540[s] | 퍼플렉서티 113.99
# | 에폭 5 |  반복 421 / 1327 | 시간 567[s] | 퍼플렉서티 97.24
# | 에폭 5 |  반복 441 / 1327 | 시간 594[s] | 퍼플렉서티 106.35
# | 에폭 5 |  반복 461 / 1327 | 시간 621[s] | 퍼플렉서티 104.43
# | 에폭 5 |  반복 481 / 1327 | 시간 648[s] | 퍼플렉서티 102.26
# | 에폭 5 |  반복 501 / 1327 | 시간 675[s] | 퍼플렉서티 114.53
# | 에폭 5 |  반복 521 / 1327 | 시간 702[s] | 퍼플렉서티 116.30
# | 에폭 5 |  반복 541 / 1327 | 시간 729[s] | 퍼플렉서티 120.40
# | 에폭 5 |  반복 561 / 1327 | 시간 756[s] | 퍼플렉서티 99.94
# | 에폭 5 |  반복 581 / 1327 | 시간 784[s] | 퍼플렉서티 91.78
# | 에폭 5 |  반복 601 / 1327 | 시간 811[s] | 퍼플렉서티 132.48
# | 에폭 5 |  반복 621 / 1327 | 시간 838[s] | 퍼플렉서티 122.24
# | 에폭 5 |  반복 641 / 1327 | 시간 865[s] | 퍼플렉서티 112.42
# | 에폭 5 |  반복 661 / 1327 | 시간 892[s] | 퍼플렉서티 105.28
# | 에폭 5 |  반복 681 / 1327 | 시간 919[s] | 퍼플렉서티 89.76
# | 에폭 5 |  반복 701 / 1327 | 시간 946[s] | 퍼플렉서티 104.92
# | 에폭 5 |  반복 721 / 1327 | 시간 974[s] | 퍼플렉서티 107.52
# | 에폭 5 |  반복 741 / 1327 | 시간 1001[s] | 퍼플렉서티 92.46
# | 에폭 5 |  반복 761 / 1327 | 시간 1028[s] | 퍼플렉서티 86.07
# | 에폭 5 |  반복 781 / 1327 | 시간 1055[s] | 퍼플렉서티 93.10
# | 에폭 5 |  반복 801 / 1327 | 시간 1082[s] | 퍼플렉서티 106.24
# | 에폭 5 |  반복 821 / 1327 | 시간 1109[s] | 퍼플렉서티 105.55
# | 에폭 5 |  반복 841 / 1327 | 시간 1136[s] | 퍼플렉서티 104.19
# | 에폭 5 |  반복 861 / 1327 | 시간 1163[s] | 퍼플렉서티 101.38
# | 에폭 5 |  반복 881 / 1327 | 시간 1190[s] | 퍼플렉서티 94.14
# | 에폭 5 |  반복 901 / 1327 | 시간 1217[s] | 퍼플렉서티 119.41
# | 에폭 5 |  반복 921 / 1327 | 시간 1243[s] | 퍼플렉서티 105.55
# | 에폭 5 |  반복 941 / 1327 | 시간 1270[s] | 퍼플렉서티 111.78
# | 에폭 5 |  반복 961 / 1327 | 시간 1297[s] | 퍼플렉서티 121.66
# | 에폭 5 |  반복 981 / 1327 | 시간 1324[s] | 퍼플렉서티 115.29
# | 에폭 5 |  반복 1001 / 1327 | 시간 1352[s] | 퍼플렉서티 97.89
# | 에폭 5 |  반복 1021 / 1327 | 시간 1379[s] | 퍼플렉서티 117.51
# | 에폭 5 |  반복 1041 / 1327 | 시간 1406[s] | 퍼플렉서티 100.89
# | 에폭 5 |  반복 1061 / 1327 | 시간 1433[s] | 퍼플렉서티 96.52
# | 에폭 5 |  반복 1081 / 1327 | 시간 1460[s] | 퍼플렉서티 77.61
# | 에폭 5 |  반복 1101 / 1327 | 시간 1486[s] | 퍼플렉서티 81.02
# | 에폭 5 |  반복 1121 / 1327 | 시간 1513[s] | 퍼플렉서티 110.05
# | 에폭 5 |  반복 1141 / 1327 | 시간 1540[s] | 퍼플렉서티 106.26
# | 에폭 5 |  반복 1161 / 1327 | 시간 1567[s] | 퍼플렉서티 89.99
# | 에폭 5 |  반복 1181 / 1327 | 시간 1593[s] | 퍼플렉서티 98.25
# | 에폭 5 |  반복 1201 / 1327 | 시간 1620[s] | 퍼플렉서티 81.50
# | 에폭 5 |  반복 1221 / 1327 | 시간 1646[s] | 퍼플렉서티 81.48
# | 에폭 5 |  반복 1241 / 1327 | 시간 1673[s] | 퍼플렉서티 96.80
# | 에폭 5 |  반복 1261 / 1327 | 시간 1700[s] | 퍼플렉서티 93.23
# | 에폭 5 |  반복 1281 / 1327 | 시간 1726[s] | 퍼플렉서티 91.00
# | 에폭 5 |  반복 1301 / 1327 | 시간 1753[s] | 퍼플렉서티 117.41
# | 에폭 5 |  반복 1321 / 1327 | 시간 1779[s] | 퍼플렉서티 116.62
# 퍼플렉서티 평가 중 ...
# 209 / 210
# 검증 퍼플렉서티:  104.82495540421895
# --------------------------------------------------
# | 에폭 6 |  반복 1 / 1327 | 시간 1[s] | 퍼플렉서티 162.04
# | 에폭 6 |  반복 21 / 1327 | 시간 28[s] | 퍼플렉서티 101.78
# | 에폭 6 |  반복 41 / 1327 | 시간 56[s] | 퍼플렉서티 99.85
# | 에폭 6 |  반복 61 / 1327 | 시간 83[s] | 퍼플렉서티 95.02
# | 에폭 6 |  반복 81 / 1327 | 시간 110[s] | 퍼플렉서티 81.92
# | 에폭 6 |  반복 101 / 1327 | 시간 137[s] | 퍼플렉서티 79.43
# | 에폭 6 |  반복 121 / 1327 | 시간 164[s] | 퍼플렉서티 88.54
# | 에폭 6 |  반복 141 / 1327 | 시간 190[s] | 퍼플렉서티 96.12
# | 에폭 6 |  반복 161 / 1327 | 시간 217[s] | 퍼플렉서티 111.18
# | 에폭 6 |  반복 181 / 1327 | 시간 244[s] | 퍼플렉서티 117.12
# | 에폭 6 |  반복 201 / 1327 | 시간 271[s] | 퍼플렉서티 112.70
# | 에폭 6 |  반복 221 / 1327 | 시간 297[s] | 퍼플렉서티 109.57
# | 에폭 6 |  반복 241 / 1327 | 시간 324[s] | 퍼플렉서티 103.92
# | 에폭 6 |  반복 261 / 1327 | 시간 351[s] | 퍼플렉서티 111.85
# | 에폭 6 |  반복 281 / 1327 | 시간 377[s] | 퍼플렉서티 110.33
# | 에폭 6 |  반복 301 / 1327 | 시간 404[s] | 퍼플렉서티 91.00
# | 에폭 6 |  반복 321 / 1327 | 시간 431[s] | 퍼플렉서티 72.95
# | 에폭 6 |  반복 341 / 1327 | 시간 458[s] | 퍼플렉서티 105.71
# | 에폭 6 |  반복 361 / 1327 | 시간 484[s] | 퍼플렉서티 112.01
# | 에폭 6 |  반복 381 / 1327 | 시간 511[s] | 퍼플렉서티 91.88
# | 에폭 6 |  반복 401 / 1327 | 시간 538[s] | 퍼플렉서티 103.34
# | 에폭 6 |  반복 421 / 1327 | 시간 565[s] | 퍼플렉서티 89.36
# | 에폭 6 |  반복 441 / 1327 | 시간 592[s] | 퍼플렉서티 96.25
# | 에폭 6 |  반복 461 / 1327 | 시간 618[s] | 퍼플렉서티 94.61
# | 에폭 6 |  반복 481 / 1327 | 시간 645[s] | 퍼플렉서티 94.17
# | 에폭 6 |  반복 501 / 1327 | 시간 671[s] | 퍼플렉서티 104.23
# | 에폭 6 |  반복 521 / 1327 | 시간 698[s] | 퍼플렉서티 107.75
# | 에폭 6 |  반복 541 / 1327 | 시간 725[s] | 퍼플렉서티 108.38
# | 에폭 6 |  반복 561 / 1327 | 시간 752[s] | 퍼플렉서티 93.43
# | 에폭 6 |  반복 581 / 1327 | 시간 778[s] | 퍼플렉서티 84.97
# | 에폭 6 |  반복 601 / 1327 | 시간 805[s] | 퍼플렉서티 121.43
# | 에폭 6 |  반복 621 / 1327 | 시간 832[s] | 퍼플렉서티 111.99
# | 에폭 6 |  반복 641 / 1327 | 시간 859[s] | 퍼플렉서티 102.68
# | 에폭 6 |  반복 661 / 1327 | 시간 886[s] | 퍼플렉서티 95.78
# | 에폭 6 |  반복 681 / 1327 | 시간 913[s] | 퍼플렉서티 83.21
# | 에폭 6 |  반복 701 / 1327 | 시간 940[s] | 퍼플렉서티 98.15
# | 에폭 6 |  반복 721 / 1327 | 시간 967[s] | 퍼플렉서티 98.96
# | 에폭 6 |  반복 741 / 1327 | 시간 994[s] | 퍼플렉서티 85.83
# | 에폭 6 |  반복 761 / 1327 | 시간 1021[s] | 퍼플렉서티 78.25
# | 에폭 6 |  반복 781 / 1327 | 시간 1048[s] | 퍼플렉서티 86.12
# | 에폭 6 |  반복 801 / 1327 | 시간 1075[s] | 퍼플렉서티 98.19
# | 에폭 6 |  반복 821 / 1327 | 시간 1101[s] | 퍼플렉서티 98.07
# | 에폭 6 |  반복 841 / 1327 | 시간 1128[s] | 퍼플렉서티 96.70
# | 에폭 6 |  반복 861 / 1327 | 시간 1156[s] | 퍼플렉서티 96.36
# | 에폭 6 |  반복 881 / 1327 | 시간 1182[s] | 퍼플렉서티 87.11
# | 에폭 6 |  반복 901 / 1327 | 시간 1209[s] | 퍼플렉서티 111.68
# | 에폭 6 |  반복 921 / 1327 | 시간 1237[s] | 퍼플렉서티 98.20
# | 에폭 6 |  반복 941 / 1327 | 시간 1264[s] | 퍼플렉서티 104.59
# | 에폭 6 |  반복 961 / 1327 | 시간 1291[s] | 퍼플렉서티 112.48
# | 에폭 6 |  반복 981 / 1327 | 시간 1318[s] | 퍼플렉서티 106.72
# | 에폭 6 |  반복 1001 / 1327 | 시간 1345[s] | 퍼플렉서티 89.85
# | 에폭 6 |  반복 1021 / 1327 | 시간 1372[s] | 퍼플렉서티 108.20
# | 에폭 6 |  반복 1041 / 1327 | 시간 1399[s] | 퍼플렉서티 93.09
# | 에폭 6 |  반복 1061 / 1327 | 시간 1426[s] | 퍼플렉서티 89.30
# | 에폭 6 |  반복 1081 / 1327 | 시간 1453[s] | 퍼플렉서티 73.68
# | 에폭 6 |  반복 1101 / 1327 | 시간 1481[s] | 퍼플렉서티 74.76
# | 에폭 6 |  반복 1121 / 1327 | 시간 1507[s] | 퍼플렉서티 101.26
# | 에폭 6 |  반복 1141 / 1327 | 시간 1534[s] | 퍼플렉서티 98.04
# | 에폭 6 |  반복 1161 / 1327 | 시간 1561[s] | 퍼플렉서티 83.21
# | 에폭 6 |  반복 1181 / 1327 | 시간 1588[s] | 퍼플렉서티 92.06
# | 에폭 6 |  반복 1201 / 1327 | 시간 1615[s] | 퍼플렉서티 76.61
# | 에폭 6 |  반복 1221 / 1327 | 시간 1642[s] | 퍼플렉서티 74.92
# | 에폭 6 |  반복 1241 / 1327 | 시간 1670[s] | 퍼플렉서티 91.16
# | 에폭 6 |  반복 1261 / 1327 | 시간 1697[s] | 퍼플렉서티 85.24
# | 에폭 6 |  반복 1281 / 1327 | 시간 1724[s] | 퍼플렉서티 87.19
# | 에폭 6 |  반복 1301 / 1327 | 시간 1751[s] | 퍼플렉서티 110.72
# | 에폭 6 |  반복 1321 / 1327 | 시간 1779[s] | 퍼플렉서티 106.47
# 퍼플렉서티 평가 중 ...
# 209 / 210
# 검증 퍼플렉서티:  100.13494544417311
# --------------------------------------------------
# | 에폭 7 |  반복 1 / 1327 | 시간 1[s] | 퍼플렉서티 152.08
# | 에폭 7 |  반복 21 / 1327 | 시간 28[s] | 퍼플렉서티 93.98
# | 에폭 7 |  반복 41 / 1327 | 시간 55[s] | 퍼플렉서티 92.19
# | 에폭 7 |  반복 61 / 1327 | 시간 82[s] | 퍼플렉서티 88.84
# | 에폭 7 |  반복 81 / 1327 | 시간 109[s] | 퍼플렉서티 76.42
# | 에폭 7 |  반복 101 / 1327 | 시간 136[s] | 퍼플렉서티 75.05
# | 에폭 7 |  반복 121 / 1327 | 시간 163[s] | 퍼플렉서티 82.14
# | 에폭 7 |  반복 141 / 1327 | 시간 190[s] | 퍼플렉서티 88.22
# | 에폭 7 |  반복 161 / 1327 | 시간 217[s] | 퍼플렉서티 103.40
# | 에폭 7 |  반복 181 / 1327 | 시간 243[s] | 퍼플렉서티 108.66
# | 에폭 7 |  반복 201 / 1327 | 시간 271[s] | 퍼플렉서티 106.70
# | 에폭 7 |  반복 221 / 1327 | 시간 298[s] | 퍼플렉서티 102.27
# | 에폭 7 |  반복 241 / 1327 | 시간 324[s] | 퍼플렉서티 97.00
# | 에폭 7 |  반복 261 / 1327 | 시간 351[s] | 퍼플렉서티 102.50
# | 에폭 7 |  반복 281 / 1327 | 시간 377[s] | 퍼플렉서티 101.50
# | 에폭 7 |  반복 301 / 1327 | 시간 404[s] | 퍼플렉서티 86.36
# | 에폭 7 |  반복 321 / 1327 | 시간 431[s] | 퍼플렉서티 67.81
# | 에폭 7 |  반복 341 / 1327 | 시간 458[s] | 퍼플렉서티 99.00
# | 에폭 7 |  반복 361 / 1327 | 시간 484[s] | 퍼플렉서티 102.67
# | 에폭 7 |  반복 381 / 1327 | 시간 511[s] | 퍼플렉서티 84.66
# | 에폭 7 |  반복 401 / 1327 | 시간 537[s] | 퍼플렉서티 96.47
# | 에폭 7 |  반복 421 / 1327 | 시간 564[s] | 퍼플렉서티 82.17
# | 에폭 7 |  반복 441 / 1327 | 시간 591[s] | 퍼플렉서티 89.65
# | 에폭 7 |  반복 461 / 1327 | 시간 619[s] | 퍼플렉서티 88.39
# | 에폭 7 |  반복 481 / 1327 | 시간 646[s] | 퍼플렉서티 88.33
# | 에폭 7 |  반복 501 / 1327 | 시간 673[s] | 퍼플렉서티 97.58
# | 에폭 7 |  반복 521 / 1327 | 시간 700[s] | 퍼플렉서티 100.48
# | 에폭 7 |  반복 541 / 1327 | 시간 726[s] | 퍼플렉서티 101.98
# | 에폭 7 |  반복 561 / 1327 | 시간 753[s] | 퍼플렉서티 85.17
# | 에폭 7 |  반복 581 / 1327 | 시간 779[s] | 퍼플렉서티 79.55
# | 에폭 7 |  반복 601 / 1327 | 시간 806[s] | 퍼플렉서티 113.45
# | 에폭 7 |  반복 621 / 1327 | 시간 832[s] | 퍼플렉서티 105.30
# | 에폭 7 |  반복 641 / 1327 | 시간 859[s] | 퍼플렉서티 97.34
# | 에폭 7 |  반복 661 / 1327 | 시간 886[s] | 퍼플렉서티 89.61
# | 에폭 7 |  반복 681 / 1327 | 시간 912[s] | 퍼플렉서티 78.29
# | 에폭 7 |  반복 701 / 1327 | 시간 939[s] | 퍼플렉서티 90.12
# | 에폭 7 |  반복 721 / 1327 | 시간 965[s] | 퍼플렉서티 90.94
# | 에폭 7 |  반복 741 / 1327 | 시간 992[s] | 퍼플렉서티 79.89
# | 에폭 7 |  반복 761 / 1327 | 시간 1018[s] | 퍼플렉서티 73.36
# | 에폭 7 |  반복 781 / 1327 | 시간 1045[s] | 퍼플렉서티 80.86
# | 에폭 7 |  반복 801 / 1327 | 시간 1071[s] | 퍼플렉서티 92.28
# | 에폭 7 |  반복 821 / 1327 | 시간 1098[s] | 퍼플렉서티 91.70
# | 에폭 7 |  반복 841 / 1327 | 시간 1124[s] | 퍼플렉서티 90.63
# | 에폭 7 |  반복 861 / 1327 | 시간 1150[s] | 퍼플렉서티 89.10
# | 에폭 7 |  반복 881 / 1327 | 시간 1177[s] | 퍼플렉서티 81.97
# | 에폭 7 |  반복 901 / 1327 | 시간 1203[s] | 퍼플렉서티 105.45
# | 에폭 7 |  반복 921 / 1327 | 시간 1230[s] | 퍼플렉서티 92.31
# | 에폭 7 |  반복 941 / 1327 | 시간 1256[s] | 퍼플렉서티 97.64
# | 에폭 7 |  반복 961 / 1327 | 시간 1282[s] | 퍼플렉서티 105.06
# | 에폭 7 |  반복 981 / 1327 | 시간 1309[s] | 퍼플렉서티 101.06
# | 에폭 7 |  반복 1001 / 1327 | 시간 1336[s] | 퍼플렉서티 85.31
# | 에폭 7 |  반복 1021 / 1327 | 시간 1362[s] | 퍼플렉서티 101.62
# | 에폭 7 |  반복 1041 / 1327 | 시간 1389[s] | 퍼플렉서티 86.82
# | 에폭 7 |  반복 1061 / 1327 | 시간 1416[s] | 퍼플렉서티 82.74
# | 에폭 7 |  반복 1081 / 1327 | 시간 1442[s] | 퍼플렉서티 66.81
# | 에폭 7 |  반복 1101 / 1327 | 시간 1469[s] | 퍼플렉서티 70.65
# | 에폭 7 |  반복 1121 / 1327 | 시간 1495[s] | 퍼플렉서티 96.04
# | 에폭 7 |  반복 1141 / 1327 | 시간 1522[s] | 퍼플렉서티 92.78
# | 에폭 7 |  반복 1161 / 1327 | 시간 1549[s] | 퍼플렉서티 77.88
# | 에폭 7 |  반복 1181 / 1327 | 시간 1575[s] | 퍼플렉서티 85.11
# | 에폭 7 |  반복 1201 / 1327 | 시간 1602[s] | 퍼플렉서티 72.78
# | 에폭 7 |  반복 1221 / 1327 | 시간 1629[s] | 퍼플렉서티 71.19
# | 에폭 7 |  반복 1241 / 1327 | 시간 1656[s] | 퍼플렉서티 86.40
# | 에폭 7 |  반복 1261 / 1327 | 시간 1683[s] | 퍼플렉서티 81.26
# | 에폭 7 |  반복 1281 / 1327 | 시간 1709[s] | 퍼플렉서티 81.84
# | 에폭 7 |  반복 1301 / 1327 | 시간 1736[s] | 퍼플렉서티 104.24
# | 에폭 7 |  반복 1321 / 1327 | 시간 1763[s] | 퍼플렉서티 101.00
# 퍼플렉서티 평가 중 ...
# 209 / 210
# 검증 퍼플렉서티:  96.48298750884045
# --------------------------------------------------
# | 에폭 8 |  반복 1 / 1327 | 시간 1[s] | 퍼플렉서티 146.80
# | 에폭 8 |  반복 21 / 1327 | 시간 28[s] | 퍼플렉서티 88.68
# | 에폭 8 |  반복 41 / 1327 | 시간 54[s] | 퍼플렉서티 86.11
# | 에폭 8 |  반복 61 / 1327 | 시간 81[s] | 퍼플렉서티 83.94
# | 에폭 8 |  반복 81 / 1327 | 시간 108[s] | 퍼플렉서티 71.85
# | 에폭 8 |  반복 101 / 1327 | 시간 134[s] | 퍼플렉서티 71.15
# | 에폭 8 |  반복 121 / 1327 | 시간 161[s] | 퍼플렉서티 76.83
# | 에폭 8 |  반복 141 / 1327 | 시간 188[s] | 퍼플렉서티 83.09
# | 에폭 8 |  반복 161 / 1327 | 시간 214[s] | 퍼플렉서티 97.94
# | 에폭 8 |  반복 181 / 1327 | 시간 240[s] | 퍼플렉서티 102.73
# | 에폭 8 |  반복 201 / 1327 | 시간 266[s] | 퍼플렉서티 100.45
# | 에폭 8 |  반복 221 / 1327 | 시간 293[s] | 퍼플렉서티 96.53
# | 에폭 8 |  반복 241 / 1327 | 시간 319[s] | 퍼플렉서티 91.89
# | 에폭 8 |  반복 261 / 1327 | 시간 345[s] | 퍼플렉서티 97.64
# | 에폭 8 |  반복 281 / 1327 | 시간 372[s] | 퍼플렉서티 97.18
# | 에폭 8 |  반복 301 / 1327 | 시간 399[s] | 퍼플렉서티 80.52
# | 에폭 8 |  반복 321 / 1327 | 시간 425[s] | 퍼플렉서티 65.11
# | 에폭 8 |  반복 341 / 1327 | 시간 452[s] | 퍼플렉서티 93.17
# | 에폭 8 |  반복 361 / 1327 | 시간 478[s] | 퍼플렉서티 96.77
# | 에폭 8 |  반복 381 / 1327 | 시간 505[s] | 퍼플렉서티 81.61
# | 에폭 8 |  반복 401 / 1327 | 시간 532[s] | 퍼플렉서티 92.07
# | 에폭 8 |  반복 421 / 1327 | 시간 558[s] | 퍼플렉서티 78.61
# | 에폭 8 |  반복 441 / 1327 | 시간 585[s] | 퍼플렉서티 84.47
# | 에폭 8 |  반복 461 / 1327 | 시간 611[s] | 퍼플렉서티 83.10
# | 에폭 8 |  반복 481 / 1327 | 시간 638[s] | 퍼플렉서티 83.02
# | 에폭 8 |  반복 501 / 1327 | 시간 664[s] | 퍼플렉서티 92.94
# | 에폭 8 |  반복 521 / 1327 | 시간 690[s] | 퍼플렉서티 95.21
# | 에폭 8 |  반복 541 / 1327 | 시간 717[s] | 퍼플렉서티 96.35
# | 에폭 8 |  반복 561 / 1327 | 시간 743[s] | 퍼플렉서티 80.23
# | 에폭 8 |  반복 581 / 1327 | 시간 770[s] | 퍼플렉서티 75.53
# | 에폭 8 |  반복 601 / 1327 | 시간 797[s] | 퍼플렉서티 106.21
# | 에폭 8 |  반복 621 / 1327 | 시간 823[s] | 퍼플렉서티 99.33
# | 에폭 8 |  반복 641 / 1327 | 시간 849[s] | 퍼플렉서티 91.60
# | 에폭 8 |  반복 661 / 1327 | 시간 876[s] | 퍼플렉서티 83.84
# | 에폭 8 |  반복 681 / 1327 | 시간 902[s] | 퍼플렉서티 73.44
# | 에폭 8 |  반복 701 / 1327 | 시간 929[s] | 퍼플렉서티 85.78
# | 에폭 8 |  반복 721 / 1327 | 시간 956[s] | 퍼플렉서티 88.02
# | 에폭 8 |  반복 741 / 1327 | 시간 983[s] | 퍼플렉서티 76.95
# | 에폭 8 |  반복 761 / 1327 | 시간 1010[s] | 퍼플렉서티 69.65
# | 에폭 8 |  반복 781 / 1327 | 시간 1037[s] | 퍼플렉서티 76.54
# | 에폭 8 |  반복 801 / 1327 | 시간 1064[s] | 퍼플렉서티 86.76
# | 에폭 8 |  반복 821 / 1327 | 시간 1091[s] | 퍼플렉서티 86.23
# | 에폭 8 |  반복 841 / 1327 | 시간 1118[s] | 퍼플렉서티 84.75
# | 에폭 8 |  반복 861 / 1327 | 시간 1145[s] | 퍼플렉서티 84.97
# | 에폭 8 |  반복 881 / 1327 | 시간 1172[s] | 퍼플렉서티 78.88
# | 에폭 8 |  반복 901 / 1327 | 시간 1199[s] | 퍼플렉서티 100.08
# | 에폭 8 |  반복 921 / 1327 | 시간 1226[s] | 퍼플렉서티 87.71
# | 에폭 8 |  반복 941 / 1327 | 시간 1253[s] | 퍼플렉서티 93.70
# | 에폭 8 |  반복 961 / 1327 | 시간 1279[s] | 퍼플렉서티 99.61
# | 에폭 8 |  반복 981 / 1327 | 시간 1306[s] | 퍼플렉서티 95.58
# | 에폭 8 |  반복 1001 / 1327 | 시간 1332[s] | 퍼플렉서티 80.78
# | 에폭 8 |  반복 1021 / 1327 | 시간 1359[s] | 퍼플렉서티 97.14
# | 에폭 8 |  반복 1041 / 1327 | 시간 1385[s] | 퍼플렉서티 82.86
# | 에폭 8 |  반복 1061 / 1327 | 시간 1412[s] | 퍼플렉서티 79.61
# | 에폭 8 |  반복 1081 / 1327 | 시간 1438[s] | 퍼플렉서티 65.20
# | 에폭 8 |  반복 1101 / 1327 | 시간 1465[s] | 퍼플렉서티 66.61
# | 에폭 8 |  반복 1121 / 1327 | 시간 1491[s] | 퍼플렉서티 91.32
# | 에폭 8 |  반복 1141 / 1327 | 시간 1518[s] | 퍼플렉서티 88.17
# | 에폭 8 |  반복 1161 / 1327 | 시간 1545[s] | 퍼플렉서티 73.58
# | 에폭 8 |  반복 1181 / 1327 | 시간 1571[s] | 퍼플렉서티 82.87
# | 에폭 8 |  반복 1201 / 1327 | 시간 1598[s] | 퍼플렉서티 67.82
# | 에폭 8 |  반복 1221 / 1327 | 시간 1625[s] | 퍼플렉서티 67.16
# | 에폭 8 |  반복 1241 / 1327 | 시간 1652[s] | 퍼플렉서티 82.06
# | 에폭 8 |  반복 1261 / 1327 | 시간 1679[s] | 퍼플렉서티 77.56
# | 에폭 8 |  반복 1281 / 1327 | 시간 1706[s] | 퍼플렉서티 76.85
# | 에폭 8 |  반복 1301 / 1327 | 시간 1733[s] | 퍼플렉서티 98.21
# | 에폭 8 |  반복 1321 / 1327 | 시간 1760[s] | 퍼플렉서티 96.24
# 퍼플렉서티 평가 중 ...
# 209 / 210
# 검증 퍼플렉서티:  94.22822997099568
# --------------------------------------------------
# | 에폭 9 |  반복 1 / 1327 | 시간 1[s] | 퍼플렉서티 136.15
# | 에폭 9 |  반복 21 / 1327 | 시간 27[s] | 퍼플렉서티 84.48
# | 에폭 9 |  반복 41 / 1327 | 시간 54[s] | 퍼플렉서티 81.69
# | 에폭 9 |  반복 61 / 1327 | 시간 80[s] | 퍼플렉서티 79.53
# | 에폭 9 |  반복 81 / 1327 | 시간 107[s] | 퍼플렉서티 68.10
# | 에폭 9 |  반복 101 / 1327 | 시간 134[s] | 퍼플렉서티 66.80
# | 에폭 9 |  반복 121 / 1327 | 시간 160[s] | 퍼플렉서티 73.78
# | 에폭 9 |  반복 141 / 1327 | 시간 187[s] | 퍼플렉서티 80.05
# | 에폭 9 |  반복 161 / 1327 | 시간 214[s] | 퍼플렉서티 92.35
# | 에폭 9 |  반복 181 / 1327 | 시간 241[s] | 퍼플렉서티 99.57
# | 에폭 9 |  반복 201 / 1327 | 시간 269[s] | 퍼플렉서티 95.13
# | 에폭 9 |  반복 221 / 1327 | 시간 296[s] | 퍼플렉서티 92.76
# | 에폭 9 |  반복 241 / 1327 | 시간 323[s] | 퍼플렉서티 87.91
# | 에폭 9 |  반복 261 / 1327 | 시간 350[s] | 퍼플렉서티 92.98
# | 에폭 9 |  반복 281 / 1327 | 시간 377[s] | 퍼플렉서티 92.43
# | 에폭 9 |  반복 301 / 1327 | 시간 404[s] | 퍼플렉서티 75.10
# | 에폭 9 |  반복 321 / 1327 | 시간 431[s] | 퍼플렉서티 61.88
# | 에폭 9 |  반복 341 / 1327 | 시간 458[s] | 퍼플렉서티 88.72
# | 에폭 9 |  반복 361 / 1327 | 시간 485[s] | 퍼플렉서티 92.61
# | 에폭 9 |  반복 381 / 1327 | 시간 512[s] | 퍼플렉서티 76.89
# | 에폭 9 |  반복 401 / 1327 | 시간 538[s] | 퍼플렉서티 87.92
# | 에폭 9 |  반복 421 / 1327 | 시간 565[s] | 퍼플렉서티 74.41
# | 에폭 9 |  반복 441 / 1327 | 시간 592[s] | 퍼플렉서티 79.51
# | 에폭 9 |  반복 461 / 1327 | 시간 618[s] | 퍼플렉서티 79.47
# | 에폭 9 |  반복 481 / 1327 | 시간 645[s] | 퍼플렉서티 78.76
# | 에폭 9 |  반복 501 / 1327 | 시간 672[s] | 퍼플렉서티 88.99
# | 에폭 9 |  반복 521 / 1327 | 시간 699[s] | 퍼플렉서티 90.37
# | 에폭 9 |  반복 541 / 1327 | 시간 726[s] | 퍼플렉서티 93.06
# | 에폭 9 |  반복 561 / 1327 | 시간 752[s] | 퍼플렉서티 76.19
# | 에폭 9 |  반복 581 / 1327 | 시간 778[s] | 퍼플렉서티 71.58
# | 에폭 9 |  반복 601 / 1327 | 시간 805[s] | 퍼플렉서티 101.28
# | 에폭 9 |  반복 621 / 1327 | 시간 832[s] | 퍼플렉서티 94.09
# | 에폭 9 |  반복 641 / 1327 | 시간 858[s] | 퍼플렉서티 87.23
# | 에폭 9 |  반복 661 / 1327 | 시간 885[s] | 퍼플렉서티 79.30
# | 에폭 9 |  반복 681 / 1327 | 시간 911[s] | 퍼플렉서티 68.52
# | 에폭 9 |  반복 701 / 1327 | 시간 938[s] | 퍼플렉서티 81.89
# | 에폭 9 |  반복 721 / 1327 | 시간 964[s] | 퍼플렉서티 82.76
# | 에폭 9 |  반복 741 / 1327 | 시간 991[s] | 퍼플렉서티 74.14
# | 에폭 9 |  반복 761 / 1327 | 시간 1018[s] | 퍼플렉서티 66.96
# | 에폭 9 |  반복 781 / 1327 | 시간 1044[s] | 퍼플렉서티 73.40
# | 에폭 9 |  반복 801 / 1327 | 시간 1071[s] | 퍼플렉서티 82.50
# | 에폭 9 |  반복 821 / 1327 | 시간 1097[s] | 퍼플렉서티 81.85
# | 에폭 9 |  반복 841 / 1327 | 시간 1124[s] | 퍼플렉서티 82.34
# | 에폭 9 |  반복 861 / 1327 | 시간 1151[s] | 퍼플렉서티 80.13
# | 에폭 9 |  반복 881 / 1327 | 시간 1177[s] | 퍼플렉서티 75.21
# | 에폭 9 |  반복 901 / 1327 | 시간 1204[s] | 퍼플렉서티 94.34
# | 에폭 9 |  반복 921 / 1327 | 시간 1231[s] | 퍼플렉서티 83.63
# | 에폭 9 |  반복 941 / 1327 | 시간 1258[s] | 퍼플렉서티 88.90
# | 에폭 9 |  반복 961 / 1327 | 시간 1285[s] | 퍼플렉서티 95.70
# | 에폭 9 |  반복 981 / 1327 | 시간 1312[s] | 퍼플렉서티 92.55
# | 에폭 9 |  반복 1001 / 1327 | 시간 1339[s] | 퍼플렉서티 76.70
# | 에폭 9 |  반복 1021 / 1327 | 시간 1366[s] | 퍼플렉서티 92.11
# | 에폭 9 |  반복 1041 / 1327 | 시간 1393[s] | 퍼플렉서티 79.59
# | 에폭 9 |  반복 1061 / 1327 | 시간 1420[s] | 퍼플렉서티 75.56
# | 에폭 9 |  반복 1081 / 1327 | 시간 1446[s] | 퍼플렉서티 61.70
# | 에폭 9 |  반복 1101 / 1327 | 시간 1473[s] | 퍼플렉서티 63.37
# | 에폭 9 |  반복 1121 / 1327 | 시간 1499[s] | 퍼플렉서티 86.92
# | 에폭 9 |  반복 1141 / 1327 | 시간 1526[s] | 퍼플렉서티 83.62
# | 에폭 9 |  반복 1161 / 1327 | 시간 1553[s] | 퍼플렉서티 70.03
# | 에폭 9 |  반복 1181 / 1327 | 시간 1580[s] | 퍼플렉서티 77.67
# | 에폭 9 |  반복 1201 / 1327 | 시간 1607[s] | 퍼플렉서티 65.11
# | 에폭 9 |  반복 1221 / 1327 | 시간 1634[s] | 퍼플렉서티 64.27
# | 에폭 9 |  반복 1241 / 1327 | 시간 1660[s] | 퍼플렉서티 77.39
# | 에폭 9 |  반복 1261 / 1327 | 시간 1687[s] | 퍼플렉서티 73.86
# | 에폭 9 |  반복 1281 / 1327 | 시간 1714[s] | 퍼플렉서티 74.82
# | 에폭 9 |  반복 1301 / 1327 | 시간 1740[s] | 퍼플렉서티 95.37
# | 에폭 9 |  반복 1321 / 1327 | 시간 1766[s] | 퍼플렉서티 91.75
# 퍼플렉서티 평가 중 ...
# 209 / 210
# 검증 퍼플렉서티:  92.06406259758356
# --------------------------------------------------
# | 에폭 10 |  반복 1 / 1327 | 시간 1[s] | 퍼플렉서티 135.30
# | 에폭 10 |  반복 21 / 1327 | 시간 27[s] | 퍼플렉서티 80.56
# | 에폭 10 |  반복 41 / 1327 | 시간 54[s] | 퍼플렉서티 78.74
# | 에폭 10 |  반복 61 / 1327 | 시간 80[s] | 퍼플렉서티 76.02
# | 에폭 10 |  반복 81 / 1327 | 시간 107[s] | 퍼플렉서티 65.76
# | 에폭 10 |  반복 101 / 1327 | 시간 133[s] | 퍼플렉서티 65.31
# | 에폭 10 |  반복 121 / 1327 | 시간 160[s] | 퍼플렉서티 71.19
# | 에폭 10 |  반복 141 / 1327 | 시간 186[s] | 퍼플렉서티 75.84
# | 에폭 10 |  반복 161 / 1327 | 시간 213[s] | 퍼플렉서티 89.14
# | 에폭 10 |  반복 181 / 1327 | 시간 239[s] | 퍼플렉서티 94.12
# | 에폭 10 |  반복 201 / 1327 | 시간 266[s] | 퍼플렉서티 91.41
# | 에폭 10 |  반복 221 / 1327 | 시간 293[s] | 퍼플렉서티 88.64
# | 에폭 10 |  반복 241 / 1327 | 시간 320[s] | 퍼플렉서티 83.65
# | 에폭 10 |  반복 261 / 1327 | 시간 347[s] | 퍼플렉서티 88.68
# | 에폭 10 |  반복 281 / 1327 | 시간 374[s] | 퍼플렉서티 87.71
# | 에폭 10 |  반복 301 / 1327 | 시간 401[s] | 퍼플렉서티 72.02
# | 에폭 10 |  반복 321 / 1327 | 시간 427[s] | 퍼플렉서티 59.53
# | 에폭 10 |  반복 341 / 1327 | 시간 454[s] | 퍼플렉서티 83.66
# | 에폭 10 |  반복 361 / 1327 | 시간 481[s] | 퍼플렉서티 87.63
# | 에폭 10 |  반복 381 / 1327 | 시간 508[s] | 퍼플렉서티 73.82
# | 에폭 10 |  반복 401 / 1327 | 시간 535[s] | 퍼플렉서티 83.12
# | 에폭 10 |  반복 421 / 1327 | 시간 561[s] | 퍼플렉서티 71.61
# | 에폭 10 |  반복 441 / 1327 | 시간 588[s] | 퍼플렉서티 77.80
# | 에폭 10 |  반복 461 / 1327 | 시간 614[s] | 퍼플렉서티 76.32
# | 에폭 10 |  반복 481 / 1327 | 시간 641[s] | 퍼플렉서티 76.05
# | 에폭 10 |  반복 501 / 1327 | 시간 668[s] | 퍼플렉서티 84.88
# | 에폭 10 |  반복 521 / 1327 | 시간 694[s] | 퍼플렉서티 86.17
# | 에폭 10 |  반복 541 / 1327 | 시간 721[s] | 퍼플렉서티 88.65
# | 에폭 10 |  반복 561 / 1327 | 시간 748[s] | 퍼플렉서티 74.21
# | 에폭 10 |  반복 581 / 1327 | 시간 775[s] | 퍼플렉서티 68.45
# | 에폭 10 |  반복 601 / 1327 | 시간 801[s] | 퍼플렉서티 97.22
# | 에폭 10 |  반복 621 / 1327 | 시간 828[s] | 퍼플렉서티 91.02
# | 에폭 10 |  반복 641 / 1327 | 시간 855[s] | 퍼플렉서티 83.46
# | 에폭 10 |  반복 661 / 1327 | 시간 882[s] | 퍼플렉서티 76.35
# | 에폭 10 |  반복 681 / 1327 | 시간 909[s] | 퍼플렉서티 66.68
# | 에폭 10 |  반복 701 / 1327 | 시간 936[s] | 퍼플렉서티 77.96
# | 에폭 10 |  반복 721 / 1327 | 시간 963[s] | 퍼플렉서티 79.15
# | 에폭 10 |  반복 741 / 1327 | 시간 989[s] | 퍼플렉서티 69.72
# | 에폭 10 |  반복 761 / 1327 | 시간 1016[s] | 퍼플렉서티 63.96
# | 에폭 10 |  반복 781 / 1327 | 시간 1042[s] | 퍼플렉서티 70.45
# | 에폭 10 |  반복 801 / 1327 | 시간 1069[s] | 퍼플렉서티 79.45
# | 에폭 10 |  반복 821 / 1327 | 시간 1095[s] | 퍼플렉서티 78.81
# | 에폭 10 |  반복 841 / 1327 | 시간 1122[s] | 퍼플렉서티 79.25
# | 에폭 10 |  반복 861 / 1327 | 시간 1148[s] | 퍼플렉서티 77.92
# | 에폭 10 |  반복 881 / 1327 | 시간 1175[s] | 퍼플렉서티 71.91
# | 에폭 10 |  반복 901 / 1327 | 시간 1202[s] | 퍼플렉서티 91.41
# | 에폭 10 |  반복 921 / 1327 | 시간 1228[s] | 퍼플렉서티 80.77
# | 에폭 10 |  반복 941 / 1327 | 시간 1255[s] | 퍼플렉서티 85.31
# | 에폭 10 |  반복 961 / 1327 | 시간 1281[s] | 퍼플렉서티 92.42
# | 에폭 10 |  반복 981 / 1327 | 시간 1308[s] | 퍼플렉서티 87.99
# | 에폭 10 |  반복 1001 / 1327 | 시간 1335[s] | 퍼플렉서티 75.15
# | 에폭 10 |  반복 1021 / 1327 | 시간 1361[s] | 퍼플렉서티 89.41
# | 에폭 10 |  반복 1041 / 1327 | 시간 1388[s] | 퍼플렉서티 76.38
# | 에폭 10 |  반복 1061 / 1327 | 시간 1415[s] | 퍼플렉서티 72.14
# | 에폭 10 |  반복 1081 / 1327 | 시간 1441[s] | 퍼플렉서티 59.93
# | 에폭 10 |  반복 1101 / 1327 | 시간 1468[s] | 퍼플렉서티 61.01
# | 에폭 10 |  반복 1121 / 1327 | 시간 1495[s] | 퍼플렉서티 84.50
# | 에폭 10 |  반복 1141 / 1327 | 시간 1522[s] | 퍼플렉서티 79.59
# | 에폭 10 |  반복 1161 / 1327 | 시간 1549[s] | 퍼플렉서티 67.20
# | 에폭 10 |  반복 1181 / 1327 | 시간 1576[s] | 퍼플렉서티 75.82
# | 에폭 10 |  반복 1201 / 1327 | 시간 1602[s] | 퍼플렉서티 62.50
# | 에폭 10 |  반복 1221 / 1327 | 시간 1629[s] | 퍼플렉서티 61.55
# | 에폭 10 |  반복 1241 / 1327 | 시간 1656[s] | 퍼플렉서티 75.67
# | 에폭 10 |  반복 1261 / 1327 | 시간 1683[s] | 퍼플렉서티 71.15
# | 에폭 10 |  반복 1281 / 1327 | 시간 1710[s] | 퍼플렉서티 71.51
# | 에폭 10 |  반복 1301 / 1327 | 시간 1736[s] | 퍼플렉서티 91.09
# | 에폭 10 |  반복 1321 / 1327 | 시간 1763[s] | 퍼플렉서티 87.29
# 퍼플렉서티 평가 중 ...
# 209 / 210
# 검증 퍼플렉서티:  90.64862051092071
# --------------------------------------------------
# | 에폭 11 |  반복 1 / 1327 | 시간 1[s] | 퍼플렉서티 123.43
# | 에폭 11 |  반복 21 / 1327 | 시간 28[s] | 퍼플렉서티 77.17
# | 에폭 11 |  반복 41 / 1327 | 시간 54[s] | 퍼플렉서티 75.23
# | 에폭 11 |  반복 61 / 1327 | 시간 81[s] | 퍼플렉서티 72.96
# | 에폭 11 |  반복 81 / 1327 | 시간 108[s] | 퍼플렉서티 64.23
# | 에폭 11 |  반복 101 / 1327 | 시간 135[s] | 퍼플렉서티 62.53
# | 에폭 11 |  반복 121 / 1327 | 시간 161[s] | 퍼플렉서티 68.23
# | 에폭 11 |  반복 141 / 1327 | 시간 188[s] | 퍼플렉서티 73.82
# | 에폭 11 |  반복 161 / 1327 | 시간 215[s] | 퍼플렉서티 84.91
# | 에폭 11 |  반복 181 / 1327 | 시간 242[s] | 퍼플렉서티 91.47
# | 에폭 11 |  반복 201 / 1327 | 시간 268[s] | 퍼플렉서티 88.47
# | 에폭 11 |  반복 221 / 1327 | 시간 295[s] | 퍼플렉서티 86.30
# | 에폭 11 |  반복 241 / 1327 | 시간 321[s] | 퍼플렉서티 81.67
# | 에폭 11 |  반복 261 / 1327 | 시간 348[s] | 퍼플렉서티 85.43
# | 에폭 11 |  반복 281 / 1327 | 시간 374[s] | 퍼플렉서티 85.64
# | 에폭 11 |  반복 301 / 1327 | 시간 401[s] | 퍼플렉서티 68.36
# | 에폭 11 |  반복 321 / 1327 | 시간 428[s] | 퍼플렉서티 56.96
# | 에폭 11 |  반복 341 / 1327 | 시간 454[s] | 퍼플렉서티 82.07
# | 에폭 11 |  반복 361 / 1327 | 시간 481[s] | 퍼플렉서티 84.61
# | 에폭 11 |  반복 381 / 1327 | 시간 507[s] | 퍼플렉서티 71.06
# | 에폭 11 |  반복 401 / 1327 | 시간 533[s] | 퍼플렉서티 80.13
# | 에폭 11 |  반복 421 / 1327 | 시간 560[s] | 퍼플렉서티 68.57
# | 에폭 11 |  반복 441 / 1327 | 시간 587[s] | 퍼플렉서티 73.83
# | 에폭 11 |  반복 461 / 1327 | 시간 614[s] | 퍼플렉서티 74.07
# | 에폭 11 |  반복 481 / 1327 | 시간 640[s] | 퍼플렉서티 73.34
# | 에폭 11 |  반복 501 / 1327 | 시간 667[s] | 퍼플렉서티 81.45
# | 에폭 11 |  반복 521 / 1327 | 시간 694[s] | 퍼플렉서티 82.87
# | 에폭 11 |  반복 541 / 1327 | 시간 721[s] | 퍼플렉서티 84.91
# | 에폭 11 |  반복 561 / 1327 | 시간 747[s] | 퍼플렉서티 71.13
# | 에폭 11 |  반복 581 / 1327 | 시간 774[s] | 퍼플렉서티 66.53
# | 에폭 11 |  반복 601 / 1327 | 시간 801[s] | 퍼플렉서티 93.87
# | 에폭 11 |  반복 621 / 1327 | 시간 827[s] | 퍼플렉서티 87.51
# | 에폭 11 |  반복 641 / 1327 | 시간 854[s] | 퍼플렉서티 80.29
# | 에폭 11 |  반복 661 / 1327 | 시간 880[s] | 퍼플렉서티 74.43
# | 에폭 11 |  반복 681 / 1327 | 시간 907[s] | 퍼플렉서티 64.61
# | 에폭 11 |  반복 701 / 1327 | 시간 934[s] | 퍼플렉서티 76.06
# | 에폭 11 |  반복 721 / 1327 | 시간 960[s] | 퍼플렉서티 76.53
# | 에폭 11 |  반복 741 / 1327 | 시간 987[s] | 퍼플렉서티 67.76
# | 에폭 11 |  반복 761 / 1327 | 시간 1014[s] | 퍼플렉서티 61.18
# | 에폭 11 |  반복 781 / 1327 | 시간 1040[s] | 퍼플렉서티 67.81
# | 에폭 11 |  반복 801 / 1327 | 시간 1067[s] | 퍼플렉서티 75.54
# | 에폭 11 |  반복 821 / 1327 | 시간 1094[s] | 퍼플렉서티 76.05
# | 에폭 11 |  반복 841 / 1327 | 시간 1121[s] | 퍼플렉서티 74.98
# | 에폭 11 |  반복 861 / 1327 | 시간 1148[s] | 퍼플렉서티 76.10
# | 에폭 11 |  반복 881 / 1327 | 시간 1174[s] | 퍼플렉서티 70.50
# | 에폭 11 |  반복 901 / 1327 | 시간 1201[s] | 퍼플렉서티 89.18
# | 에폭 11 |  반복 921 / 1327 | 시간 1228[s] | 퍼플렉서티 77.53
# | 에폭 11 |  반복 941 / 1327 | 시간 1254[s] | 퍼플렉서티 82.79
# | 에폭 11 |  반복 961 / 1327 | 시간 1281[s] | 퍼플렉서티 88.47
# | 에폭 11 |  반복 981 / 1327 | 시간 1308[s] | 퍼플렉서티 85.12
# | 에폭 11 |  반복 1001 / 1327 | 시간 1334[s] | 퍼플렉서티 72.48
# | 에폭 11 |  반복 1021 / 1327 | 시간 1361[s] | 퍼플렉서티 84.69
# | 에폭 11 |  반복 1041 / 1327 | 시간 1387[s] | 퍼플렉서티 74.09
# | 에폭 11 |  반복 1061 / 1327 | 시간 1414[s] | 퍼플렉서티 71.22
# | 에폭 11 |  반복 1081 / 1327 | 시간 1441[s] | 퍼플렉서티 57.36
# | 에폭 11 |  반복 1101 / 1327 | 시간 1468[s] | 퍼플렉서티 59.49
# | 에폭 11 |  반복 1121 / 1327 | 시간 1495[s] | 퍼플렉서티 81.58
# | 에폭 11 |  반복 1141 / 1327 | 시간 1521[s] | 퍼플렉서티 78.18
# | 에폭 11 |  반복 1161 / 1327 | 시간 1548[s] | 퍼플렉서티 64.78
# | 에폭 11 |  반복 1181 / 1327 | 시간 1574[s] | 퍼플렉서티 72.31
# | 에폭 11 |  반복 1201 / 1327 | 시간 1601[s] | 퍼플렉서티 60.22
# | 에폭 11 |  반복 1221 / 1327 | 시간 1628[s] | 퍼플렉서티 60.43
# | 에폭 11 |  반복 1241 / 1327 | 시간 1654[s] | 퍼플렉서티 72.19
# | 에폭 11 |  반복 1261 / 1327 | 시간 1681[s] | 퍼플렉서티 68.34
# | 에폭 11 |  반복 1281 / 1327 | 시간 1708[s] | 퍼플렉서티 69.56
# | 에폭 11 |  반복 1301 / 1327 | 시간 1734[s] | 퍼플렉서티 87.84
# | 에폭 11 |  반복 1321 / 1327 | 시간 1761[s] | 퍼플렉서티 85.24
# 퍼플렉서티 평가 중 ...
# 209 / 210
# 검증 퍼플렉서티:  89.8664374097531
# --------------------------------------------------
# | 에폭 12 |  반복 1 / 1327 | 시간 1[s] | 퍼플렉서티 127.46
# | 에폭 12 |  반복 21 / 1327 | 시간 28[s] | 퍼플렉서티 74.82
# | 에폭 12 |  반복 41 / 1327 | 시간 55[s] | 퍼플렉서티 73.90
# | 에폭 12 |  반복 61 / 1327 | 시간 82[s] | 퍼플렉서티 71.18
# | 에폭 12 |  반복 81 / 1327 | 시간 109[s] | 퍼플렉서티 61.62
# | 에폭 12 |  반복 101 / 1327 | 시간 136[s] | 퍼플렉서티 61.34
# | 에폭 12 |  반복 121 / 1327 | 시간 163[s] | 퍼플렉서티 65.33
# | 에폭 12 |  반복 141 / 1327 | 시간 190[s] | 퍼플렉서티 70.38
# | 에폭 12 |  반복 161 / 1327 | 시간 217[s] | 퍼플렉서티 81.43
# | 에폭 12 |  반복 181 / 1327 | 시간 245[s] | 퍼플렉서티 86.52
# | 에폭 12 |  반복 201 / 1327 | 시간 272[s] | 퍼플렉서티 85.91
# | 에폭 12 |  반복 221 / 1327 | 시간 300[s] | 퍼플렉서티 83.49
# | 에폭 12 |  반복 241 / 1327 | 시간 327[s] | 퍼플렉서티 78.15
# | 에폭 12 |  반복 261 / 1327 | 시간 354[s] | 퍼플렉서티 83.78
# | 에폭 12 |  반복 281 / 1327 | 시간 381[s] | 퍼플렉서티 83.01
# | 에폭 12 |  반복 301 / 1327 | 시간 408[s] | 퍼플렉서티 67.40
# | 에폭 12 |  반복 321 / 1327 | 시간 435[s] | 퍼플렉서티 55.11
# | 에폭 12 |  반복 341 / 1327 | 시간 462[s] | 퍼플렉서티 78.28
# | 에폭 12 |  반복 361 / 1327 | 시간 489[s] | 퍼플렉서티 81.61
# | 에폭 12 |  반복 381 / 1327 | 시간 516[s] | 퍼플렉서티 69.25
# | 에폭 12 |  반복 401 / 1327 | 시간 543[s] | 퍼플렉서티 77.32
# | 에폭 12 |  반복 421 / 1327 | 시간 570[s] | 퍼플렉서티 66.60
# | 에폭 12 |  반복 441 / 1327 | 시간 597[s] | 퍼플렉서티 71.83
# | 에폭 12 |  반복 461 / 1327 | 시간 624[s] | 퍼플렉서티 70.87
# | 에폭 12 |  반복 481 / 1327 | 시간 651[s] | 퍼플렉서티 71.69
# | 에폭 12 |  반복 501 / 1327 | 시간 678[s] | 퍼플렉서티 79.20
# | 에폭 12 |  반복 521 / 1327 | 시간 705[s] | 퍼플렉서티 81.85
# | 에폭 12 |  반복 541 / 1327 | 시간 732[s] | 퍼플렉서티 81.93
# | 에폭 12 |  반복 561 / 1327 | 시간 759[s] | 퍼플렉서티 68.74
# | 에폭 12 |  반복 581 / 1327 | 시간 787[s] | 퍼플렉서티 65.52
# | 에폭 12 |  반복 601 / 1327 | 시간 814[s] | 퍼플렉서티 91.34
# | 에폭 12 |  반복 621 / 1327 | 시간 842[s] | 퍼플렉서티 84.43
# | 에폭 12 |  반복 641 / 1327 | 시간 869[s] | 퍼플렉서티 76.86
# | 에폭 12 |  반복 661 / 1327 | 시간 896[s] | 퍼플렉서티 70.93
# | 에폭 12 |  반복 681 / 1327 | 시간 923[s] | 퍼플렉서티 62.46
# | 에폭 12 |  반복 701 / 1327 | 시간 950[s] | 퍼플렉서티 73.94
# | 에폭 12 |  반복 721 / 1327 | 시간 978[s] | 퍼플렉서티 73.80
# | 에폭 12 |  반복 741 / 1327 | 시간 1005[s] | 퍼플렉서티 67.11
# | 에폭 12 |  반복 761 / 1327 | 시간 1032[s] | 퍼플렉서티 59.45
# | 에폭 12 |  반복 781 / 1327 | 시간 1059[s] | 퍼플렉서티 65.31
# | 에폭 12 |  반복 801 / 1327 | 시간 1087[s] | 퍼플렉서티 74.45
# | 에폭 12 |  반복 821 / 1327 | 시간 1114[s] | 퍼플렉서티 74.57
# | 에폭 12 |  반복 841 / 1327 | 시간 1141[s] | 퍼플렉서티 74.00
# | 에폭 12 |  반복 861 / 1327 | 시간 1168[s] | 퍼플렉서티 72.24
# | 에폭 12 |  반복 881 / 1327 | 시간 1195[s] | 퍼플렉서티 67.92
# | 에폭 12 |  반복 901 / 1327 | 시간 1221[s] | 퍼플렉서티 85.04
# | 에폭 12 |  반복 921 / 1327 | 시간 1248[s] | 퍼플렉서티 76.86
# | 에폭 12 |  반복 941 / 1327 | 시간 1275[s] | 퍼플렉서티 80.63
# | 에폭 12 |  반복 961 / 1327 | 시간 1302[s] | 퍼플렉서티 86.39
# | 에폭 12 |  반복 981 / 1327 | 시간 1328[s] | 퍼플렉서티 82.96
# | 에폭 12 |  반복 1001 / 1327 | 시간 1355[s] | 퍼플렉서티 69.91
# | 에폭 12 |  반복 1021 / 1327 | 시간 1382[s] | 퍼플렉서티 83.14
# | 에폭 12 |  반복 1041 / 1327 | 시간 1409[s] | 퍼플렉서티 71.27
# | 에폭 12 |  반복 1061 / 1327 | 시간 1436[s] | 퍼플렉서티 67.89
# | 에폭 12 |  반복 1081 / 1327 | 시간 1463[s] | 퍼플렉서티 55.14
# | 에폭 12 |  반복 1101 / 1327 | 시간 1490[s] | 퍼플렉서티 57.15
# | 에폭 12 |  반복 1121 / 1327 | 시간 1517[s] | 퍼플렉서티 78.40
# | 에폭 12 |  반복 1141 / 1327 | 시간 1544[s] | 퍼플렉서티 74.42
# | 에폭 12 |  반복 1161 / 1327 | 시간 1572[s] | 퍼플렉서티 63.54
# | 에폭 12 |  반복 1181 / 1327 | 시간 1599[s] | 퍼플렉서티 70.67
# | 에폭 12 |  반복 1201 / 1327 | 시간 1626[s] | 퍼플렉서티 58.47
# | 에폭 12 |  반복 1221 / 1327 | 시간 1653[s] | 퍼플렉서티 58.30
# | 에폭 12 |  반복 1241 / 1327 | 시간 1680[s] | 퍼플렉서티 69.70
# | 에폭 12 |  반복 1261 / 1327 | 시간 1708[s] | 퍼플렉서티 67.24
# | 에폭 12 |  반복 1281 / 1327 | 시간 1735[s] | 퍼플렉서티 67.34
# | 에폭 12 |  반복 1301 / 1327 | 시간 1762[s] | 퍼플렉서티 85.09
# | 에폭 12 |  반복 1321 / 1327 | 시간 1789[s] | 퍼플렉서티 83.97
# 퍼플렉서티 평가 중 ...
# 209 / 210
# 검증 퍼플렉서티:  89.18274356785997
# --------------------------------------------------
# | 에폭 13 |  반복 1 / 1327 | 시간 1[s] | 퍼플렉서티 126.02
# | 에폭 13 |  반복 21 / 1327 | 시간 28[s] | 퍼플렉서티 73.18
# | 에폭 13 |  반복 41 / 1327 | 시간 55[s] | 퍼플렉서티 70.99
# | 에폭 13 |  반복 61 / 1327 | 시간 82[s] | 퍼플렉서티 69.17
# | 에폭 13 |  반복 81 / 1327 | 시간 109[s] | 퍼플렉서티 60.71
# | 에폭 13 |  반복 101 / 1327 | 시간 136[s] | 퍼플렉서티 59.38
# | 에폭 13 |  반복 121 / 1327 | 시간 162[s] | 퍼플렉서티 64.62
# | 에폭 13 |  반복 141 / 1327 | 시간 190[s] | 퍼플렉서티 68.03
# | 에폭 13 |  반복 161 / 1327 | 시간 217[s] | 퍼플렉서티 79.17
# | 에폭 13 |  반복 181 / 1327 | 시간 244[s] | 퍼플렉서티 83.71
# | 에폭 13 |  반복 201 / 1327 | 시간 271[s] | 퍼플렉서티 82.58
# | 에폭 13 |  반복 221 / 1327 | 시간 297[s] | 퍼플렉서티 81.08
# | 에폭 13 |  반복 241 / 1327 | 시간 324[s] | 퍼플렉서티 77.51
# | 에폭 13 |  반복 261 / 1327 | 시간 351[s] | 퍼플렉서티 80.62
# | 에폭 13 |  반복 281 / 1327 | 시간 378[s] | 퍼플렉서티 79.11
# | 에폭 13 |  반복 301 / 1327 | 시간 405[s] | 퍼플렉서티 65.22
# | 에폭 13 |  반복 321 / 1327 | 시간 432[s] | 퍼플렉서티 54.35
# | 에폭 13 |  반복 341 / 1327 | 시간 459[s] | 퍼플렉서티 76.90
# | 에폭 13 |  반복 361 / 1327 | 시간 486[s] | 퍼플렉서티 80.11
# | 에폭 13 |  반복 381 / 1327 | 시간 513[s] | 퍼플렉서티 66.44
# | 에폭 13 |  반복 401 / 1327 | 시간 539[s] | 퍼플렉서티 74.90
# | 에폭 13 |  반복 421 / 1327 | 시간 566[s] | 퍼플렉서티 64.39
# | 에폭 13 |  반복 441 / 1327 | 시간 592[s] | 퍼플렉서티 69.43
# | 에폭 13 |  반복 461 / 1327 | 시간 619[s] | 퍼플렉서티 69.19
# | 에폭 13 |  반복 481 / 1327 | 시간 646[s] | 퍼플렉서티 70.06
# | 에폭 13 |  반복 501 / 1327 | 시간 673[s] | 퍼플렉서티 76.24
# | 에폭 13 |  반복 521 / 1327 | 시간 700[s] | 퍼플렉서티 79.21
# | 에폭 13 |  반복 541 / 1327 | 시간 727[s] | 퍼플렉서티 80.16
# | 에폭 13 |  반복 561 / 1327 | 시간 755[s] | 퍼플렉서티 66.58
# | 에폭 13 |  반복 581 / 1327 | 시간 782[s] | 퍼플렉서티 62.91
# | 에폭 13 |  반복 601 / 1327 | 시간 809[s] | 퍼플렉서티 87.51
# | 에폭 13 |  반복 621 / 1327 | 시간 836[s] | 퍼플렉서티 81.71
# | 에폭 13 |  반복 641 / 1327 | 시간 863[s] | 퍼플렉서티 76.03
# | 에폭 13 |  반복 661 / 1327 | 시간 890[s] | 퍼플렉서티 70.99
# | 에폭 13 |  반복 681 / 1327 | 시간 917[s] | 퍼플렉서티 60.83
# | 에폭 13 |  반복 701 / 1327 | 시간 943[s] | 퍼플렉서티 71.98
# | 에폭 13 |  반복 721 / 1327 | 시간 970[s] | 퍼플렉서티 73.52
# | 에폭 13 |  반복 741 / 1327 | 시간 998[s] | 퍼플렉서티 64.97
# | 에폭 13 |  반복 761 / 1327 | 시간 1024[s] | 퍼플렉서티 58.59
# | 에폭 13 |  반복 781 / 1327 | 시간 1051[s] | 퍼플렉서티 64.43
# | 에폭 13 |  반복 801 / 1327 | 시간 1078[s] | 퍼플렉서티 71.96
# | 에폭 13 |  반복 821 / 1327 | 시간 1105[s] | 퍼플렉서티 71.67
# | 에폭 13 |  반복 841 / 1327 | 시간 1132[s] | 퍼플렉서티 71.42
# | 에폭 13 |  반복 861 / 1327 | 시간 1158[s] | 퍼플렉서티 70.62
# | 에폭 13 |  반복 881 / 1327 | 시간 1185[s] | 퍼플렉서티 65.47
# | 에폭 13 |  반복 901 / 1327 | 시간 1211[s] | 퍼플렉서티 83.42
# | 에폭 13 |  반복 921 / 1327 | 시간 1238[s] | 퍼플렉서티 73.27
# | 에폭 13 |  반복 941 / 1327 | 시간 1265[s] | 퍼플렉서티 78.39
# | 에폭 13 |  반복 961 / 1327 | 시간 1292[s] | 퍼플렉서티 84.31
# | 에폭 13 |  반복 981 / 1327 | 시간 1319[s] | 퍼플렉서티 79.36
# | 에폭 13 |  반복 1001 / 1327 | 시간 1346[s] | 퍼플렉서티 68.11
# | 에폭 13 |  반복 1021 / 1327 | 시간 1372[s] | 퍼플렉서티 80.08
# | 에폭 13 |  반복 1041 / 1327 | 시간 1399[s] | 퍼플렉서티 69.65
# | 에폭 13 |  반복 1061 / 1327 | 시간 1425[s] | 퍼플렉서티 66.15
# | 에폭 13 |  반복 1081 / 1327 | 시간 1452[s] | 퍼플렉서티 53.72
# | 에폭 13 |  반복 1101 / 1327 | 시간 1478[s] | 퍼플렉서티 56.72
# | 에폭 13 |  반복 1121 / 1327 | 시간 1505[s] | 퍼플렉서티 76.93
# | 에폭 13 |  반복 1141 / 1327 | 시간 1531[s] | 퍼플렉서티 72.55
# | 에폭 13 |  반복 1161 / 1327 | 시간 1558[s] | 퍼플렉서티 60.97
# | 에폭 13 |  반복 1181 / 1327 | 시간 1584[s] | 퍼플렉서티 69.06
# | 에폭 13 |  반복 1201 / 1327 | 시간 1611[s] | 퍼플렉서티 57.47
# | 에폭 13 |  반복 1221 / 1327 | 시간 1637[s] | 퍼플렉서티 57.17
# | 에폭 13 |  반복 1241 / 1327 | 시간 1664[s] | 퍼플렉서티 68.99
# | 에폭 13 |  반복 1261 / 1327 | 시간 1691[s] | 퍼플렉서티 65.46
# | 에폭 13 |  반복 1281 / 1327 | 시간 1718[s] | 퍼플렉서티 66.15
# | 에폭 13 |  반복 1301 / 1327 | 시간 1745[s] | 퍼플렉서티 82.40
# | 에폭 13 |  반복 1321 / 1327 | 시간 1772[s] | 퍼플렉서티 81.01
# 퍼플렉서티 평가 중 ...
# 209 / 210
# 검증 퍼플렉서티:  88.19025936893354
# --------------------------------------------------
# | 에폭 14 |  반복 1 / 1327 | 시간 1[s] | 퍼플렉서티 120.10
# | 에폭 14 |  반복 21 / 1327 | 시간 28[s] | 퍼플렉서티 71.38
# | 에폭 14 |  반복 41 / 1327 | 시간 55[s] | 퍼플렉서티 69.40
# | 에폭 14 |  반복 61 / 1327 | 시간 82[s] | 퍼플렉서티 67.61
# | 에폭 14 |  반복 81 / 1327 | 시간 109[s] | 퍼플렉서티 58.29
# | 에폭 14 |  반복 101 / 1327 | 시간 135[s] | 퍼플렉서티 56.80
# | 에폭 14 |  반복 121 / 1327 | 시간 162[s] | 퍼플렉서티 63.21
# | 에폭 14 |  반복 141 / 1327 | 시간 188[s] | 퍼플렉서티 66.73
# | 에폭 14 |  반복 161 / 1327 | 시간 215[s] | 퍼플렉서티 78.19
# | 에폭 14 |  반복 181 / 1327 | 시간 242[s] | 퍼플렉서티 81.84
# | 에폭 14 |  반복 201 / 1327 | 시간 269[s] | 퍼플렉서티 81.59
# | 에폭 14 |  반복 221 / 1327 | 시간 296[s] | 퍼플렉서티 78.78
# | 에폭 14 |  반복 241 / 1327 | 시간 323[s] | 퍼플렉서티 74.43
# | 에폭 14 |  반복 261 / 1327 | 시간 350[s] | 퍼플렉서티 77.83
# | 에폭 14 |  반복 281 / 1327 | 시간 377[s] | 퍼플렉서티 76.61
# | 에폭 14 |  반복 301 / 1327 | 시간 404[s] | 퍼플렉서티 63.41
# | 에폭 14 |  반복 321 / 1327 | 시간 430[s] | 퍼플렉서티 52.43
# | 에폭 14 |  반복 341 / 1327 | 시간 458[s] | 퍼플렉서티 73.42
# | 에폭 14 |  반복 361 / 1327 | 시간 484[s] | 퍼플렉서티 78.61
# | 에폭 14 |  반복 381 / 1327 | 시간 511[s] | 퍼플렉서티 65.16
# | 에폭 14 |  반복 401 / 1327 | 시간 538[s] | 퍼플렉서티 72.57
# | 에폭 14 |  반복 421 / 1327 | 시간 565[s] | 퍼플렉서티 63.12
# | 에폭 14 |  반복 441 / 1327 | 시간 592[s] | 퍼플렉서티 67.11
# | 에폭 14 |  반복 461 / 1327 | 시간 619[s] | 퍼플렉서티 67.44
# | 에폭 14 |  반복 481 / 1327 | 시간 646[s] | 퍼플렉서티 67.98
# | 에폭 14 |  반복 501 / 1327 | 시간 673[s] | 퍼플렉서티 76.00
# | 에폭 14 |  반복 521 / 1327 | 시간 700[s] | 퍼플렉서티 77.44
# | 에폭 14 |  반복 541 / 1327 | 시간 727[s] | 퍼플렉서티 78.41
# | 에폭 14 |  반복 561 / 1327 | 시간 754[s] | 퍼플렉서티 64.97
# | 에폭 14 |  반복 581 / 1327 | 시간 780[s] | 퍼플렉서티 60.76
# | 에폭 14 |  반복 601 / 1327 | 시간 807[s] | 퍼플렉서티 85.55
# | 에폭 14 |  반복 621 / 1327 | 시간 834[s] | 퍼플렉서티 80.49
# | 에폭 14 |  반복 641 / 1327 | 시간 861[s] | 퍼플렉서티 74.45
# | 에폭 14 |  반복 661 / 1327 | 시간 887[s] | 퍼플렉서티 67.23
# | 에폭 14 |  반복 681 / 1327 | 시간 914[s] | 퍼플렉서티 59.65
# | 에폭 14 |  반복 701 / 1327 | 시간 941[s] | 퍼플렉서티 69.86
# | 에폭 14 |  반복 721 / 1327 | 시간 968[s] | 퍼플렉서티 69.54
# | 에폭 14 |  반복 741 / 1327 | 시간 995[s] | 퍼플렉서티 63.21
# | 에폭 14 |  반복 761 / 1327 | 시간 1022[s] | 퍼플렉서티 56.33
# ...
# | 에폭 36 |  반복 721 / 1327 | 시간 975[s] | 퍼플렉서티 42.39
# | 에폭 36 |  반복 741 / 1327 | 시간 1002[s] | 퍼플렉서티 38.79
# | 에폭 36 |  반복 761 / 1327 | 시간 1029[s] | 퍼플렉서티 34.13
# | 에폭 36 |  반복 781 / 1327 | 시간 1056[s] | 퍼플렉서티 37.99
# | 에폭 36 |  반복 801 / 1327 | 시간 1083[s] | 퍼플렉서티 41.75
# | 에폭 36 |  반복 821 / 1327 | 시간 1110[s] | 퍼플렉서티 42.68
# | 에폭 36 |  반복 841 / 1327 | 시간 1138[s] | 퍼플렉서티 41.78
# | 에폭 36 |  반복 861 / 1327 | 시간 1164[s] | 퍼플렉서티 41.75
# | 에폭 36 |  반복 881 / 1327 | 시간 1192[s] | 퍼플렉서티 39.21
# | 에폭 36 |  반복 901 / 1327 | 시간 1218[s] | 퍼플렉서티 49.44
# | 에폭 36 |  반복 921 / 1327 | 시간 1246[s] | 퍼플렉서티 44.27
# | 에폭 36 |  반복 941 / 1327 | 시간 1273[s] | 퍼플렉서티 46.73
# | 에폭 36 |  반복 961 / 1327 | 시간 1300[s] | 퍼플렉서티 49.02
# | 에폭 36 |  반복 981 / 1327 | 시간 1326[s] | 퍼플렉서티 46.50
# | 에폭 36 |  반복 1001 / 1327 | 시간 1353[s] | 퍼플렉서티 39.81
# | 에폭 36 |  반복 1021 / 1327 | 시간 1380[s] | 퍼플렉서티 46.96
# | 에폭 36 |  반복 1041 / 1327 | 시간 1407[s] | 퍼플렉서티 41.33
# | 에폭 36 |  반복 1061 / 1327 | 시간 1434[s] | 퍼플렉서티 38.56
# | 에폭 36 |  반복 1081 / 1327 | 시간 1461[s] | 퍼플렉서티 31.27
# | 에폭 36 |  반복 1101 / 1327 | 시간 1488[s] | 퍼플렉서티 32.28
# | 에폭 36 |  반복 1121 / 1327 | 시간 1515[s] | 퍼플렉서티 43.86
# | 에폭 36 |  반복 1141 / 1327 | 시간 1542[s] | 퍼플렉서티 41.54
# | 에폭 36 |  반복 1161 / 1327 | 시간 1569[s] | 퍼플렉서티 35.54
# | 에폭 36 |  반복 1181 / 1327 | 시간 1596[s] | 퍼플렉서티 38.83
# | 에폭 36 |  반복 1201 / 1327 | 시간 1624[s] | 퍼플렉서티 32.86
# | 에폭 36 |  반복 1221 / 1327 | 시간 1651[s] | 퍼플렉서티 32.62
# | 에폭 36 |  반복 1241 / 1327 | 시간 1678[s] | 퍼플렉서티 39.74
# | 에폭 36 |  반복 1261 / 1327 | 시간 1706[s] | 퍼플렉서티 38.01
# | 에폭 36 |  반복 1281 / 1327 | 시간 1733[s] | 퍼플렉서티 37.76
# | 에폭 36 |  반복 1301 / 1327 | 시간 1760[s] | 퍼플렉서티 46.63
# | 에폭 36 |  반복 1321 / 1327 | 시간 1787[s] | 퍼플렉서티 45.25
# 퍼플렉서티 평가 중 ...
# 209 / 210
# 검증 퍼플렉서티:  80.43748517141088
# --------------------------------------------------
# | 에폭 37 |  반복 1 / 1327 | 시간 1[s] | 퍼플렉서티 76.97
# | 에폭 37 |  반복 21 / 1327 | 시간 28[s] | 퍼플렉서티 45.65
# | 에폭 37 |  반복 41 / 1327 | 시간 55[s] | 퍼플렉서티 44.34
# | 에폭 37 |  반복 61 / 1327 | 시간 83[s] | 퍼플렉서티 43.48
# | 에폭 37 |  반복 81 / 1327 | 시간 111[s] | 퍼플렉서티 36.90
# | 에폭 37 |  반복 101 / 1327 | 시간 138[s] | 퍼플렉서티 36.88
# | 에폭 37 |  반복 121 / 1327 | 시간 165[s] | 퍼플렉서티 39.58
# | 에폭 37 |  반복 141 / 1327 | 시간 192[s] | 퍼플렉서티 42.26
# | 에폭 37 |  반복 161 / 1327 | 시간 220[s] | 퍼플렉서티 49.02
# | 에폭 37 |  반복 181 / 1327 | 시간 247[s] | 퍼플렉서티 51.06
# | 에폭 37 |  반복 201 / 1327 | 시간 274[s] | 퍼플렉서티 51.51
# | 에폭 37 |  반복 221 / 1327 | 시간 302[s] | 퍼플렉서티 49.22
# | 에폭 37 |  반복 241 / 1327 | 시간 329[s] | 퍼플렉서티 46.32
# | 에폭 37 |  반복 261 / 1327 | 시간 356[s] | 퍼플렉서티 49.45
# | 에폭 37 |  반복 281 / 1327 | 시간 383[s] | 퍼플렉서티 47.95
# | 에폭 37 |  반복 301 / 1327 | 시간 410[s] | 퍼플렉서티 39.71
# | 에폭 37 |  반복 321 / 1327 | 시간 437[s] | 퍼플렉서티 32.57
# | 에폭 37 |  반복 341 / 1327 | 시간 465[s] | 퍼플렉서티 44.71
# | 에폭 37 |  반복 361 / 1327 | 시간 492[s] | 퍼플렉서티 47.12
# | 에폭 37 |  반복 381 / 1327 | 시간 519[s] | 퍼플렉서티 39.49
# | 에폭 37 |  반복 401 / 1327 | 시간 546[s] | 퍼플렉서티 45.55
# | 에폭 37 |  반복 421 / 1327 | 시간 573[s] | 퍼플렉서티 39.46
# | 에폭 37 |  반복 441 / 1327 | 시간 601[s] | 퍼플렉서티 40.68
# | 에폭 37 |  반복 461 / 1327 | 시간 627[s] | 퍼플렉서티 41.73
# | 에폭 37 |  반복 481 / 1327 | 시간 654[s] | 퍼플렉서티 42.13
# | 에폭 37 |  반복 501 / 1327 | 시간 681[s] | 퍼플렉서티 45.90
# | 에폭 37 |  반복 521 / 1327 | 시간 708[s] | 퍼플렉서티 47.25
# | 에폭 37 |  반복 541 / 1327 | 시간 734[s] | 퍼플렉서티 47.76
# | 에폭 37 |  반복 561 / 1327 | 시간 761[s] | 퍼플렉서티 38.91
# | 에폭 37 |  반복 581 / 1327 | 시간 788[s] | 퍼플렉서티 37.63
# | 에폭 37 |  반복 601 / 1327 | 시간 815[s] | 퍼플렉서티 53.46
# | 에폭 37 |  반복 621 / 1327 | 시간 842[s] | 퍼플렉서티 48.71
# | 에폭 37 |  반복 641 / 1327 | 시간 869[s] | 퍼플렉서티 44.05
# | 에폭 37 |  반복 661 / 1327 | 시간 895[s] | 퍼플렉서티 40.90
# | 에폭 37 |  반복 681 / 1327 | 시간 922[s] | 퍼플렉서티 35.99
# | 에폭 37 |  반복 701 / 1327 | 시간 949[s] | 퍼플렉서티 42.47
# | 에폭 37 |  반복 721 / 1327 | 시간 976[s] | 퍼플렉서티 42.63
# | 에폭 37 |  반복 741 / 1327 | 시간 1003[s] | 퍼플렉서티 39.31
# | 에폭 37 |  반복 761 / 1327 | 시간 1030[s] | 퍼플렉서티 34.08
# | 에폭 37 |  반복 781 / 1327 | 시간 1057[s] | 퍼플렉서티 37.90
# | 에폭 37 |  반복 801 / 1327 | 시간 1084[s] | 퍼플렉서티 42.11
# | 에폭 37 |  반복 821 / 1327 | 시간 1111[s] | 퍼플렉서티 42.90
# | 에폭 37 |  반복 841 / 1327 | 시간 1138[s] | 퍼플렉서티 42.16
# | 에폭 37 |  반복 861 / 1327 | 시간 1165[s] | 퍼플렉서티 42.35
# | 에폭 37 |  반복 881 / 1327 | 시간 1192[s] | 퍼플렉서티 39.62
# | 에폭 37 |  반복 901 / 1327 | 시간 1219[s] | 퍼플렉서티 49.41
# | 에폭 37 |  반복 921 / 1327 | 시간 1245[s] | 퍼플렉서티 44.45
# | 에폭 37 |  반복 941 / 1327 | 시간 1272[s] | 퍼플렉서티 47.09
# | 에폭 37 |  반복 961 / 1327 | 시간 1299[s] | 퍼플렉서티 48.84
# | 에폭 37 |  반복 981 / 1327 | 시간 1325[s] | 퍼플렉서티 46.53
# | 에폭 37 |  반복 1001 / 1327 | 시간 1352[s] | 퍼플렉서티 39.85
# | 에폭 37 |  반복 1021 / 1327 | 시간 1378[s] | 퍼플렉서티 47.32
# | 에폭 37 |  반복 1041 / 1327 | 시간 1405[s] | 퍼플렉서티 40.84
# | 에폭 37 |  반복 1061 / 1327 | 시간 1432[s] | 퍼플렉서티 38.25
# | 에폭 37 |  반복 1081 / 1327 | 시간 1459[s] | 퍼플렉서티 31.23
# | 에폭 37 |  반복 1101 / 1327 | 시간 1486[s] | 퍼플렉서티 32.45
# | 에폭 37 |  반복 1121 / 1327 | 시간 1513[s] | 퍼플렉서티 44.12
# | 에폭 37 |  반복 1141 / 1327 | 시간 1539[s] | 퍼플렉서티 42.66
# | 에폭 37 |  반복 1161 / 1327 | 시간 1566[s] | 퍼플렉서티 34.91
# | 에폭 37 |  반복 1181 / 1327 | 시간 1593[s] | 퍼플렉서티 38.54
# | 에폭 37 |  반복 1201 / 1327 | 시간 1620[s] | 퍼플렉서티 32.63
# | 에폭 37 |  반복 1221 / 1327 | 시간 1647[s] | 퍼플렉서티 32.67
# | 에폭 37 |  반복 1241 / 1327 | 시간 1674[s] | 퍼플렉서티 39.68
# | 에폭 37 |  반복 1261 / 1327 | 시간 1700[s] | 퍼플렉서티 37.26
# | 에폭 37 |  반복 1281 / 1327 | 시간 1727[s] | 퍼플렉서티 37.85
# | 에폭 37 |  반복 1301 / 1327 | 시간 1754[s] | 퍼플렉서티 46.77
# | 에폭 37 |  반복 1321 / 1327 | 시간 1781[s] | 퍼플렉서티 45.65
# 퍼플렉서티 평가 중 ...
# 209 / 210
# 검증 퍼플렉서티:  80.42720697472456
# --------------------------------------------------
# | 에폭 38 |  반복 1 / 1327 | 시간 1[s] | 퍼플렉서티 70.39
# | 에폭 38 |  반복 21 / 1327 | 시간 28[s] | 퍼플렉서티 45.72
# | 에폭 38 |  반복 41 / 1327 | 시간 55[s] | 퍼플렉서티 44.02
# | 에폭 38 |  반복 61 / 1327 | 시간 83[s] | 퍼플렉서티 42.76
# | 에폭 38 |  반복 81 / 1327 | 시간 110[s] | 퍼플렉서티 36.80
# | 에폭 38 |  반복 101 / 1327 | 시간 137[s] | 퍼플렉서티 36.92
# | 에폭 38 |  반복 121 / 1327 | 시간 164[s] | 퍼플렉서티 39.40
# | 에폭 38 |  반복 141 / 1327 | 시간 191[s] | 퍼플렉서티 41.20
# | 에폭 38 |  반복 161 / 1327 | 시간 218[s] | 퍼플렉서티 48.73
# | 에폭 38 |  반복 181 / 1327 | 시간 246[s] | 퍼플렉서티 51.20
# | 에폭 38 |  반복 201 / 1327 | 시간 273[s] | 퍼플렉서티 51.00
# | 에폭 38 |  반복 221 / 1327 | 시간 300[s] | 퍼플렉서티 49.60
# | 에폭 38 |  반복 241 / 1327 | 시간 327[s] | 퍼플렉서티 46.77
# | 에폭 38 |  반복 261 / 1327 | 시간 354[s] | 퍼플렉서티 49.66
# | 에폭 38 |  반복 281 / 1327 | 시간 380[s] | 퍼플렉서티 48.12
# | 에폭 38 |  반복 301 / 1327 | 시간 407[s] | 퍼플렉서티 39.52
# | 에폭 38 |  반복 321 / 1327 | 시간 434[s] | 퍼플렉서티 32.43
# | 에폭 38 |  반복 341 / 1327 | 시간 460[s] | 퍼플렉서티 46.30
# | 에폭 38 |  반복 361 / 1327 | 시간 487[s] | 퍼플렉서티 46.80
# | 에폭 38 |  반복 381 / 1327 | 시간 514[s] | 퍼플렉서티 39.40
# | 에폭 38 |  반복 401 / 1327 | 시간 540[s] | 퍼플렉서티 45.28
# | 에폭 38 |  반복 421 / 1327 | 시간 567[s] | 퍼플렉서티 39.31
# | 에폭 38 |  반복 441 / 1327 | 시간 594[s] | 퍼플렉서티 41.06
# | 에폭 38 |  반복 461 / 1327 | 시간 621[s] | 퍼플렉서티 42.23
# | 에폭 38 |  반복 481 / 1327 | 시간 648[s] | 퍼플렉서티 41.61
# | 에폭 38 |  반복 501 / 1327 | 시간 675[s] | 퍼플렉서티 44.54
# | 에폭 38 |  반복 521 / 1327 | 시간 702[s] | 퍼플렉서티 47.08
# | 에폭 38 |  반복 541 / 1327 | 시간 728[s] | 퍼플렉서티 48.59
# | 에폭 38 |  반복 561 / 1327 | 시간 755[s] | 퍼플렉서티 39.39
# | 에폭 38 |  반복 581 / 1327 | 시간 782[s] | 퍼플렉서티 37.20
# | 에폭 38 |  반복 601 / 1327 | 시간 810[s] | 퍼플렉서티 53.26
# | 에폭 38 |  반복 621 / 1327 | 시간 837[s] | 퍼플렉서티 48.74
# | 에폭 38 |  반복 641 / 1327 | 시간 863[s] | 퍼플렉서티 45.21
# | 에폭 38 |  반복 661 / 1327 | 시간 890[s] | 퍼플렉서티 40.89
# | 에폭 38 |  반복 681 / 1327 | 시간 917[s] | 퍼플렉서티 36.00
# | 에폭 38 |  반복 701 / 1327 | 시간 945[s] | 퍼플렉서티 42.69
# | 에폭 38 |  반복 721 / 1327 | 시간 972[s] | 퍼플렉서티 42.11
# | 에폭 38 |  반복 741 / 1327 | 시간 999[s] | 퍼플렉서티 38.59
# | 에폭 38 |  반복 761 / 1327 | 시간 1026[s] | 퍼플렉서티 34.39
# | 에폭 38 |  반복 781 / 1327 | 시간 1054[s] | 퍼플렉서티 38.45
# | 에폭 38 |  반복 801 / 1327 | 시간 1081[s] | 퍼플렉서티 41.95
# | 에폭 38 |  반복 821 / 1327 | 시간 1108[s] | 퍼플렉서티 42.78
# | 에폭 38 |  반복 841 / 1327 | 시간 1135[s] | 퍼플렉서티 42.27
# | 에폭 38 |  반복 861 / 1327 | 시간 1162[s] | 퍼플렉서티 41.97
# | 에폭 38 |  반복 881 / 1327 | 시간 1189[s] | 퍼플렉서티 39.65
# | 에폭 38 |  반복 901 / 1327 | 시간 1216[s] | 퍼플렉서티 49.32
# | 에폭 38 |  반복 921 / 1327 | 시간 1243[s] | 퍼플렉서티 43.58
# | 에폭 38 |  반복 941 / 1327 | 시간 1270[s] | 퍼플렉서티 46.59
# | 에폭 38 |  반복 961 / 1327 | 시간 1297[s] | 퍼플렉서티 48.48
# | 에폭 38 |  반복 981 / 1327 | 시간 1324[s] | 퍼플렉서티 46.15
# | 에폭 38 |  반복 1001 / 1327 | 시간 1351[s] | 퍼플렉서티 40.37
# | 에폭 38 |  반복 1021 / 1327 | 시간 1378[s] | 퍼플렉서티 46.73
# | 에폭 38 |  반복 1041 / 1327 | 시간 1406[s] | 퍼플렉서티 41.21
# | 에폭 38 |  반복 1061 / 1327 | 시간 1432[s] | 퍼플렉서티 37.94
# | 에폭 38 |  반복 1081 / 1327 | 시간 1459[s] | 퍼플렉서티 31.53
# | 에폭 38 |  반복 1101 / 1327 | 시간 1486[s] | 퍼플렉서티 32.78
# | 에폭 38 |  반복 1121 / 1327 | 시간 1513[s] | 퍼플렉서티 44.11
# | 에폭 38 |  반복 1141 / 1327 | 시간 1540[s] | 퍼플렉서티 42.04
# | 에폭 38 |  반복 1161 / 1327 | 시간 1566[s] | 퍼플렉서티 35.37
# | 에폭 38 |  반복 1181 / 1327 | 시간 1593[s] | 퍼플렉서티 38.88
# | 에폭 38 |  반복 1201 / 1327 | 시간 1620[s] | 퍼플렉서티 33.04
# | 에폭 38 |  반복 1221 / 1327 | 시간 1647[s] | 퍼플렉서티 32.88
# | 에폭 38 |  반복 1241 / 1327 | 시간 1675[s] | 퍼플렉서티 39.77
# | 에폭 38 |  반복 1261 / 1327 | 시간 1702[s] | 퍼플렉서티 37.42
# | 에폭 38 |  반복 1281 / 1327 | 시간 1729[s] | 퍼플렉서티 37.95
# | 에폭 38 |  반복 1301 / 1327 | 시간 1757[s] | 퍼플렉서티 46.30
# | 에폭 38 |  반복 1321 / 1327 | 시간 1783[s] | 퍼플렉서티 45.16
# 퍼플렉서티 평가 중 ...
# 209 / 210
# 검증 퍼플렉서티:  80.39252111353164
# --------------------------------------------------
# | 에폭 39 |  반복 1 / 1327 | 시간 1[s] | 퍼플렉서티 72.95
# | 에폭 39 |  반복 21 / 1327 | 시간 28[s] | 퍼플렉서티 45.19
# | 에폭 39 |  반복 41 / 1327 | 시간 55[s] | 퍼플렉서티 44.33
# | 에폭 39 |  반복 61 / 1327 | 시간 82[s] | 퍼플렉서티 42.48
# | 에폭 39 |  반복 81 / 1327 | 시간 110[s] | 퍼플렉서티 36.76
# | 에폭 39 |  반복 101 / 1327 | 시간 137[s] | 퍼플렉서티 36.70
# | 에폭 39 |  반복 121 / 1327 | 시간 164[s] | 퍼플렉서티 39.42
# | 에폭 39 |  반복 141 / 1327 | 시간 191[s] | 퍼플렉서티 41.65
# | 에폭 39 |  반복 161 / 1327 | 시간 218[s] | 퍼플렉서티 49.35
# | 에폭 39 |  반복 181 / 1327 | 시간 245[s] | 퍼플렉서티 50.92
# | 에폭 39 |  반복 201 / 1327 | 시간 272[s] | 퍼플렉서티 50.88
# | 에폭 39 |  반복 221 / 1327 | 시간 300[s] | 퍼플렉서티 48.68
# | 에폭 39 |  반복 241 / 1327 | 시간 327[s] | 퍼플렉서티 45.97
# | 에폭 39 |  반복 261 / 1327 | 시간 354[s] | 퍼플렉서티 48.98
# | 에폭 39 |  반복 281 / 1327 | 시간 381[s] | 퍼플렉서티 48.65
# | 에폭 39 |  반복 301 / 1327 | 시간 409[s] | 퍼플렉서티 39.47
# | 에폭 39 |  반복 321 / 1327 | 시간 436[s] | 퍼플렉서티 32.91
# | 에폭 39 |  반복 341 / 1327 | 시간 463[s] | 퍼플렉서티 46.00
# | 에폭 39 |  반복 361 / 1327 | 시간 490[s] | 퍼플렉서티 47.15
# | 에폭 39 |  반복 381 / 1327 | 시간 518[s] | 퍼플렉서티 40.66
# | 에폭 39 |  반복 401 / 1327 | 시간 545[s] | 퍼플렉서티 45.17
# | 에폭 39 |  반복 421 / 1327 | 시간 571[s] | 퍼플렉서티 38.85
# | 에폭 39 |  반복 441 / 1327 | 시간 599[s] | 퍼플렉서티 41.08
# | 에폭 39 |  반복 461 / 1327 | 시간 625[s] | 퍼플렉서티 41.12
# | 에폭 39 |  반복 481 / 1327 | 시간 652[s] | 퍼플렉서티 41.78
# | 에폭 39 |  반복 501 / 1327 | 시간 679[s] | 퍼플렉서티 46.04
# | 에폭 39 |  반복 521 / 1327 | 시간 705[s] | 퍼플렉서티 46.78
# | 에폭 39 |  반복 541 / 1327 | 시간 732[s] | 퍼플렉서티 47.88
# | 에폭 39 |  반복 561 / 1327 | 시간 759[s] | 퍼플렉서티 38.93
# | 에폭 39 |  반복 581 / 1327 | 시간 786[s] | 퍼플렉서티 37.83
# | 에폭 39 |  반복 601 / 1327 | 시간 812[s] | 퍼플렉서티 53.54
# | 에폭 39 |  반복 621 / 1327 | 시간 839[s] | 퍼플렉서티 48.24
# | 에폭 39 |  반복 641 / 1327 | 시간 866[s] | 퍼플렉서티 45.01
# | 에폭 39 |  반복 661 / 1327 | 시간 893[s] | 퍼플렉서티 40.56
# | 에폭 39 |  반복 681 / 1327 | 시간 920[s] | 퍼플렉서티 36.29
# | 에폭 39 |  반복 701 / 1327 | 시간 947[s] | 퍼플렉서티 43.48
# | 에폭 39 |  반복 721 / 1327 | 시간 974[s] | 퍼플렉서티 42.81
# | 에폭 39 |  반복 741 / 1327 | 시간 1001[s] | 퍼플렉서티 39.08
# | 에폭 39 |  반복 761 / 1327 | 시간 1028[s] | 퍼플렉서티 34.67
# | 에폭 39 |  반복 781 / 1327 | 시간 1055[s] | 퍼플렉서티 37.89
# | 에폭 39 |  반복 801 / 1327 | 시간 1082[s] | 퍼플렉서티 41.59
# | 에폭 39 |  반복 821 / 1327 | 시간 1109[s] | 퍼플렉서티 43.35
# | 에폭 39 |  반복 841 / 1327 | 시간 1136[s] | 퍼플렉서티 42.05
# | 에폭 39 |  반복 861 / 1327 | 시간 1163[s] | 퍼플렉서티 42.04
# | 에폭 39 |  반복 881 / 1327 | 시간 1190[s] | 퍼플렉서티 38.82
# | 에폭 39 |  반복 901 / 1327 | 시간 1217[s] | 퍼플렉서티 49.37
# | 에폭 39 |  반복 921 / 1327 | 시간 1244[s] | 퍼플렉서티 44.32
# | 에폭 39 |  반복 941 / 1327 | 시간 1271[s] | 퍼플렉서티 46.80
# | 에폭 39 |  반복 961 / 1327 | 시간 1298[s] | 퍼플렉서티 48.70
# | 에폭 39 |  반복 981 / 1327 | 시간 1325[s] | 퍼플렉서티 46.19
# | 에폭 39 |  반복 1001 / 1327 | 시간 1352[s] | 퍼플렉서티 39.77
# | 에폭 39 |  반복 1021 / 1327 | 시간 1379[s] | 퍼플렉서티 46.74
# | 에폭 39 |  반복 1041 / 1327 | 시간 1405[s] | 퍼플렉서티 41.04
# | 에폭 39 |  반복 1061 / 1327 | 시간 1432[s] | 퍼플렉서티 37.91
# | 에폭 39 |  반복 1081 / 1327 | 시간 1459[s] | 퍼플렉서티 31.56
# | 에폭 39 |  반복 1101 / 1327 | 시간 1486[s] | 퍼플렉서티 32.42
# | 에폭 39 |  반복 1121 / 1327 | 시간 1514[s] | 퍼플렉서티 43.71
# | 에폭 39 |  반복 1141 / 1327 | 시간 1541[s] | 퍼플렉서티 41.57
# | 에폭 39 |  반복 1161 / 1327 | 시간 1568[s] | 퍼플렉서티 35.08
# | 에폭 39 |  반복 1181 / 1327 | 시간 1595[s] | 퍼플렉서티 38.93
# | 에폭 39 |  반복 1201 / 1327 | 시간 1621[s] | 퍼플렉서티 32.58
# | 에폭 39 |  반복 1221 / 1327 | 시간 1648[s] | 퍼플렉서티 31.99
# | 에폭 39 |  반복 1241 / 1327 | 시간 1675[s] | 퍼플렉서티 39.63
# | 에폭 39 |  반복 1261 / 1327 | 시간 1703[s] | 퍼플렉서티 38.16
# | 에폭 39 |  반복 1281 / 1327 | 시간 1730[s] | 퍼플렉서티 38.09
# | 에폭 39 |  반복 1301 / 1327 | 시간 1757[s] | 퍼플렉서티 46.32
# | 에폭 39 |  반복 1321 / 1327 | 시간 1785[s] | 퍼플렉서티 45.21
# 퍼플렉서티 평가 중 ...
# 209 / 210
# 검증 퍼플렉서티:  80.3754244068049
# --------------------------------------------------
# | 에폭 40 |  반복 1 / 1327 | 시간 1[s] | 퍼플렉서티 75.74
# | 에폭 40 |  반복 21 / 1327 | 시간 28[s] | 퍼플렉서티 45.52
# | 에폭 40 |  반복 41 / 1327 | 시간 55[s] | 퍼플렉서티 44.69
# | 에폭 40 |  반복 61 / 1327 | 시간 82[s] | 퍼플렉서티 42.10
# | 에폭 40 |  반복 81 / 1327 | 시간 109[s] | 퍼플렉서티 36.79
# | 에폭 40 |  반복 101 / 1327 | 시간 136[s] | 퍼플렉서티 36.32
# | 에폭 40 |  반복 121 / 1327 | 시간 163[s] | 퍼플렉서티 39.28
# | 에폭 40 |  반복 141 / 1327 | 시간 190[s] | 퍼플렉서티 41.36
# | 에폭 40 |  반복 161 / 1327 | 시간 217[s] | 퍼플렉서티 48.87
# | 에폭 40 |  반복 181 / 1327 | 시간 244[s] | 퍼플렉서티 51.28
# | 에폭 40 |  반복 201 / 1327 | 시간 271[s] | 퍼플렉서티 51.19
# | 에폭 40 |  반복 221 / 1327 | 시간 298[s] | 퍼플렉서티 49.22
# | 에폭 40 |  반복 241 / 1327 | 시간 325[s] | 퍼플렉서티 46.12
# | 에폭 40 |  반복 261 / 1327 | 시간 352[s] | 퍼플렉서티 49.10
# | 에폭 40 |  반복 281 / 1327 | 시간 379[s] | 퍼플렉서티 48.45
# | 에폭 40 |  반복 301 / 1327 | 시간 406[s] | 퍼플렉서티 39.21
# | 에폭 40 |  반복 321 / 1327 | 시간 433[s] | 퍼플렉서티 32.83
# | 에폭 40 |  반복 341 / 1327 | 시간 460[s] | 퍼플렉서티 45.36
# | 에폭 40 |  반복 361 / 1327 | 시간 487[s] | 퍼플렉서티 46.52
# | 에폭 40 |  반복 381 / 1327 | 시간 514[s] | 퍼플렉서티 40.24
# | 에폭 40 |  반복 401 / 1327 | 시간 541[s] | 퍼플렉서티 44.85
# | 에폭 40 |  반복 421 / 1327 | 시간 568[s] | 퍼플렉서티 39.48
# | 에폭 40 |  반복 441 / 1327 | 시간 595[s] | 퍼플렉서티 40.94
# | 에폭 40 |  반복 461 / 1327 | 시간 621[s] | 퍼플렉서티 41.07
# | 에폭 40 |  반복 481 / 1327 | 시간 648[s] | 퍼플렉서티 41.83
# | 에폭 40 |  반복 501 / 1327 | 시간 675[s] | 퍼플렉서티 45.57
# | 에폭 40 |  반복 521 / 1327 | 시간 702[s] | 퍼플렉서티 46.82
# | 에폭 40 |  반복 541 / 1327 | 시간 729[s] | 퍼플렉서티 48.09
# | 에폭 40 |  반복 561 / 1327 | 시간 755[s] | 퍼플렉서티 38.94
# | 에폭 40 |  반복 581 / 1327 | 시간 782[s] | 퍼플렉서티 37.60
# | 에폭 40 |  반복 601 / 1327 | 시간 809[s] | 퍼플렉서티 52.90
# | 에폭 40 |  반복 621 / 1327 | 시간 836[s] | 퍼플렉서티 48.83
# | 에폭 40 |  반복 641 / 1327 | 시간 862[s] | 퍼플렉서티 44.79
# | 에폭 40 |  반복 661 / 1327 | 시간 889[s] | 퍼플렉서티 40.56
# | 에폭 40 |  반복 681 / 1327 | 시간 915[s] | 퍼플렉서티 36.46
# | 에폭 40 |  반복 701 / 1327 | 시간 942[s] | 퍼플렉서티 42.62
# | 에폭 40 |  반복 721 / 1327 | 시간 969[s] | 퍼플렉서티 42.25
# | 에폭 40 |  반복 741 / 1327 | 시간 995[s] | 퍼플렉서티 37.85
# | 에폭 40 |  반복 761 / 1327 | 시간 1022[s] | 퍼플렉서티 34.27
# | 에폭 40 |  반복 781 / 1327 | 시간 1049[s] | 퍼플렉서티 37.74
# | 에폭 40 |  반복 801 / 1327 | 시간 1076[s] | 퍼플렉서티 41.68
# | 에폭 40 |  반복 821 / 1327 | 시간 1103[s] | 퍼플렉서티 42.97
# | 에폭 40 |  반복 841 / 1327 | 시간 1129[s] | 퍼플렉서티 42.07
# | 에폭 40 |  반복 861 / 1327 | 시간 1156[s] | 퍼플렉서티 41.12
# | 에폭 40 |  반복 881 / 1327 | 시간 1183[s] | 퍼플렉서티 38.67
# | 에폭 40 |  반복 901 / 1327 | 시간 1210[s] | 퍼플렉서티 48.94
# | 에폭 40 |  반복 921 / 1327 | 시간 1237[s] | 퍼플렉서티 44.33
# | 에폭 40 |  반복 941 / 1327 | 시간 1264[s] | 퍼플렉서티 46.69
# | 에폭 40 |  반복 961 / 1327 | 시간 1291[s] | 퍼플렉서티 49.44
# | 에폭 40 |  반복 981 / 1327 | 시간 1318[s] | 퍼플렉서티 45.91
# | 에폭 40 |  반복 1001 / 1327 | 시간 1345[s] | 퍼플렉서티 40.08
# | 에폭 40 |  반복 1021 / 1327 | 시간 1372[s] | 퍼플렉서티 47.07
# | 에폭 40 |  반복 1041 / 1327 | 시간 1398[s] | 퍼플렉서티 40.85
# | 에폭 40 |  반복 1061 / 1327 | 시간 1425[s] | 퍼플렉서티 38.13
# | 에폭 40 |  반복 1081 / 1327 | 시간 1452[s] | 퍼플렉서티 31.75
# | 에폭 40 |  반복 1101 / 1327 | 시간 1479[s] | 퍼플렉서티 32.25
# | 에폭 40 |  반복 1121 / 1327 | 시간 1506[s] | 퍼플렉서티 44.27
# | 에폭 40 |  반복 1141 / 1327 | 시간 1533[s] | 퍼플렉서티 42.05
# | 에폭 40 |  반복 1161 / 1327 | 시간 1559[s] | 퍼플렉서티 35.23
# | 에폭 40 |  반복 1181 / 1327 | 시간 1586[s] | 퍼플렉서티 39.79
# | 에폭 40 |  반복 1201 / 1327 | 시간 1613[s] | 퍼플렉서티 32.88
# | 에폭 40 |  반복 1221 / 1327 | 시간 1640[s] | 퍼플렉서티 32.06
# | 에폭 40 |  반복 1241 / 1327 | 시간 1666[s] | 퍼플렉서티 39.44
# | 에폭 40 |  반복 1261 / 1327 | 시간 1693[s] | 퍼플렉서티 37.27
# | 에폭 40 |  반복 1281 / 1327 | 시간 1720[s] | 퍼플렉서티 38.32
# | 에폭 40 |  반복 1301 / 1327 | 시간 1748[s] | 퍼플렉서티 46.17
# | 에폭 40 |  반복 1321 / 1327 | 시간 1775[s] | 퍼플렉서티 45.81
# 퍼플렉서티 평가 중 ...
# 209 / 210
# 검증 퍼플렉서티:  80.39828647469186
# --------------------------------------------------

# %%
# 테스트 데이터로 평가
model.reset_state()
ppl_test = eval_perplexity(model, corpus_test)
print('테스트 퍼플렉서티: ', ppl_test)
# Out:
# 퍼플렉서티 평가 중 ...
# 234 / 235
# 테스트 퍼플렉서티:  76.94841229986457
